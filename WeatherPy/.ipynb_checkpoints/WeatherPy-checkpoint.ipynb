# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import json
import requests
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import datetime
from scipy.stats import linregress

# Import API key
from api_key import weather_api_key

# Incorporate citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/city_data.csv"

# Range of latitude and longitude
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Create a base url
base_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# Counters
city_counter = 1
set_counter = 1

# Create the lists we will need to append to for the dataframe
city_names = []
lat = []
long = []
maxtemp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

print("Beginning Data Retrieval")
print("-----------------------------")

# Create a query url for each city in the cities list to get json response
for i, city in enumerate(cities):
    
    # Group cities as sets of 50s
    if (i % 50 == 0 and i >= 50):
        set_counter += 1
        city_counter = 1
         
    # Create API url for each city
    query_url = base_url +"&q=" + city
    
    # Get json respose for each city
    response = requests.get(query_url).json()
    
    # Print the results 
    print(f"Processing Record {city_counter} of Set {set_counter} | {city}")
    
    # Increase record count for next loop
    city_counter += 1
    
   # Add the values to the lists
    try:       
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        maxtemp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        city_names.append(response["name"])
    except:
        print("City not found. Skipping...")
        pass
       
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 3 of Set 1 | teya
# Processing Record 4 of Set 1 | saskylakh
# Processing Record 5 of Set 1 | saldanha
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | cairns
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | vieux-habitants
# Processing Record 10 of Set 1 | kula
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | luderitz
# Processing Record 13 of Set 1 | muzhi
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | nanning
# Processing Record 16 of Set 1 | riyadh
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | qaqortoq
# Processing Record 20 of Set 1 | mwinilunga
# Processing Record 21 of Set 1 | port lincoln
# Processing Record 22 of Set 1 | honiara
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | conde
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | cabo san lucas
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | tuatapere
# Processing Record 31 of Set 1 | lavrentiya
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | loiza
# Processing Record 34 of Set 1 | hami
# Processing Record 35 of Set 1 | caravelas
# Processing Record 36 of Set 1 | sao filipe
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | pisco
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | pontes e lacerda
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | kathmandu
# Processing Record 45 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 1 | shenjiamen
# Processing Record 47 of Set 1 | oksfjord
# Processing Record 48 of Set 1 | cherskiy
# Processing Record 49 of Set 1 | belmonte
# Processing Record 50 of Set 1 | jiwani
# Processing Record 1 of Set 2 | dhidhdhoo
# Processing Record 2 of Set 2 | upernavik
# Processing Record 3 of Set 2 | bilma
# Processing Record 4 of Set 2 | kaitangata
# Processing Record 5 of Set 2 | bouna
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | kazachinskoye
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | fairbanks
# Processing Record 12 of Set 2 | gunjur
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | kruisfontein
# Processing Record 15 of Set 2 | auki
# Processing Record 16 of Set 2 | aripuana
# Processing Record 17 of Set 2 | tsiroanomandidy
# Processing Record 18 of Set 2 | mehamn
# Processing Record 19 of Set 2 | shelburne
# Processing Record 20 of Set 2 | touros
# Processing Record 21 of Set 2 | sangar
# Processing Record 22 of Set 2 | umm kaddadah
# Processing Record 23 of Set 2 | skiros
# City not found. Skipping...
# Processing Record 24 of Set 2 | grajewo
# Processing Record 25 of Set 2 | mitsamiouli
# Processing Record 26 of Set 2 | muros
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | sioux lookout
# Processing Record 31 of Set 2 | penzance
# Processing Record 32 of Set 2 | nyurba
# Processing Record 33 of Set 2 | araouane
# Processing Record 34 of Set 2 | sorland
# Processing Record 35 of Set 2 | moindou
# Processing Record 36 of Set 2 | belgrade
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | saquarema
# Processing Record 39 of Set 2 | maun
# Processing Record 40 of Set 2 | sitka
# Processing Record 41 of Set 2 | nouadhibou
# Processing Record 42 of Set 2 | macheng
# Processing Record 43 of Set 2 | esil
# Processing Record 44 of Set 2 | casa nova
# Processing Record 45 of Set 2 | castro
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | nargana
# Processing Record 48 of Set 2 | lebu
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | kloulklubed
# Processing Record 1 of Set 3 | bengkulu
# Processing Record 2 of Set 3 | kaniama
# Processing Record 3 of Set 3 | talnakh
# Processing Record 4 of Set 3 | thunder bay
# Processing Record 5 of Set 3 | tasiilaq
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | rocha
# Processing Record 8 of Set 3 | piove di sacco
# Processing Record 9 of Set 3 | flinders
# Processing Record 10 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 3 | buxtehude
# Processing Record 13 of Set 3 | bobon
# Processing Record 14 of Set 3 | dzhebariki-khaya
# Processing Record 15 of Set 3 | port blair
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | san patricio
# Processing Record 18 of Set 3 | ahipara
# Processing Record 19 of Set 3 | fortuna
# Processing Record 20 of Set 3 | deputatskiy
# Processing Record 21 of Set 3 | victoria
# Processing Record 22 of Set 3 | husavik
# Processing Record 23 of Set 3 | san nicolas
# Processing Record 24 of Set 3 | oussouye
# Processing Record 25 of Set 3 | coquimbo
# Processing Record 26 of Set 3 | west bay
# Processing Record 27 of Set 3 | kavieng
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | khatanga
# Processing Record 30 of Set 3 | fougamou
# Processing Record 31 of Set 3 | cape town
# Processing Record 32 of Set 3 | diamantino
# Processing Record 33 of Set 3 | dharmanagar
# Processing Record 34 of Set 3 | lihula
# Processing Record 35 of Set 3 | tautira
# Processing Record 36 of Set 3 | sao joao da barra
# Processing Record 37 of Set 3 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 38 of Set 3 | tiarei
# Processing Record 39 of Set 3 | chuy
# Processing Record 40 of Set 3 | ramnagar
# Processing Record 41 of Set 3 | yar-sale
# Processing Record 42 of Set 3 | saint-pierre
# Processing Record 43 of Set 3 | tiznit
# Processing Record 44 of Set 3 | kidal
# Processing Record 45 of Set 3 | chiali
# City not found. Skipping...
# Processing Record 46 of Set 3 | maraa
# Processing Record 47 of Set 3 | miraflores
# Processing Record 48 of Set 3 | dingle
# Processing Record 49 of Set 3 | alyangula
# Processing Record 50 of Set 3 | aklavik
# Processing Record 1 of Set 4 | talcahuano
# Processing Record 2 of Set 4 | namyslow
# Processing Record 3 of Set 4 | bambous virieux
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | pochutla
# Processing Record 6 of Set 4 | puerto ayora
# Processing Record 7 of Set 4 | lubango
# Processing Record 8 of Set 4 | vostok
# Processing Record 9 of Set 4 | hokitika
# Processing Record 10 of Set 4 | lingao
# Processing Record 11 of Set 4 | qaanaaq
# Processing Record 12 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 13 of Set 4 | woodstock
# Processing Record 14 of Set 4 | pangnirtung
# Processing Record 15 of Set 4 | jumla
# Processing Record 16 of Set 4 | ishigaki
# Processing Record 17 of Set 4 | juegang
# Processing Record 18 of Set 4 | smirnykh
# Processing Record 19 of Set 4 | atyashevo
# Processing Record 20 of Set 4 | hlyboka
# Processing Record 21 of Set 4 | mudhol
# Processing Record 22 of Set 4 | chaumont
# Processing Record 23 of Set 4 | georgetown
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | cayenne
# Processing Record 26 of Set 4 | sola
# Processing Record 27 of Set 4 | vila velha
# Processing Record 28 of Set 4 | hobart
# Processing Record 29 of Set 4 | klaksvik
# Processing Record 30 of Set 4 | bud
# Processing Record 31 of Set 4 | leh
# Processing Record 32 of Set 4 | marsabit
# Processing Record 33 of Set 4 | lompoc
# Processing Record 34 of Set 4 | poronaysk
# Processing Record 35 of Set 4 | alofi
# Processing Record 36 of Set 4 | ornskoldsvik
# Processing Record 37 of Set 4 | katsuura
# Processing Record 38 of Set 4 | nong han
# Processing Record 39 of Set 4 | najran
# Processing Record 40 of Set 4 | rawson
# Processing Record 41 of Set 4 | saint-francois
# Processing Record 42 of Set 4 | meulaboh
# Processing Record 43 of Set 4 | saeby
# Processing Record 44 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 4 | taltal
# Processing Record 46 of Set 4 | beidao
# Processing Record 47 of Set 4 | san rafael
# Processing Record 48 of Set 4 | calama
# Processing Record 49 of Set 4 | rock sound
# Processing Record 50 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 5 | rassvet
# Processing Record 2 of Set 5 | adrar
# Processing Record 3 of Set 5 | mouzakion
# City not found. Skipping...
# Processing Record 4 of Set 5 | keita
# Processing Record 5 of Set 5 | mount gambier
# Processing Record 6 of Set 5 | grindavik
# Processing Record 7 of Set 5 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 8 of Set 5 | twin falls
# Processing Record 9 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 5 | mana
# Processing Record 11 of Set 5 | ancud
# Processing Record 12 of Set 5 | alta floresta
# Processing Record 13 of Set 5 | geraldton
# Processing Record 14 of Set 5 | fort wellington
# Processing Record 15 of Set 5 | lamu
# Processing Record 16 of Set 5 | garowe
# Processing Record 17 of Set 5 | el cobre
# Processing Record 18 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 20 of Set 5 | shimoda
# Processing Record 21 of Set 5 | tekeli
# Processing Record 22 of Set 5 | san cristobal
# Processing Record 23 of Set 5 | tyler
# Processing Record 24 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 5 | ormara
# Processing Record 26 of Set 5 | antofagasta
# Processing Record 27 of Set 5 | leningradskiy
# Processing Record 28 of Set 5 | kattivakkam
# Processing Record 29 of Set 5 | middlebury
# Processing Record 30 of Set 5 | buala
# Processing Record 31 of Set 5 | voyvozh
# Processing Record 32 of Set 5 | stornoway
# Processing Record 33 of Set 5 | minas
# Processing Record 34 of Set 5 | kushima
# Processing Record 35 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 5 | esperance
# Processing Record 37 of Set 5 | lubao
# Processing Record 38 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 5 | souillac
# Processing Record 40 of Set 5 | nalut
# Processing Record 41 of Set 5 | baykit
# Processing Record 42 of Set 5 | saint george
# Processing Record 43 of Set 5 | chiredzi
# Processing Record 44 of Set 5 | sibu
# Processing Record 45 of Set 5 | nanortalik
# Processing Record 46 of Set 5 | naze
# Processing Record 47 of Set 5 | sandwick
# Processing Record 48 of Set 5 | monte alegre
# Processing Record 49 of Set 5 | kargil
# Processing Record 50 of Set 5 | kandalaksha
# Processing Record 1 of Set 6 | hualmay
# Processing Record 2 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 6 | carnarvon
# Processing Record 4 of Set 6 | havoysund
# Processing Record 5 of Set 6 | tsaratanana
# Processing Record 6 of Set 6 | pacific grove
# Processing Record 7 of Set 6 | tura
# Processing Record 8 of Set 6 | benguela
# Processing Record 9 of Set 6 | scottsbluff
# Processing Record 10 of Set 6 | borba
# Processing Record 11 of Set 6 | paamiut
# Processing Record 12 of Set 6 | bluff
# Processing Record 13 of Set 6 | emerald
# Processing Record 14 of Set 6 | iranshahr
# Processing Record 15 of Set 6 | ruteng
# Processing Record 16 of Set 6 | manta
# Processing Record 17 of Set 6 | lake charles
# Processing Record 18 of Set 6 | kirakira
# Processing Record 19 of Set 6 | the valley
# Processing Record 20 of Set 6 | ketchikan
# Processing Record 21 of Set 6 | hasaki
# Processing Record 22 of Set 6 | sambava
# Processing Record 23 of Set 6 | tambura
# Processing Record 24 of Set 6 | lazaro cardenas
# Processing Record 25 of Set 6 | qeshm
# Processing Record 26 of Set 6 | olafsvik
# Processing Record 27 of Set 6 | hongjiang
# Processing Record 28 of Set 6 | bairiki
# Processing Record 29 of Set 6 | karakol
# Processing Record 30 of Set 6 | iqaluit
# Processing Record 31 of Set 6 | mount isa
# Processing Record 32 of Set 6 | svetlogorsk
# Processing Record 33 of Set 6 | clyde river
# Processing Record 34 of Set 6 | calarasi
# Processing Record 35 of Set 6 | tuktoyaktuk
# Processing Record 36 of Set 6 | baniyas
# Processing Record 37 of Set 6 | la ronge
# Processing Record 38 of Set 6 | provideniya
# Processing Record 39 of Set 6 | ugoofaaru
# Processing Record 40 of Set 6 | hofn
# Processing Record 41 of Set 6 | padang
# Processing Record 42 of Set 6 | ngorongoro
# Processing Record 43 of Set 6 | egvekinot
# Processing Record 44 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 6 | itaguai
# Processing Record 46 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 47 of Set 6 | goundam
# Processing Record 48 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 6 | caldwell
# Processing Record 50 of Set 6 | port elizabeth
# Processing Record 1 of Set 7 | vestmanna
# Processing Record 2 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 7 | hirara
# Processing Record 4 of Set 7 | lorengau
# Processing Record 5 of Set 7 | tucurui
# Processing Record 6 of Set 7 | hudiksvall
# Processing Record 7 of Set 7 | san miguel
# Processing Record 8 of Set 7 | narsaq
# Processing Record 9 of Set 7 | os
# City not found. Skipping...
# Processing Record 10 of Set 7 | bredasdorp
# Processing Record 11 of Set 7 | havre-saint-pierre
# Processing Record 12 of Set 7 | pevek
# Processing Record 13 of Set 7 | vyara
# Processing Record 14 of Set 7 | groningen
# Processing Record 15 of Set 7 | norman wells
# Processing Record 16 of Set 7 | manacor
# Processing Record 17 of Set 7 | sinop
# Processing Record 18 of Set 7 | celestun
# Processing Record 19 of Set 7 | kropotkin
# Processing Record 20 of Set 7 | prainha
# Processing Record 21 of Set 7 | piacabucu
# Processing Record 22 of Set 7 | coahuayana
# Processing Record 23 of Set 7 | avera
# Processing Record 24 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 25 of Set 7 | kavaratti
# Processing Record 26 of Set 7 | finschhafen
# Processing Record 27 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 28 of Set 7 | singkang
# Processing Record 29 of Set 7 | nome
# Processing Record 30 of Set 7 | altamira
# Processing Record 31 of Set 7 | huanren
# Processing Record 32 of Set 7 | san carlos de bariloche
# Processing Record 33 of Set 7 | lincoln
# Processing Record 34 of Set 7 | kismayo
# Processing Record 35 of Set 7 | karratha
# Processing Record 36 of Set 7 | road town
# Processing Record 37 of Set 7 | bathsheba
# Processing Record 38 of Set 7 | camacha
# Processing Record 39 of Set 7 | lososina
# Processing Record 40 of Set 7 | wlodawa
# Processing Record 41 of Set 7 | zionsville
# Processing Record 42 of Set 7 | longyearbyen
# Processing Record 43 of Set 7 | takapau
# Processing Record 44 of Set 7 | terrace
# Processing Record 45 of Set 7 | pompeu
# Processing Record 46 of Set 7 | orahovac
# Processing Record 47 of Set 7 | isla mujeres
# Processing Record 48 of Set 7 | saint-joseph
# Processing Record 49 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 7 | wukari
# Processing Record 1 of Set 8 | roald
# Processing Record 2 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 8 | prince rupert
# Processing Record 4 of Set 8 | kalemie
# Processing Record 5 of Set 8 | barrow
# Processing Record 6 of Set 8 | buraydah
# Processing Record 7 of Set 8 | guerrero negro
# Processing Record 8 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 8 | port-cartier
# Processing Record 12 of Set 8 | makurdi
# Processing Record 13 of Set 8 | owando
# Processing Record 14 of Set 8 | haines junction
# Processing Record 15 of Set 8 | saint-georges
# Processing Record 16 of Set 8 | fort nelson
# Processing Record 17 of Set 8 | port lavaca
# Processing Record 18 of Set 8 | assiniboia
# Processing Record 19 of Set 8 | itarema
# Processing Record 20 of Set 8 | hervey bay
# Processing Record 21 of Set 8 | ende
# Processing Record 22 of Set 8 | danane
# Processing Record 23 of Set 8 | burica
# City not found. Skipping...
# Processing Record 24 of Set 8 | thinadhoo
# Processing Record 25 of Set 8 | bongor
# Processing Record 26 of Set 8 | thessalon
# Processing Record 27 of Set 8 | saint-augustin
# Processing Record 28 of Set 8 | east wenatchee bench
# Processing Record 29 of Set 8 | ajdabiya
# Processing Record 30 of Set 8 | kyshtovka
# Processing Record 31 of Set 8 | sao gabriel da cachoeira
# Processing Record 32 of Set 8 | cidreira
# Processing Record 33 of Set 8 | djambala
# Processing Record 34 of Set 8 | atasu
# Processing Record 35 of Set 8 | catuday
# Processing Record 36 of Set 8 | premia de mar
# Processing Record 37 of Set 8 | awbari
# Processing Record 38 of Set 8 | librazhd
# Processing Record 39 of Set 8 | college
# Processing Record 40 of Set 8 | wollongong
# Processing Record 41 of Set 8 | salalah
# Processing Record 42 of Set 8 | bethanien
# Processing Record 43 of Set 8 | aranos
# Processing Record 44 of Set 8 | inhambane
# Processing Record 45 of Set 8 | areosa
# Processing Record 46 of Set 8 | kassala
# Processing Record 47 of Set 8 | kodinsk
# Processing Record 48 of Set 8 | bubaque
# Processing Record 49 of Set 8 | tanete
# Processing Record 50 of Set 8 | sao desiderio
# Processing Record 1 of Set 9 | san policarpo
# Processing Record 2 of Set 9 | qinggang
# Processing Record 3 of Set 9 | hambantota
# Processing Record 4 of Set 9 | byron bay
# Processing Record 5 of Set 9 | yamada
# Processing Record 6 of Set 9 | slave lake
# Processing Record 7 of Set 9 | axim
# Processing Record 8 of Set 9 | palmer
# Processing Record 9 of Set 9 | alangudi
# Processing Record 10 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 9 | beringovskiy
# Processing Record 13 of Set 9 | yarega
# Processing Record 14 of Set 9 | mezen
# Processing Record 15 of Set 9 | evensk
# Processing Record 16 of Set 9 | isangel
# Processing Record 17 of Set 9 | berezovyy
# Processing Record 18 of Set 9 | hanna
# Processing Record 19 of Set 9 | kieta
# Processing Record 20 of Set 9 | avarua
# Processing Record 21 of Set 9 | trat
# Processing Record 22 of Set 9 | kulhudhuffushi
# Processing Record 23 of Set 9 | bethel
# Processing Record 24 of Set 9 | goderich
# Processing Record 25 of Set 9 | pokhara
# Processing Record 26 of Set 9 | vagur
# Processing Record 27 of Set 9 | kayan
# Processing Record 28 of Set 9 | ilulissat
# Processing Record 29 of Set 9 | scarborough
# Processing Record 30 of Set 9 | vao
# Processing Record 31 of Set 9 | puerto escondido
# Processing Record 32 of Set 9 | labuhan
# Processing Record 33 of Set 9 | jacareacanga
# Processing Record 34 of Set 9 | caraquet
# Processing Record 35 of Set 9 | berbera
# Processing Record 36 of Set 9 | turbat
# Processing Record 37 of Set 9 | bowen
# Processing Record 38 of Set 9 | pryazha
# Processing Record 39 of Set 9 | ushtobe
# Processing Record 40 of Set 9 | ghanzi
# Processing Record 41 of Set 9 | hamilton
# Processing Record 42 of Set 9 | charcas
# Processing Record 43 of Set 9 | altay
# Processing Record 44 of Set 9 | samarai
# Processing Record 45 of Set 9 | jujuy
# City not found. Skipping...
# Processing Record 46 of Set 9 | ballina
# Processing Record 47 of Set 9 | sungaipenuh
# Processing Record 48 of Set 9 | waimana
# Processing Record 49 of Set 9 | nakapiripirit
# Processing Record 50 of Set 9 | kahului
# Processing Record 1 of Set 10 | vanavara
# Processing Record 2 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 10 | ostersund
# Processing Record 4 of Set 10 | izumo
# Processing Record 5 of Set 10 | santa cruz de la palma
# Processing Record 6 of Set 10 | mayor pablo lagerenza
# Processing Record 7 of Set 10 | opobo
# City not found. Skipping...
# Processing Record 8 of Set 10 | kirovsk
# Processing Record 9 of Set 10 | san luis
# Processing Record 10 of Set 10 | nizwa
# Processing Record 11 of Set 10 | faanui
# Processing Record 12 of Set 10 | apucarana
# Processing Record 13 of Set 10 | beloha
# Processing Record 14 of Set 10 | nemuro
# Processing Record 15 of Set 10 | carlos antonio lopez
# Processing Record 16 of Set 10 | hosanagara
# Processing Record 17 of Set 10 | malanje
# Processing Record 18 of Set 10 | westport
# Processing Record 19 of Set 10 | asau
# Processing Record 20 of Set 10 | payo
# Processing Record 21 of Set 10 | panguipulli
# Processing Record 22 of Set 10 | doha
# Processing Record 23 of Set 10 | olinda
# Processing Record 24 of Set 10 | indramayu
# Processing Record 25 of Set 10 | nova olimpia
# Processing Record 26 of Set 10 | visakhapatnam
# Processing Record 27 of Set 10 | knysna
# Processing Record 28 of Set 10 | ciudad bolivar
# Processing Record 29 of Set 10 | berlevag
# Processing Record 30 of Set 10 | grand gaube
# Processing Record 31 of Set 10 | matara
# Processing Record 32 of Set 10 | loreto
# Processing Record 33 of Set 10 | xiongzhou
# Processing Record 34 of Set 10 | yozgat
# Processing Record 35 of Set 10 | kalamare
# Processing Record 36 of Set 10 | te anau
# Processing Record 37 of Set 10 | jiangyou
# Processing Record 38 of Set 10 | san vicente
# Processing Record 39 of Set 10 | sumenep
# Processing Record 40 of Set 10 | sept-iles
# Processing Record 41 of Set 10 | nuevo progreso
# Processing Record 42 of Set 10 | atar
# Processing Record 43 of Set 10 | khorinsk
# Processing Record 44 of Set 10 | anshun
# Processing Record 45 of Set 10 | omboue
# Processing Record 46 of Set 10 | sayat
# Processing Record 47 of Set 10 | berdyuzhye
# City not found. Skipping...
# Processing Record 48 of Set 10 | muisne
# Processing Record 49 of Set 10 | marakkanam
# Processing Record 50 of Set 10 | oriximina
# Processing Record 1 of Set 11 | lom sak
# Processing Record 2 of Set 11 | presidente medici
# Processing Record 3 of Set 11 | sao bernardo
# Processing Record 4 of Set 11 | kiboga
# Processing Record 5 of Set 11 | adjuntas
# Processing Record 6 of Set 11 | bodden town
# Processing Record 7 of Set 11 | ayan
# Processing Record 8 of Set 11 | severnoye
# Processing Record 9 of Set 11 | dulce nombre de culmi
# Processing Record 10 of Set 11 | trapani
# Processing Record 11 of Set 11 | brae
# Processing Record 12 of Set 11 | blonduos
# City not found. Skipping...
# Processing Record 13 of Set 11 | bakurianis andeziti
# Processing Record 14 of Set 11 | prescott
# Processing Record 15 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 11 | ixtapa
# Processing Record 17 of Set 11 | san quintin
# Processing Record 18 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 19 of Set 11 | eureka
# Processing Record 20 of Set 11 | chizhou
# Processing Record 21 of Set 11 | ponta delgada
# Processing Record 22 of Set 11 | champerico
# Processing Record 23 of Set 11 | calvia
# Processing Record 24 of Set 11 | hirado
# Processing Record 25 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 26 of Set 11 | sadiqabad
# Processing Record 27 of Set 11 | guadalupe y calvo
# Processing Record 28 of Set 11 | chandler
# Processing Record 29 of Set 11 | bela
# Processing Record 30 of Set 11 | punuare
# Processing Record 31 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 11 | manacapuru
# Processing Record 33 of Set 11 | takhtamygda
# Processing Record 34 of Set 11 | ha
# City not found. Skipping...
# Processing Record 35 of Set 11 | tokomaru
# Processing Record 36 of Set 11 | sogne
# Processing Record 37 of Set 11 | kulachi
# Processing Record 38 of Set 11 | matay
# Processing Record 39 of Set 11 | muravlenko
# Processing Record 40 of Set 11 | dimbokro
# Processing Record 41 of Set 11 | namibe
# Processing Record 42 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 45 of Set 11 | spornoye
# Processing Record 46 of Set 11 | loandjili
# Processing Record 47 of Set 11 | dauriya
# Processing Record 48 of Set 11 | yulara
# Processing Record 49 of Set 11 | fernie
# Processing Record 50 of Set 11 | aksarka
# Processing Record 1 of Set 12 | corinto
# Processing Record 2 of Set 12 | arcachon
# Processing Record 3 of Set 12 | praia
# Processing Record 4 of Set 12 | saint-leu
# Processing Record 5 of Set 12 | george
# Processing Record 6 of Set 12 | ulaangom
# Processing Record 7 of Set 12 | bulgan
# Processing Record 8 of Set 12 | labytnangi
# Processing Record 9 of Set 12 | skibbereen
# Processing Record 10 of Set 12 | umm lajj
# Processing Record 11 of Set 12 | kungurtug
# Processing Record 12 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 13 of Set 12 | mar de espanha
# Processing Record 14 of Set 12 | mahuva
# Processing Record 15 of Set 12 | banjar
# Processing Record 16 of Set 12 | anloga
# Processing Record 17 of Set 12 | huarmey
# Processing Record 18 of Set 12 | lata
# Processing Record 19 of Set 12 | san juan bautista
# Processing Record 20 of Set 12 | bay roberts
# Processing Record 21 of Set 12 | jian
# Processing Record 22 of Set 12 | singaraja
# Processing Record 23 of Set 12 | neijiang
# Processing Record 24 of Set 12 | manyana
# Processing Record 25 of Set 12 | orange cove
# Processing Record 26 of Set 12 | senmonorom
# City not found. Skipping...
# Processing Record 27 of Set 12 | robore
# Processing Record 28 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 29 of Set 12 | ondjiva
# Processing Record 30 of Set 12 | pocatello
# Processing Record 31 of Set 12 | bergerac
# Processing Record 32 of Set 12 | vardo
# Processing Record 33 of Set 12 | sevenoaks
# Processing Record 34 of Set 12 | dongsheng
# Processing Record 35 of Set 12 | taman
# Processing Record 36 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 37 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 38 of Set 12 | ucluelet
# Processing Record 39 of Set 12 | zakharovo
# Processing Record 40 of Set 12 | mayo
# Processing Record 41 of Set 12 | lerwick
# Processing Record 42 of Set 12 | harper
# Processing Record 43 of Set 12 | xicotencatl
# Processing Record 44 of Set 12 | laramie
# Processing Record 45 of Set 12 | gushi
# Processing Record 46 of Set 12 | apolda
# Processing Record 47 of Set 12 | atambua
# Processing Record 48 of Set 12 | rio grande
# Processing Record 49 of Set 12 | nhulunbuy
# Processing Record 50 of Set 12 | vanino
# Processing Record 1 of Set 13 | stanger
# Processing Record 2 of Set 13 | cascas
# Processing Record 3 of Set 13 | bratsk
# Processing Record 4 of Set 13 | pathein
# Processing Record 5 of Set 13 | cap-aux-meules
# Processing Record 6 of Set 13 | lagoa
# Processing Record 7 of Set 13 | romny
# Processing Record 8 of Set 13 | acarau
# Processing Record 9 of Set 13 | newport
# Processing Record 10 of Set 13 | gurupa
# Processing Record 11 of Set 13 | yumen
# Processing Record 12 of Set 13 | xiamen
# Processing Record 13 of Set 13 | albanel
# Processing Record 14 of Set 13 | vestmannaeyjar
# Processing Record 15 of Set 13 | niquero
# Processing Record 16 of Set 13 | menongue
# Processing Record 17 of Set 13 | kristiansund
# Processing Record 18 of Set 13 | jutai
# Processing Record 19 of Set 13 | palma di montechiaro
# Processing Record 20 of Set 13 | surgut
# Processing Record 21 of Set 13 | luanda
# Processing Record 22 of Set 13 | kendari
# Processing Record 23 of Set 13 | luau
# Processing Record 24 of Set 13 | coihaique
# Processing Record 25 of Set 13 | puerto madryn
# Processing Record 26 of Set 13 | kangaatsiaq
# Processing Record 27 of Set 13 | la libertad
# Processing Record 28 of Set 13 | chimbote
# Processing Record 29 of Set 13 | junction city
# Processing Record 30 of Set 13 | balkanabat
# Processing Record 31 of Set 13 | innisfail
# Processing Record 32 of Set 13 | tezu
# Processing Record 33 of Set 13 | barra patuca
# Processing Record 34 of Set 13 | ugento
# Processing Record 35 of Set 13 | opuwo
# Processing Record 36 of Set 13 | eyl
# Processing Record 37 of Set 13 | dubai
# Processing Record 38 of Set 13 | morehead
# Processing Record 39 of Set 13 | palma
# Processing Record 40 of Set 13 | fomeque
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Put the data into a dataframe
city_data_df = pd.DataFrame({
    "City": city_names,
    "Lat": lat,
    "Lng": long,
    "Max Temp": maxtemp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
})

# Display the DataFrame
city_data_df
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 Teya  60.3778   92.6267     37.90        72         100
# 1            Saskylakh  71.9167  114.0833     31.14        85          90
# 2             Saldanha -33.0117   17.9442     50.00        81          97
# 3           Butaritari   3.0707  172.7902     81.90        79          64
# 4               Cairns -16.9167  145.7667     88.00        54           0
# ..                 ...      ...       ...       ...       ...         ...
# 580                Eyl   7.9803   49.8164     83.34        62          83
# 581              Dubai  25.2582   55.3047     78.80        73          29
# 582           Morehead  37.2711  -87.1764     48.00        81           1
# 583  Palma de Mallorca  39.5694    2.6502     61.00        88          20
# 584            Fómeque   4.4880  -73.8975     55.40        82          40
#
#      Wind Speed Country        Date
# 0         10.60      RU  1620963727
# 1          2.26      RU  1620963727
# 2          6.80      ZA  1620963727
# 3          9.35      KI  1620963727
# 4         12.66      AU  1620963728
# ..          ...     ...         ...
# 580       22.88      SO  1620963863
# 581        6.91      AE  1620963729
# 582        3.00      US  1620963863
# 583        2.30      ES  1620963652
# 584        2.30      CO  1620963864
#
# [585 rows x 9 columns]

# %%
# How many entries were returned?
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Teya  60.3778   92.6267     37.90        72         100       10.60
# 1   Saskylakh  71.9167  114.0833     31.14        85          90        2.26
# 2    Saldanha -33.0117   17.9442     50.00        81          97        6.80
# 3  Butaritari   3.0707  172.7902     81.90        79          64        9.35
# 4      Cairns -16.9167  145.7667     88.00        54           0       12.66
#
#   Country        Date
# 0      RU  1620963727
# 1      RU  1620963727
# 2      ZA  1620963727
# 3      KI  1620963727
# 4      AU  1620963728

# %%
# Inspect the data by using the describe function
city_data_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  585.000000  585.000000  585.000000  585.000000  585.000000  585.000000
# mean    19.060698   13.697103   64.192701   70.278632   52.529915    7.371179
# std     32.528077   88.270925   17.007941   20.919103   38.340886    5.222472
# min    -54.800000 -179.166700   15.800000    7.000000    0.000000    0.110000
# 25%     -8.145000  -61.901400   51.420000   60.000000   12.000000    3.490000
# 50%     20.931000   15.899900   64.330000   74.000000   62.000000    5.750000
# 75%     46.833300   88.116700   78.800000   87.000000   90.000000    9.550000
# max     78.218600  179.316700   98.010000  100.000000  100.000000   40.310000
#
#                Date
# count  5.850000e+02
# mean   1.620964e+09
# std    6.841928e+01
# min    1.620963e+09
# 25%    1.620964e+09
# 50%    1.620964e+09
# 75%    1.620964e+09
# max    1.620964e+09

# %%
# Export the city data into a csv file
city_data_df.to_csv("../output_data/city_data.csv", index=False)

# %%
# Show Record Count
countforme = len(city_data_df)
countforme
# Out:
# 574

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Calculate latest date (max) for plot titles
tstamp = city_data_df.Date.max()

# Convert Unix timestamp to formated date
fdate= time.strftime("%m/%d/%y",time.localtime(tstamp))
fdate

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude")

plt.savefig("../images/tempvlat.png")

# As latitude approaches 0, i.e. the equator, temperature increases

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Humidity (%) vs Latitude")

plt.savefig("../images/humvlat.png")

# There seems to be no relationship between humidity and latitude

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Cloudiness (%) vs Latitude")

plt.savefig("../images/cloudvlat.png")

# There seems to be no relationship between cloudiness and latitude

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Wind Speed (mph) vs Latitude")

plt.savefig("../images/windvlat.png")

# There seems to be no relationship between wind speed and latitude

# %% [markdown]
# ## Linear Regression

# %%
# Locate cities above or equal to 0 latitude and below 0 latitude
northern_cities = city_data_df[city_data_df.loc[:, "Lat"] >= 0]
southern_cities = city_data_df[city_data_df.loc[:, "Lat"] < 0]

# %%
# Create Northern and Southern Hemisphere DataFrames
northlat_df = city_data_df.loc[city_data_df["Lat"] >= 0,:]
southlat_df = city_data_df.loc[city_data_df["Lat"] < 0,:]

# %%
#Your next objective is to run linear regression on each relationship, only this time separating 
#them into Northern Hemisphere (greater than or equal to 0 degrees latitude) and 
#Southern Hemisphere (less than 0 degrees latitude):

#Northern Hemisphere - Humidity (%) vs. Latitude
#Southern Hemisphere - Humidity (%) vs. Latitude
#Northern Hemisphere - Cloudiness (%) vs. Latitude
#Southern Hemisphere - Cloudiness (%) vs. Latitude
#Northern Hemisphere - Wind Speed (mph) vs. Latitude
#Southern Hemisphere - Wind Speed (mph) vs. Latitude

#After each pair of plots explain what the linear regression is analyzing, any relationships you notice and any other analysis you may have.

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot Temperature (°F) vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Max Temp"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(10,10),fontsize=12,color="black")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/tempvlatnh.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot Temperature (F) vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Max Temp"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-53,81),fontsize=12,color="black")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/tempvlatsh.png")

# %%
print("The high r value indicates a strong positive correlation between latitude and max temperature.")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Lat"]
y_values = northlat_df["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('northernhumvlat')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Lat"]
y_values = southlat_df["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('southernhumvlat')

print("The low r values indicate a weak to no relationship between humidity and latitude.")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Lat"]
y_values = northlat_df["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig('northerncloudvlat')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Lat"]
y_values = southlat_df["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig('southerncloudvlat')

print("The low r values indicate a weak positive relationship between latitude and cloudiness.")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Lat"]
y_values = northlat_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('northernwindvlat')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Lat"]
y_values = southlat_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('southernwindvlat')

print("The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.")
      °

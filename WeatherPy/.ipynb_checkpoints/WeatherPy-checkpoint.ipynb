# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import json
import requests
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import datetime
from scipy.stats import linregress

# Import API key
from api_key import weather_api_key

# Incorporate citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/city_data.csv"

# Range of latitude and longitude
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %%
city_names = []
lat = []
long = []
maxtemp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
city_counter = 1
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
#         date.append(response["dt"])

print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_names.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date = datetime.datetime.fromtimestamp(int(response['dt'])).strftime('%m-%d-%Y')
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        maxtemp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        
        if city_counter > 49:
            city_counter = 0
            set_counter = set_counter + 1
    
        else:
            city_counter = city_counter + 1
            
        print(f"Processing Record {city_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 2 of Set 1 : kavieng
# City not found. Skipping...
# Processing Record 3 of Set 1 : college
# Processing Record 4 of Set 1 : port alfred
# Processing Record 5 of Set 1 : bluff
# Processing Record 6 of Set 1 : bredasdorp
# Processing Record 7 of Set 1 : bodden town
# Processing Record 8 of Set 1 : rikitea
# Processing Record 9 of Set 1 : longyearbyen
# Processing Record 10 of Set 1 : albany
# Processing Record 11 of Set 1 : east london
# Processing Record 12 of Set 1 : nanortalik
# Processing Record 13 of Set 1 : acapulco
# City not found. Skipping...
# Processing Record 14 of Set 1 : arkhara
# Processing Record 15 of Set 1 : souillac
# Processing Record 16 of Set 1 : kahului
# Processing Record 17 of Set 1 : prince george
# Processing Record 18 of Set 1 : beringovskiy
# Processing Record 19 of Set 1 : gatesville
# Processing Record 20 of Set 1 : atuona
# Processing Record 21 of Set 1 : mataura
# Processing Record 22 of Set 1 : zyryanka
# Processing Record 23 of Set 1 : georgetown
# Processing Record 24 of Set 1 : grindavik
# Processing Record 25 of Set 1 : svetlaya
# Processing Record 26 of Set 1 : jambi
# Processing Record 27 of Set 1 : pevek
# Processing Record 28 of Set 1 : saldanha
# City not found. Skipping...
# Processing Record 29 of Set 1 : tasiilaq
# Processing Record 30 of Set 1 : butaritari
# City not found. Skipping...
# Processing Record 31 of Set 1 : kaniama
# Processing Record 32 of Set 1 : vaini
# Processing Record 33 of Set 1 : punta arenas
# Processing Record 34 of Set 1 : saint-philippe
# Processing Record 35 of Set 1 : tefe
# Processing Record 36 of Set 1 : firozpur jhirka
# Processing Record 37 of Set 1 : ixtapa
# Processing Record 38 of Set 1 : torbat-e jam
# Processing Record 39 of Set 1 : busselton
# City not found. Skipping...
# Processing Record 40 of Set 1 : saint george
# City not found. Skipping...
# Processing Record 41 of Set 1 : lahaina
# Processing Record 42 of Set 1 : santa isabel do rio negro
# Processing Record 43 of Set 1 : ibra
# Processing Record 44 of Set 1 : ushuaia
# Processing Record 45 of Set 1 : namatanai
# Processing Record 46 of Set 1 : zverinogolovskoye
# Processing Record 47 of Set 1 : vila velha
# Processing Record 48 of Set 1 : kapaa
# Processing Record 49 of Set 1 : alofi
# Processing Record 50 of Set 1 : yulara
# Processing Record 0 of Set 2 : gari
# Processing Record 1 of Set 2 : qaanaaq
# Processing Record 2 of Set 2 : ribeira grande
# Processing Record 3 of Set 2 : zhigansk
# Processing Record 4 of Set 2 : sitka
# Processing Record 5 of Set 2 : nome
# Processing Record 6 of Set 2 : guerrero negro
# Processing Record 7 of Set 2 : norman wells
# Processing Record 8 of Set 2 : luderitz
# Processing Record 9 of Set 2 : bayan
# Processing Record 10 of Set 2 : waipawa
# Processing Record 11 of Set 2 : champerico
# Processing Record 12 of Set 2 : new norfolk
# Processing Record 13 of Set 2 : cadereyta
# Processing Record 14 of Set 2 : constitucion
# Processing Record 15 of Set 2 : batemans bay
# Processing Record 16 of Set 2 : lahijan
# Processing Record 17 of Set 2 : port-gentil
# Processing Record 18 of Set 2 : tuktoyaktuk
# Processing Record 19 of Set 2 : glenwood springs
# Processing Record 20 of Set 2 : avarua
# City not found. Skipping...
# Processing Record 21 of Set 2 : pisco
# Processing Record 22 of Set 2 : lebanon
# Processing Record 23 of Set 2 : jamestown
# Processing Record 24 of Set 2 : vestmannaeyjar
# Processing Record 25 of Set 2 : bubaque
# Processing Record 26 of Set 2 : nouakchott
# Processing Record 27 of Set 2 : kamina
# Processing Record 28 of Set 2 : aksu
# Processing Record 29 of Set 2 : evans
# Processing Record 30 of Set 2 : springdale
# Processing Record 31 of Set 2 : samarinda
# Processing Record 32 of Set 2 : cockburn town
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 2 : talnakh
# Processing Record 34 of Set 2 : cape town
# Processing Record 35 of Set 2 : rafaela
# Processing Record 36 of Set 2 : victoria
# Processing Record 37 of Set 2 : saint-louis
# Processing Record 38 of Set 2 : viransehir
# City not found. Skipping...
# Processing Record 39 of Set 2 : vardo
# Processing Record 40 of Set 2 : zhangjiakou
# Processing Record 41 of Set 2 : faanui
# Processing Record 42 of Set 2 : kanniyakumari
# Processing Record 43 of Set 2 : hasaki
# Processing Record 44 of Set 2 : sarkand
# Processing Record 45 of Set 2 : kashi
# Processing Record 46 of Set 2 : vanimo
# Processing Record 47 of Set 2 : saint-augustin
# Processing Record 48 of Set 2 : linhares
# Processing Record 49 of Set 2 : vila franca do campo
# Processing Record 50 of Set 2 : birjand
# Processing Record 0 of Set 3 : porto nacional
# Processing Record 1 of Set 3 : fairbanks
# Processing Record 2 of Set 3 : arraial do cabo
# Processing Record 3 of Set 3 : kaitangata
# Processing Record 4 of Set 3 : nikolskoye
# Processing Record 5 of Set 3 : airai
# Processing Record 6 of Set 3 : bengkulu
# Processing Record 7 of Set 3 : yellowknife
# Processing Record 8 of Set 3 : port arthur
# Processing Record 9 of Set 3 : buritizeiro
# Processing Record 10 of Set 3 : aklavik
# Processing Record 11 of Set 3 : coahuayana
# City not found. Skipping...
# Processing Record 12 of Set 3 : xinqing
# Processing Record 13 of Set 3 : morros
# Processing Record 14 of Set 3 : kiunga
# City not found. Skipping...
# Processing Record 15 of Set 3 : hobart
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 3 : chuy
# Processing Record 17 of Set 3 : cuamba
# Processing Record 18 of Set 3 : tabou
# Processing Record 19 of Set 3 : mahebourg
# Processing Record 20 of Set 3 : torbay
# Processing Record 21 of Set 3 : lompoc
# Processing Record 22 of Set 3 : cherskiy
# Processing Record 23 of Set 3 : meulaboh
# Processing Record 24 of Set 3 : ponta do sol
# Processing Record 25 of Set 3 : barrow
# Processing Record 26 of Set 3 : esperance
# Processing Record 27 of Set 3 : garissa
# Processing Record 28 of Set 3 : nouadhibou
# Processing Record 29 of Set 3 : kirakira
# Processing Record 30 of Set 3 : skjervoy
# Processing Record 31 of Set 3 : tuatapere
# Processing Record 32 of Set 3 : port moresby
# City not found. Skipping...
# Processing Record 33 of Set 3 : mahon
# Processing Record 34 of Set 3 : fortuna
# Processing Record 35 of Set 3 : zhangye
# Processing Record 36 of Set 3 : eureka
# Processing Record 37 of Set 3 : mount gambier
# Processing Record 38 of Set 3 : garden city
# Processing Record 39 of Set 3 : price
# Processing Record 40 of Set 3 : bethel
# Processing Record 41 of Set 3 : izhma
# Processing Record 42 of Set 3 : bambous virieux
# Processing Record 43 of Set 3 : kodiak
# Processing Record 44 of Set 3 : trelew
# Processing Record 45 of Set 3 : sheridan
# Processing Record 46 of Set 3 : high prairie
# Processing Record 47 of Set 3 : talaya
# Processing Record 48 of Set 3 : biskamzha
# Processing Record 49 of Set 3 : vao
# Processing Record 50 of Set 3 : gravdal
# Processing Record 0 of Set 4 : carnarvon
# Processing Record 1 of Set 4 : ust-kuyga
# Processing Record 2 of Set 4 : dikson
# City not found. Skipping...
# Processing Record 3 of Set 4 : mar del plata
# Processing Record 4 of Set 4 : upernavik
# Processing Record 5 of Set 4 : pushkino
# Processing Record 6 of Set 4 : polunochnoye
# Processing Record 7 of Set 4 : cape coast
# Processing Record 8 of Set 4 : te anau
# Processing Record 9 of Set 4 : manzhouli
# City not found. Skipping...
# Processing Record 10 of Set 4 : berdyaush
# Processing Record 11 of Set 4 : dalby
# Processing Record 12 of Set 4 : pathein
# Processing Record 13 of Set 4 : axim
# Processing Record 14 of Set 4 : merauke
# Processing Record 15 of Set 4 : port elizabeth
# Processing Record 16 of Set 4 : san rafael
# Processing Record 17 of Set 4 : huilong
# City not found. Skipping...
# Processing Record 18 of Set 4 : tawang
# Processing Record 19 of Set 4 : terrace bay
# Processing Record 20 of Set 4 : yinchuan
# Processing Record 21 of Set 4 : qaqortoq
# Processing Record 22 of Set 4 : mongar
# Processing Record 23 of Set 4 : lerwick
# City not found. Skipping...
# Processing Record 24 of Set 4 : sangar
# Processing Record 25 of Set 4 : sibolga
# Processing Record 26 of Set 4 : lima
# Processing Record 27 of Set 4 : lodwar
# Processing Record 28 of Set 4 : dukat
# Processing Record 29 of Set 4 : gat
# Processing Record 30 of Set 4 : puerto ayora
# Processing Record 31 of Set 4 : iquitos
# Processing Record 32 of Set 4 : brightwater
# Processing Record 33 of Set 4 : olafsvik
# Processing Record 34 of Set 4 : atikokan
# Processing Record 35 of Set 4 : moranbah
# Processing Record 36 of Set 4 : rapid valley
# Processing Record 37 of Set 4 : barghat
# Processing Record 38 of Set 4 : erzin
# Processing Record 39 of Set 4 : ahipara
# Processing Record 40 of Set 4 : laureles
# Processing Record 41 of Set 4 : swan hill
# Processing Record 42 of Set 4 : poso
# Processing Record 43 of Set 4 : doha
# Processing Record 44 of Set 4 : northam
# Processing Record 45 of Set 4 : chokurdakh
# Processing Record 46 of Set 4 : dandong
# Processing Record 47 of Set 4 : upata
# Processing Record 48 of Set 4 : ormstown
# Processing Record 49 of Set 4 : acajutla
# Processing Record 50 of Set 4 : linxi
# Processing Record 0 of Set 5 : castro verde
# Processing Record 1 of Set 5 : guanica
# Processing Record 2 of Set 5 : toronto
# Processing Record 3 of Set 5 : laizhou
# Processing Record 4 of Set 5 : bathsheba
# Processing Record 5 of Set 5 : maragogi
# Processing Record 6 of Set 5 : galesong
# Processing Record 7 of Set 5 : tokonou
# Processing Record 8 of Set 5 : khatanga
# Processing Record 9 of Set 5 : naze
# Processing Record 10 of Set 5 : puerto del rosario
# Processing Record 11 of Set 5 : mandalgovi
# Processing Record 12 of Set 5 : matay
# Processing Record 13 of Set 5 : codrington
# Processing Record 14 of Set 5 : kitob
# Processing Record 15 of Set 5 : kyra
# Processing Record 16 of Set 5 : donskoye
# Processing Record 17 of Set 5 : novoagansk
# Processing Record 18 of Set 5 : castro
# Processing Record 19 of Set 5 : lagoa
# Processing Record 20 of Set 5 : tezu
# Processing Record 21 of Set 5 : richards bay
# Processing Record 22 of Set 5 : baruun-urt
# Processing Record 23 of Set 5 : hermanus
# Processing Record 24 of Set 5 : aleysk
# Processing Record 25 of Set 5 : hithadhoo
# Processing Record 26 of Set 5 : bardejov
# Processing Record 27 of Set 5 : asyut
# City not found. Skipping...
# Processing Record 28 of Set 5 : santarem
# Processing Record 29 of Set 5 : jurado
# Processing Record 30 of Set 5 : mana
# Processing Record 31 of Set 5 : touros
# Processing Record 32 of Set 5 : vetlanda
# Processing Record 33 of Set 5 : bac lieu
# Processing Record 34 of Set 5 : thompson
# Processing Record 35 of Set 5 : clyde river
# Processing Record 36 of Set 5 : grand-santi
# Processing Record 37 of Set 5 : celestun
# Processing Record 38 of Set 5 : kupang
# Processing Record 39 of Set 5 : whitehorse
# Processing Record 40 of Set 5 : baculin
# Processing Record 41 of Set 5 : lebu
# Processing Record 42 of Set 5 : tiksi
# Processing Record 43 of Set 5 : wladyslawowo
# Processing Record 44 of Set 5 : vilkaviskis
# Processing Record 45 of Set 5 : sao joao da barra
# Processing Record 46 of Set 5 : katsuura
# Processing Record 47 of Set 5 : jucuaran
# City not found. Skipping...
# Processing Record 48 of Set 5 : port-cartier
# Processing Record 49 of Set 5 : yar-sale
# Processing Record 50 of Set 5 : provideniya
# Processing Record 0 of Set 6 : geraldton
# Processing Record 1 of Set 6 : sur
# Processing Record 2 of Set 6 : iqaluit
# Processing Record 3 of Set 6 : lindsay
# Processing Record 4 of Set 6 : springbok
# Processing Record 5 of Set 6 : deer lake
# Processing Record 6 of Set 6 : vrangel
# Processing Record 7 of Set 6 : omsukchan
# Processing Record 8 of Set 6 : tukrah
# Processing Record 9 of Set 6 : lata
# Processing Record 10 of Set 6 : ende
# Processing Record 11 of Set 6 : itapecerica
# Processing Record 12 of Set 6 : sindhnur
# City not found. Skipping...
# Processing Record 13 of Set 6 : mae sot
# Processing Record 14 of Set 6 : komsomolskiy
# Processing Record 15 of Set 6 : el reno
# Processing Record 16 of Set 6 : quang ngai
# Processing Record 17 of Set 6 : raub
# Processing Record 18 of Set 6 : disna
# Processing Record 19 of Set 6 : deputatskiy
# Processing Record 20 of Set 6 : tongzi
# City not found. Skipping...
# Processing Record 21 of Set 6 : angoche
# Processing Record 22 of Set 6 : arroyo
# Processing Record 23 of Set 6 : alice springs
# Processing Record 24 of Set 6 : andenes
# Processing Record 25 of Set 6 : caraballeda
# Processing Record 26 of Set 6 : mitsamiouli
# Processing Record 27 of Set 6 : namibe
# Processing Record 28 of Set 6 : mahajanga
# Processing Record 29 of Set 6 : makakilo city
# Processing Record 30 of Set 6 : alta floresta
# Processing Record 31 of Set 6 : haines junction
# Processing Record 32 of Set 6 : robertson
# Processing Record 33 of Set 6 : san cristobal
# Processing Record 34 of Set 6 : narsaq
# Processing Record 35 of Set 6 : altay
# Processing Record 36 of Set 6 : makkaveyevo
# Processing Record 37 of Set 6 : ust-nera
# Processing Record 38 of Set 6 : pultusk
# Processing Record 39 of Set 6 : namtsy
# Processing Record 40 of Set 6 : jaru
# Processing Record 41 of Set 6 : pauini
# Processing Record 42 of Set 6 : kutoarjo
# Processing Record 43 of Set 6 : padang
# Processing Record 44 of Set 6 : catamarca
# Processing Record 45 of Set 6 : kununurra
# Processing Record 46 of Set 6 : evensk
# City not found. Skipping...
# Processing Record 47 of Set 6 : zwedru
# Processing Record 48 of Set 6 : palauig
# Processing Record 49 of Set 6 : narrabri
# Processing Record 50 of Set 6 : la ronge
# Processing Record 0 of Set 7 : bonthe
# Processing Record 1 of Set 7 : hamilton
# Processing Record 2 of Set 7 : kruisfontein
# Processing Record 3 of Set 7 : kresttsy
# Processing Record 4 of Set 7 : kitsuki
# Processing Record 5 of Set 7 : iracoubo
# Processing Record 6 of Set 7 : bodmin
# Processing Record 7 of Set 7 : iglesias
# Processing Record 8 of Set 7 : vilcun
# Processing Record 9 of Set 7 : hobyo
# Processing Record 10 of Set 7 : millington
# City not found. Skipping...
# Processing Record 11 of Set 7 : leshukonskoye
# Processing Record 12 of Set 7 : scarborough
# Processing Record 13 of Set 7 : puerto escondido
# Processing Record 14 of Set 7 : papara
# Processing Record 15 of Set 7 : tura
# Processing Record 16 of Set 7 : ginda
# Processing Record 17 of Set 7 : xining
# Processing Record 18 of Set 7 : brae
# City not found. Skipping...
# Processing Record 19 of Set 7 : faya
# Processing Record 20 of Set 7 : bondo
# Processing Record 21 of Set 7 : saskylakh
# Processing Record 22 of Set 7 : muravlenko
# Processing Record 23 of Set 7 : maykor
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 7 : lokosovo
# Processing Record 25 of Set 7 : saint-francois
# Processing Record 26 of Set 7 : corund
# Processing Record 27 of Set 7 : ponta delgada
# Processing Record 28 of Set 7 : verkh-usugli
# Processing Record 29 of Set 7 : council bluffs
# Processing Record 30 of Set 7 : madanapalle
# Processing Record 31 of Set 7 : khani
# Processing Record 32 of Set 7 : daudnagar
# Processing Record 33 of Set 7 : sept-iles
# Processing Record 34 of Set 7 : vicuna
# Processing Record 35 of Set 7 : sinnamary
# Processing Record 36 of Set 7 : neftcala
# City not found. Skipping...
# Processing Record 37 of Set 7 : palu
# Processing Record 38 of Set 7 : dawson creek
# Processing Record 39 of Set 7 : talakan
# Processing Record 40 of Set 7 : aykhal
# Processing Record 41 of Set 7 : kudowa-zdroj
# Processing Record 42 of Set 7 : salisbury
# Processing Record 43 of Set 7 : warora
# City not found. Skipping...
# Processing Record 44 of Set 7 : severo-kurilsk
# Processing Record 45 of Set 7 : linxia
# Processing Record 46 of Set 7 : bandraboua
# Processing Record 47 of Set 7 : lander
# Processing Record 48 of Set 7 : omagh
# Processing Record 49 of Set 7 : zambezi
# City not found. Skipping...
# Processing Record 50 of Set 7 : fenoarivo
# Processing Record 0 of Set 8 : nyurba
# Processing Record 1 of Set 8 : plettenberg bay
# Processing Record 2 of Set 8 : roald
# Processing Record 3 of Set 8 : assiniboia
# Processing Record 4 of Set 8 : margate
# Processing Record 5 of Set 8 : paamiut
# Processing Record 6 of Set 8 : mareeba
# Processing Record 7 of Set 8 : klaksvik
# Processing Record 8 of Set 8 : lorengau
# Processing Record 9 of Set 8 : seoul
# Processing Record 10 of Set 8 : neuquen
# Processing Record 11 of Set 8 : necochea
# Processing Record 12 of Set 8 : kwinana
# Processing Record 13 of Set 8 : sokolo
# Processing Record 14 of Set 8 : flinders
# Processing Record 15 of Set 8 : santa cruz
# City not found. Skipping...
# Processing Record 16 of Set 8 : carballo
# Processing Record 17 of Set 8 : bonavista
# Processing Record 18 of Set 8 : luganville
# Processing Record 19 of Set 8 : asau
# Processing Record 20 of Set 8 : sao filipe
# Processing Record 21 of Set 8 : hambantota
# City not found. Skipping...
# Processing Record 22 of Set 8 : aswan
# Processing Record 23 of Set 8 : colwyn bay
# Processing Record 24 of Set 8 : annau
# Processing Record 25 of Set 8 : iranshahr
# Processing Record 26 of Set 8 : los llanos de aridane
# Processing Record 27 of Set 8 : chiredzi
# Processing Record 28 of Set 8 : hilo
# Processing Record 29 of Set 8 : thuin
# Processing Record 30 of Set 8 : kedrovyy
# Processing Record 31 of Set 8 : warwick
# Processing Record 32 of Set 8 : visby
# Processing Record 33 of Set 8 : carutapera
# Processing Record 34 of Set 8 : burnie
# City not found. Skipping...
# Processing Record 35 of Set 8 : lamar
# Processing Record 36 of Set 8 : chumikan
# Processing Record 37 of Set 8 : kandi
# Processing Record 38 of Set 8 : rijeka
# Processing Record 39 of Set 8 : harper
# Processing Record 40 of Set 8 : terrace
# Processing Record 41 of Set 8 : opuwo
# Processing Record 42 of Set 8 : riyadh
# Processing Record 43 of Set 8 : paita
# Processing Record 44 of Set 8 : rio grande
# City not found. Skipping...
# Processing Record 45 of Set 8 : amapa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 8 : along
# Processing Record 47 of Set 8 : bluefields
# Processing Record 48 of Set 8 : ostrovnoy
# City not found. Skipping...
# Processing Record 49 of Set 8 : pailon
# Processing Record 50 of Set 8 : kaeo
# Processing Record 0 of Set 9 : severnoye
# Processing Record 1 of Set 9 : petropavlovsk-kamchatskiy
# Processing Record 2 of Set 9 : labuhan
# Processing Record 3 of Set 9 : gimli
# Processing Record 4 of Set 9 : anadyr
# Processing Record 5 of Set 9 : turayf
# City not found. Skipping...
# Processing Record 6 of Set 9 : kletskaya
# Processing Record 7 of Set 9 : hami
# Processing Record 8 of Set 9 : wlodawa
# Processing Record 9 of Set 9 : kavaratti
# City not found. Skipping...
# Processing Record 10 of Set 9 : banikoara
# Processing Record 11 of Set 9 : abha
# Processing Record 12 of Set 9 : zlobin
# Processing Record 13 of Set 9 : chenzhou
# Processing Record 14 of Set 9 : biskupiec
# Processing Record 15 of Set 9 : yaan
# Processing Record 16 of Set 9 : coquimbo
# Processing Record 17 of Set 9 : saryg-sep
# Processing Record 18 of Set 9 : lavrentiya
# Processing Record 19 of Set 9 : abu zabad
# Processing Record 20 of Set 9 : sola
# Processing Record 21 of Set 9 : key largo
# Processing Record 22 of Set 9 : alyangula
# Processing Record 23 of Set 9 : solnechnyy
# Processing Record 24 of Set 9 : amla
# Processing Record 25 of Set 9 : salalah
# Processing Record 26 of Set 9 : shaunavon
# City not found. Skipping...
# Processing Record 27 of Set 9 : bougouni
# Processing Record 28 of Set 9 : porto velho
# City not found. Skipping...
# Processing Record 29 of Set 9 : shingu
# Processing Record 30 of Set 9 : umm lajj
# Processing Record 31 of Set 9 : potosi
# Processing Record 32 of Set 9 : la libertad
# Processing Record 33 of Set 9 : cabo san lucas
# Processing Record 34 of Set 9 : wanaka
# Processing Record 35 of Set 9 : svetlogorsk
# Processing Record 36 of Set 9 : jacksonville
# Processing Record 37 of Set 9 : goma
# Processing Record 38 of Set 9 : acarau
# Processing Record 39 of Set 9 : dagda
# Processing Record 40 of Set 9 : dekar
# Processing Record 41 of Set 9 : sao gabriel da cachoeira
# Processing Record 42 of Set 9 : nishihara
# Processing Record 43 of Set 9 : redwater
# Processing Record 44 of Set 9 : sobolevo
# Processing Record 45 of Set 9 : manaus
# Processing Record 46 of Set 9 : buchanan
# Processing Record 47 of Set 9 : belomorsk
# Processing Record 48 of Set 9 : goderich
# Processing Record 49 of Set 9 : bud
# Processing Record 50 of Set 9 : saint anthony
# Processing Record 0 of Set 10 : edson
# Processing Record 1 of Set 10 : pagudpud
# Processing Record 2 of Set 10 : catabola
# Processing Record 3 of Set 10 : ratnagiri
# Processing Record 4 of Set 10 : srednekolymsk
# Processing Record 5 of Set 10 : cauquenes
# Processing Record 6 of Set 10 : bongor
# Processing Record 7 of Set 10 : novaya malykla
# Processing Record 8 of Set 10 : arman
# Processing Record 9 of Set 10 : ancud
# Processing Record 10 of Set 10 : felanitx
# Processing Record 11 of Set 10 : les cayes
# City not found. Skipping...
# Processing Record 12 of Set 10 : ocosingo
# Processing Record 13 of Set 10 : general roca
# Processing Record 14 of Set 10 : netarhat
# Processing Record 15 of Set 10 : belmonte
# Processing Record 16 of Set 10 : shubarkuduk
# Processing Record 17 of Set 10 : antofagasta
# Processing Record 18 of Set 10 : cidreira
# Processing Record 19 of Set 10 : karratha
# Processing Record 20 of Set 10 : praia
# Processing Record 21 of Set 10 : melilla
# Processing Record 22 of Set 10 : prado
# Processing Record 23 of Set 10 : loikaw
# Processing Record 24 of Set 10 : fort nelson
# Processing Record 25 of Set 10 : san luis
# Processing Record 26 of Set 10 : broken hill
# Processing Record 27 of Set 10 : winslow
# Processing Record 28 of Set 10 : port keats
# Processing Record 29 of Set 10 : neyveli
# Processing Record 30 of Set 10 : hervey bay
# Processing Record 31 of Set 10 : havoysund
# Processing Record 32 of Set 10 : uruana
# City not found. Skipping...
# Processing Record 33 of Set 10 : mezen
# Processing Record 34 of Set 10 : tallahassee
# Processing Record 35 of Set 10 : port antonio
# Processing Record 36 of Set 10 : roma
# Processing Record 37 of Set 10 : fare
# Processing Record 38 of Set 10 : saint-joseph
# City not found. Skipping...
# Processing Record 39 of Set 10 : tocopilla
# Processing Record 40 of Set 10 : wageningen
# Processing Record 41 of Set 10 : antsohihy
# Processing Record 42 of Set 10 : leningradskiy
# Processing Record 43 of Set 10 : praia da vitoria
# Processing Record 44 of Set 10 : smithers
# Processing Record 45 of Set 10 : yangambi
# Processing Record 46 of Set 10 : muisne
# Processing Record 47 of Set 10 : hirara
# Processing Record 48 of Set 10 : matara
# Processing Record 49 of Set 10 : maceio
# Processing Record 50 of Set 10 : camacha
# Processing Record 0 of Set 11 : umea
# Processing Record 1 of Set 11 : taoudenni
# Processing Record 2 of Set 11 : kyaikkami
# Processing Record 3 of Set 11 : suntar
# Processing Record 4 of Set 11 : ajdabiya
# Processing Record 5 of Set 11 : noumea
# Processing Record 6 of Set 11 : taksimo
# Processing Record 7 of Set 11 : nuevo progreso
# Processing Record 8 of Set 11 : tumen
# Processing Record 9 of Set 11 : muros
# Processing Record 10 of Set 11 : vila
# Processing Record 11 of Set 11 : verkhnyaya inta
# Processing Record 12 of Set 11 : khowst
# Processing Record 13 of Set 11 : weston
# Processing Record 14 of Set 11 : kharakvasla
# Processing Record 15 of Set 11 : dzhebariki-khaya
# Processing Record 16 of Set 11 : aasiaat
# Processing Record 17 of Set 11 : ouesso
# Processing Record 18 of Set 11 : poum
# Processing Record 19 of Set 11 : balsas
# Processing Record 20 of Set 11 : mahanoro
# Processing Record 21 of Set 11 : olinda
# Processing Record 22 of Set 11 : mubende
# Processing Record 23 of Set 11 : turukhansk
# Processing Record 24 of Set 11 : belaya gora
# City not found. Skipping...
# Processing Record 25 of Set 11 : otane
# Processing Record 26 of Set 11 : coihueco
# Processing Record 27 of Set 11 : mezhdurechensk
# Processing Record 28 of Set 11 : kenai
# Processing Record 29 of Set 11 : leh
# Processing Record 30 of Set 11 : bouloupari
# Processing Record 31 of Set 11 : ust-maya
# Processing Record 32 of Set 11 : portland
# Processing Record 33 of Set 11 : maroantsetra
# Processing Record 34 of Set 11 : barstow
# Processing Record 35 of Set 11 : linjiang
# Processing Record 36 of Set 11 : vostok
# Processing Record 37 of Set 11 : anito
# Processing Record 38 of Set 11 : glendive
# Processing Record 39 of Set 11 : ascension
# Processing Record 40 of Set 11 : bluefield
# Processing Record 41 of Set 11 : kemise
# Processing Record 42 of Set 11 : chapais
# Processing Record 43 of Set 11 : batagay
# Processing Record 44 of Set 11 : vilyuysk
# Processing Record 45 of Set 11 : lingao
# Processing Record 46 of Set 11 : jalor
# Processing Record 47 of Set 11 : pemba
# Processing Record 48 of Set 11 : okhotsk
# Processing Record 49 of Set 11 : stalpeni
# Processing Record 50 of Set 11 : gryfino
# Processing Record 0 of Set 12 : bilibino
# Processing Record 1 of Set 12 : liverpool
# Processing Record 2 of Set 12 : high level
# Processing Record 3 of Set 12 : ridgecrest
# Processing Record 4 of Set 12 : avera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Put the data into a dataframe
city_data_df = pd.DataFrame({
    "City": city_names,
    "Lat": lat,
    "Lng": long,
    "Max Temp": maxtemp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
})

# Display the DataFrame
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Kavieng  -2.5744  150.7967     84.20        77          97       13.38
# 1      College  64.8569 -147.8028     55.40        50          75        1.30
# 2  Port Alfred -33.5906   26.8910     61.27        83         100       16.40
# 3        Bluff -46.6000  168.3333     46.99        78          15        1.99
# 4   Bredasdorp -34.5322   20.0403     53.60        82          28        8.05
#
#   Country        Date
# 0      PG  05-16-2021
# 1      US  05-16-2021
# 2      ZA  05-16-2021
# 3      NZ  05-16-2021
# 4      ZA  05-16-2021

# %%
# How many entries were returned?
city_data_df.count()
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# Country       564
# Date          564
# dtype: int64

# %%
# Inspect the data by using the describe function
city_data_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  564.000000  564.000000  564.000000  564.000000  564.000000  564.000000
# mean    21.666008   18.455769   64.628972   67.143617   56.363475    7.787004
# std     33.395485   92.202345   17.525337   24.243560   39.766201    5.285607
# min    -54.800000 -175.200000    1.400000    1.000000    0.000000    0.690000
# 25%     -6.312525  -65.761125   52.712500   51.000000   15.750000    3.837500
# 50%     27.191750   21.603000   66.035000   73.000000   75.000000    6.850000
# 75%     50.322400  101.789275   78.220000   87.000000   97.000000   10.360000
# max     78.218600  179.316700  105.800000  100.000000  100.000000   34.290000

# %%
# Export the city data into a csv file
city_data_df.to_csv("../output_data/city_data.csv", index=False)

# %%
# Show Record Count
countforme = len(city_data_df)
countforme
# Out:
# 564

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Calculate latest date (max) for plot titles
tstamp = city_data_df.Date.max()
tstamp
# Out:
# '05-16-2021'

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude")

plt.savefig("../images/tempvlat.png")

# As latitude approaches 0, i.e. the equator, temperature increases

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Humidity (%) vs Latitude")

plt.savefig("../images/humvlat.png")

# There seems to be no relationship between humidity and latitude

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Cloudiness (%) vs Latitude")

plt.savefig("../images/cloudvlat.png")

# There seems to be no relationship between cloudiness and latitude

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Wind Speed (mph) vs Latitude")

plt.savefig("../images/windvlat.png")

# There seems to be no relationship between wind speed and latitude

# %% [markdown]
# ## Linear Regression

# %%
# Locate cities above or equal to 0 latitude and below 0 latitude
northern_cities = city_data_df[city_data_df.loc[:, "Lat"] >= 0]
southern_cities = city_data_df[city_data_df.loc[:, "Lat"] < 0]

# %%
# Create Northern and Southern Hemisphere DataFrames
northlat_df = city_data_df.loc[city_data_df["Lat"] >= 0,:]
southlat_df = city_data_df.loc[city_data_df["Lat"] < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot Temperature (°F) vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Max Temp"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(10,10),fontsize=12,color="black")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/tempvlatnh.png")

# %%
print("The high r value indicates a strong positive correlation between latitude and max temperature.")
# Out:
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot Temperature (°F) vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Max Temp"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-53,81),fontsize=12,color="black")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/tempvlatsh.png")

# %%
print("The high r value indicates a strong positive correlation between latitude and max temperature.")
# Out:
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot Humidity vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Humidity"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(52,10),fontsize=12,color="black")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/northernhumvlat.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot Humidity vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Humidity"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-55,25),fontsize=12,color="black")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/sourthernhumvlat.png")

# %%
print("The low r values indicate a weak to no relationship between humidity and latitude.")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot Cloudiness vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Cloudiness"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(50,10),fontsize=12,color="black")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/northerncloudvlat.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot Humidity vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Humidity"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-55,25),fontsize=12,color="black")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig('southerncloudvlat')

print("The low r values indicate a weak positive relationship between latitude and cloudiness.")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Lat"]
y_values = northlat_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('northernwindvlat')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Lat"]
y_values = southlat_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('southernwindvlat')

print("The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.")
      °

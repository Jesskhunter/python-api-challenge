# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import json
import requests
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import datetime
from scipy.stats import linregress

# Import API key
from api_key import weather_api_key

# Incorporate citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/city_data.csv"

# Range of latitude and longitude
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Create a base url
base_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# Counters
city_counter = 1
set_counter = 1

# Create the lists we will need to append to for the dataframe
city_names = []
lat = []
long = []
maxtemp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

print("Beginning Data Retrieval")
print("-----------------------------")

# Create a query url for each city in the cities list to get json response
for i, city in enumerate(cities):
    
    # Group cities as sets of 50s
    if (i % 50 == 0 and i >= 50):
        set_counter += 1
        city_counter = 1
         
    # Create API url for each city
    query_url = base_url +"&q=" + city
    
    # Get json respose for each city
    response = requests.get(query_url).json()
    
    # Print the results 
    print(f"Processing Record {city_counter} of Set {set_counter} | {city}")
    
    # Increase record count for next loop
    city_counter += 1
    
   # Add the values to the lists
    try:       
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        maxtemp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        city_names.append(response["name"])
    except:
        print("City not found. Skipping...")
        pass
       
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | clyde river
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | homer
# Processing Record 7 of Set 1 | carmen
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | mount gambier
# Processing Record 11 of Set 1 | malaya vishera
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | sorland
# Processing Record 14 of Set 1 | vilhena
# Processing Record 15 of Set 1 | miranda
# Processing Record 16 of Set 1 | kualakapuas
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | pak phanang
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | saint george
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | lorengau
# Processing Record 26 of Set 1 | juneau
# Processing Record 27 of Set 1 | paramonga
# Processing Record 28 of Set 1 | nancha
# Processing Record 29 of Set 1 | tabuk
# Processing Record 30 of Set 1 | paamiut
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | kapuskasing
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | avera
# Processing Record 40 of Set 1 | grindavik
# Processing Record 41 of Set 1 | pochutla
# Processing Record 42 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | ketchikan
# Processing Record 45 of Set 1 | vetralla
# Processing Record 46 of Set 1 | nago
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | upernavik
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | cockburn town
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | woodward
# Processing Record 6 of Set 2 | siverek
# Processing Record 7 of Set 2 | newport
# Processing Record 8 of Set 2 | gondar
# Processing Record 9 of Set 2 | portland
# Processing Record 10 of Set 2 | nishihara
# Processing Record 11 of Set 2 | qaqortoq
# Processing Record 12 of Set 2 | we
# City not found. Skipping...
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | dawson creek
# Processing Record 15 of Set 2 | ilebo
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | santander jimenez
# Processing Record 19 of Set 2 | ahipara
# Processing Record 20 of Set 2 | kaitangata
# Processing Record 21 of Set 2 | agha jari
# City not found. Skipping...
# Processing Record 22 of Set 2 | saint-francois
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | hilo
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | dingle
# Processing Record 28 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 2 | mareeba
# Processing Record 30 of Set 2 | baker city
# Processing Record 31 of Set 2 | neiafu
# Processing Record 32 of Set 2 | doha
# Processing Record 33 of Set 2 | merritt
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | atka
# City not found. Skipping...
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | deputatskiy
# Processing Record 38 of Set 2 | sarangani
# Processing Record 39 of Set 2 | umm kaddadah
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | maceio
# Processing Record 42 of Set 2 | college
# Processing Record 43 of Set 2 | alyangula
# Processing Record 44 of Set 2 | bud
# Processing Record 45 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | faya
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | pangody
# Processing Record 49 of Set 2 | qaanaaq
# Processing Record 50 of Set 2 | prosvet
# Processing Record 1 of Set 3 | geraldton
# Processing Record 2 of Set 3 | iranshahr
# Processing Record 3 of Set 3 | husavik
# Processing Record 4 of Set 3 | coquimbo
# Processing Record 5 of Set 3 | dalbandin
# Processing Record 6 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 3 | ust-kuyga
# Processing Record 9 of Set 3 | ponta do sol
# Processing Record 10 of Set 3 | ixtapa
# Processing Record 11 of Set 3 | lompoc
# Processing Record 12 of Set 3 | boone
# Processing Record 13 of Set 3 | harper
# Processing Record 14 of Set 3 | allapalli
# Processing Record 15 of Set 3 | ilulissat
# Processing Record 16 of Set 3 | salalah
# Processing Record 17 of Set 3 | busselton
# Processing Record 18 of Set 3 | bukama
# Processing Record 19 of Set 3 | kollo
# Processing Record 20 of Set 3 | tilichiki
# Processing Record 21 of Set 3 | elko
# Processing Record 22 of Set 3 | victoria
# Processing Record 23 of Set 3 | mahebourg
# Processing Record 24 of Set 3 | harer
# Processing Record 25 of Set 3 | jibuti
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | dhemaji
# Processing Record 28 of Set 3 | qiongshan
# Processing Record 29 of Set 3 | nortelandia
# Processing Record 30 of Set 3 | radnevo
# Processing Record 31 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 3 | haapiti
# Processing Record 33 of Set 3 | dogondoutchi
# Processing Record 34 of Set 3 | narsaq
# Processing Record 35 of Set 3 | saint quentin
# City not found. Skipping...
# Processing Record 36 of Set 3 | bredasdorp
# Processing Record 37 of Set 3 | deep river
# Processing Record 38 of Set 3 | ancud
# Processing Record 39 of Set 3 | nizhniy kuranakh
# Processing Record 40 of Set 3 | butaritari
# Processing Record 41 of Set 3 | esperance
# Processing Record 42 of Set 3 | coahuayana
# Processing Record 43 of Set 3 | port hedland
# Processing Record 44 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 3 | farah
# Processing Record 46 of Set 3 | torbay
# Processing Record 47 of Set 3 | kununurra
# Processing Record 48 of Set 3 | saskylakh
# Processing Record 49 of Set 3 | vallenar
# Processing Record 50 of Set 3 | tura
# Processing Record 1 of Set 4 | kahului
# Processing Record 2 of Set 4 | codrington
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | talnakh
# Processing Record 5 of Set 4 | les ponts-de-ce
# Processing Record 6 of Set 4 | marzuq
# Processing Record 7 of Set 4 | lappeenranta
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | bellmead
# Processing Record 10 of Set 4 | batemans bay
# Processing Record 11 of Set 4 | sao jose da coroa grande
# Processing Record 12 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 13 of Set 4 | tolaga bay
# Processing Record 14 of Set 4 | mozirje
# Processing Record 15 of Set 4 | mar del plata
# Processing Record 16 of Set 4 | pingliang
# Processing Record 17 of Set 4 | camana
# Processing Record 18 of Set 4 | gainesville
# Processing Record 19 of Set 4 | iskateley
# Processing Record 20 of Set 4 | atambua
# Processing Record 21 of Set 4 | isla mujeres
# Processing Record 22 of Set 4 | havre-saint-pierre
# Processing Record 23 of Set 4 | olafsvik
# Processing Record 24 of Set 4 | flin flon
# Processing Record 25 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 4 | ostrovnoy
# Processing Record 27 of Set 4 | banda aceh
# Processing Record 28 of Set 4 | santa rosa
# Processing Record 29 of Set 4 | padang
# Processing Record 30 of Set 4 | mattru
# Processing Record 31 of Set 4 | santa maria
# Processing Record 32 of Set 4 | westport
# Processing Record 33 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 4 | barcelos
# Processing Record 35 of Set 4 | tuatapere
# Processing Record 36 of Set 4 | bereda
# Processing Record 37 of Set 4 | luderitz
# Processing Record 38 of Set 4 | paducah
# Processing Record 39 of Set 4 | carnarvon
# Processing Record 40 of Set 4 | belaya gora
# Processing Record 41 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 4 | inuvik
# Processing Record 43 of Set 4 | hay river
# Processing Record 44 of Set 4 | manjacaze
# Processing Record 45 of Set 4 | tiksi
# Processing Record 46 of Set 4 | aklavik
# Processing Record 47 of Set 4 | sao joao da barra
# Processing Record 48 of Set 4 | bathsheba
# Processing Record 49 of Set 4 | marfino
# Processing Record 50 of Set 4 | sabang
# Processing Record 1 of Set 5 | touros
# Processing Record 2 of Set 5 | carutapera
# Processing Record 3 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 5 | fredericksburg
# Processing Record 5 of Set 5 | pacific grove
# Processing Record 6 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 7 of Set 5 | chemax
# Processing Record 8 of Set 5 | cidreira
# Processing Record 9 of Set 5 | ternate
# Processing Record 10 of Set 5 | alofi
# Processing Record 11 of Set 5 | port macquarie
# Processing Record 12 of Set 5 | cotonou
# Processing Record 13 of Set 5 | airai
# Processing Record 14 of Set 5 | vanimo
# Processing Record 15 of Set 5 | kon tum
# Processing Record 16 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 5 | hami
# Processing Record 18 of Set 5 | new norfolk
# Processing Record 19 of Set 5 | pisco
# Processing Record 20 of Set 5 | lagoa
# Processing Record 21 of Set 5 | mersing
# Processing Record 22 of Set 5 | akdepe
# Processing Record 23 of Set 5 | vila franca do campo
# Processing Record 24 of Set 5 | cherskiy
# Processing Record 25 of Set 5 | tasiilaq
# Processing Record 26 of Set 5 | san matias
# Processing Record 27 of Set 5 | davila
# Processing Record 28 of Set 5 | gushikawa
# Processing Record 29 of Set 5 | thompson
# Processing Record 30 of Set 5 | lata
# Processing Record 31 of Set 5 | namatanai
# Processing Record 32 of Set 5 | acapulco
# Processing Record 33 of Set 5 | ca mau
# Processing Record 34 of Set 5 | santiago del estero
# Processing Record 35 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 5 | kirakira
# Processing Record 37 of Set 5 | el fuerte
# Processing Record 38 of Set 5 | farmington
# Processing Record 39 of Set 5 | guerrero negro
# Processing Record 40 of Set 5 | nzega
# Processing Record 41 of Set 5 | kleck
# City not found. Skipping...
# Processing Record 42 of Set 5 | ucluelet
# Processing Record 43 of Set 5 | hasaki
# Processing Record 44 of Set 5 | nyrob
# Processing Record 45 of Set 5 | lebu
# Processing Record 46 of Set 5 | san patricio
# Processing Record 47 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 5 | shelburne
# Processing Record 49 of Set 5 | leningradskiy
# Processing Record 50 of Set 5 | faanui
# Processing Record 1 of Set 6 | saldanha
# Processing Record 2 of Set 6 | tarakan
# Processing Record 3 of Set 6 | san quintin
# Processing Record 4 of Set 6 | sao filipe
# Processing Record 5 of Set 6 | ambilobe
# Processing Record 6 of Set 6 | gelemso
# Processing Record 7 of Set 6 | samarai
# Processing Record 8 of Set 6 | wukari
# Processing Record 9 of Set 6 | northam
# Processing Record 10 of Set 6 | bengkulu
# Processing Record 11 of Set 6 | rio gallegos
# Processing Record 12 of Set 6 | prainha
# Processing Record 13 of Set 6 | horsham
# Processing Record 14 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 15 of Set 6 | mabaruma
# Processing Record 16 of Set 6 | belmonte
# Processing Record 17 of Set 6 | fairbanks
# Processing Record 18 of Set 6 | green river
# Processing Record 19 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 6 | filadelfia
# Processing Record 21 of Set 6 | romanovka
# Processing Record 22 of Set 6 | sechura
# Processing Record 23 of Set 6 | pangnirtung
# Processing Record 24 of Set 6 | sibolga
# Processing Record 25 of Set 6 | terra santa
# Processing Record 26 of Set 6 | linda
# Processing Record 27 of Set 6 | tsentralnyy
# City not found. Skipping...
# Processing Record 28 of Set 6 | axim
# Processing Record 29 of Set 6 | eenhana
# Processing Record 30 of Set 6 | karabuk
# Processing Record 31 of Set 6 | kargil
# Processing Record 32 of Set 6 | zabaykalsk
# Processing Record 33 of Set 6 | svetlogorsk
# Processing Record 34 of Set 6 | katsuura
# Processing Record 35 of Set 6 | devils lake
# Processing Record 36 of Set 6 | pemberton
# Processing Record 37 of Set 6 | fougamou
# Processing Record 38 of Set 6 | along
# Processing Record 39 of Set 6 | tuktoyaktuk
# Processing Record 40 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 6 | tooele
# Processing Record 42 of Set 6 | port keats
# Processing Record 43 of Set 6 | raudeberg
# Processing Record 44 of Set 6 | karratha
# Processing Record 45 of Set 6 | emirdag
# Processing Record 46 of Set 6 | wasilla
# Processing Record 47 of Set 6 | san lawrenz
# Processing Record 48 of Set 6 | xaxim
# Processing Record 49 of Set 6 | izumo
# Processing Record 50 of Set 6 | taiyuan
# Processing Record 1 of Set 7 | bathurst
# Processing Record 2 of Set 7 | laguna
# Processing Record 3 of Set 7 | lasa
# Processing Record 4 of Set 7 | kenai
# Processing Record 5 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 7 | wanning
# Processing Record 7 of Set 7 | nassau
# Processing Record 8 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 7 | jacareacanga
# Processing Record 10 of Set 7 | altay
# Processing Record 11 of Set 7 | port hardy
# Processing Record 12 of Set 7 | havoysund
# Processing Record 13 of Set 7 | senneterre
# Processing Record 14 of Set 7 | tartagal
# Processing Record 15 of Set 7 | iquitos
# Processing Record 16 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 17 of Set 7 | wattegama
# Processing Record 18 of Set 7 | beyneu
# Processing Record 19 of Set 7 | sakakah
# Processing Record 20 of Set 7 | chapais
# Processing Record 21 of Set 7 | foix
# Processing Record 22 of Set 7 | bagdarin
# Processing Record 23 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 7 | golden rock
# City not found. Skipping...
# Processing Record 25 of Set 7 | staryy nadym
# Processing Record 26 of Set 7 | murgab
# Processing Record 27 of Set 7 | coihaique
# Processing Record 28 of Set 7 | rawson
# Processing Record 29 of Set 7 | sistranda
# Processing Record 30 of Set 7 | sinnamary
# Processing Record 31 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 7 | nanortalik
# Processing Record 33 of Set 7 | bontang
# Processing Record 34 of Set 7 | kavaratti
# Processing Record 35 of Set 7 | tono
# Processing Record 36 of Set 7 | waipawa
# Processing Record 37 of Set 7 | rockland
# Processing Record 38 of Set 7 | mattoon
# Processing Record 39 of Set 7 | broken hill
# Processing Record 40 of Set 7 | lakes entrance
# Processing Record 41 of Set 7 | east hampton
# Processing Record 42 of Set 7 | fort nelson
# Processing Record 43 of Set 7 | berlevag
# Processing Record 44 of Set 7 | tairua
# Processing Record 45 of Set 7 | vershino-darasunskiy
# Processing Record 46 of Set 7 | cabo san lucas
# Processing Record 47 of Set 7 | te anau
# Processing Record 48 of Set 7 | bairiki
# Processing Record 49 of Set 7 | muros
# Processing Record 50 of Set 7 | octeville
# Processing Record 1 of Set 8 | dera ghazi khan
# Processing Record 2 of Set 8 | kieta
# Processing Record 3 of Set 8 | oranjestad
# Processing Record 4 of Set 8 | isangel
# Processing Record 5 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 7 of Set 8 | great falls
# Processing Record 8 of Set 8 | puerto carreno
# Processing Record 9 of Set 8 | constantine
# Processing Record 10 of Set 8 | sitka
# Processing Record 11 of Set 8 | teya
# Processing Record 12 of Set 8 | kattivakkam
# Processing Record 13 of Set 8 | almeirim
# Processing Record 14 of Set 8 | flinders
# Processing Record 15 of Set 8 | kruisfontein
# Processing Record 16 of Set 8 | ukiah
# Processing Record 17 of Set 8 | cam ranh
# Processing Record 18 of Set 8 | malaya serdoba
# Processing Record 19 of Set 8 | wewak
# Processing Record 20 of Set 8 | calbuco
# Processing Record 21 of Set 8 | touzim
# Processing Record 22 of Set 8 | chota
# Processing Record 23 of Set 8 | montevideo
# Processing Record 24 of Set 8 | ambulu
# Processing Record 25 of Set 8 | port lincoln
# Processing Record 26 of Set 8 | abhar
# Processing Record 27 of Set 8 | suba
# Processing Record 28 of Set 8 | victor harbor
# Processing Record 29 of Set 8 | itoman
# Processing Record 30 of Set 8 | weligama
# Processing Record 31 of Set 8 | tiznit
# Processing Record 32 of Set 8 | paita
# Processing Record 33 of Set 8 | nakamura
# Processing Record 34 of Set 8 | queanbeyan
# Processing Record 35 of Set 8 | biak
# Processing Record 36 of Set 8 | palmeira das missoes
# Processing Record 37 of Set 8 | balikpapan
# Processing Record 38 of Set 8 | palmer
# Processing Record 39 of Set 8 | kibala
# Processing Record 40 of Set 8 | spirovo
# Processing Record 41 of Set 8 | dayong
# Processing Record 42 of Set 8 | selenginsk
# Processing Record 43 of Set 8 | marihatag
# Processing Record 44 of Set 8 | am timan
# Processing Record 45 of Set 8 | bambous virieux
# Processing Record 46 of Set 8 | korla
# Processing Record 47 of Set 8 | illapel
# Processing Record 48 of Set 8 | red wing
# Processing Record 49 of Set 8 | shimoda
# Processing Record 50 of Set 8 | abu zabad
# Processing Record 1 of Set 9 | muncie
# Processing Record 2 of Set 9 | seoul
# Processing Record 3 of Set 9 | constitucion
# Processing Record 4 of Set 9 | dubreka
# Processing Record 5 of Set 9 | hualmay
# Processing Record 6 of Set 9 | mwense
# Processing Record 7 of Set 9 | mingguang
# Processing Record 8 of Set 9 | kyra
# Processing Record 9 of Set 9 | bandarbeyla
# Processing Record 10 of Set 9 | talin
# Processing Record 11 of Set 9 | prata
# Processing Record 12 of Set 9 | saint-augustin
# Processing Record 13 of Set 9 | mayo
# Processing Record 14 of Set 9 | vila velha
# Processing Record 15 of Set 9 | vardo
# Processing Record 16 of Set 9 | takaka
# Processing Record 17 of Set 9 | cabra
# Processing Record 18 of Set 9 | predivinsk
# Processing Record 19 of Set 9 | baykit
# Processing Record 20 of Set 9 | tucupita
# Processing Record 21 of Set 9 | vicksburg
# Processing Record 22 of Set 9 | christchurch
# Processing Record 23 of Set 9 | molchanovo
# Processing Record 24 of Set 9 | rantepao
# Processing Record 25 of Set 9 | phalombe
# Processing Record 26 of Set 9 | wageningen
# Processing Record 27 of Set 9 | russell
# Processing Record 28 of Set 9 | inongo
# Processing Record 29 of Set 9 | evensk
# Processing Record 30 of Set 9 | beloha
# Processing Record 31 of Set 9 | visby
# Processing Record 32 of Set 9 | huntington
# Processing Record 33 of Set 9 | colares
# Processing Record 34 of Set 9 | alberton
# Processing Record 35 of Set 9 | berlin
# Processing Record 36 of Set 9 | caravelas
# Processing Record 37 of Set 9 | sibu
# Processing Record 38 of Set 9 | sembakung
# Processing Record 39 of Set 9 | matara
# Processing Record 40 of Set 9 | chuy
# Processing Record 41 of Set 9 | bambanglipuro
# Processing Record 42 of Set 9 | kavieng
# Processing Record 43 of Set 9 | gazojak
# Processing Record 44 of Set 9 | pevek
# Processing Record 45 of Set 9 | nikolayevka
# Processing Record 46 of Set 9 | makakilo city
# Processing Record 47 of Set 9 | cienfuegos
# Processing Record 48 of Set 9 | eyl
# Processing Record 49 of Set 9 | mount isa
# Processing Record 50 of Set 9 | batagay-alyta
# Processing Record 1 of Set 10 | norman wells
# Processing Record 2 of Set 10 | ambon
# Processing Record 3 of Set 10 | mopti
# Processing Record 4 of Set 10 | chissamba
# Processing Record 5 of Set 10 | kijang
# Processing Record 6 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 8 of Set 10 | sanchor
# Processing Record 9 of Set 10 | clarksburg
# Processing Record 10 of Set 10 | kyren
# Processing Record 11 of Set 10 | pandan
# Processing Record 12 of Set 10 | phangnga
# Processing Record 13 of Set 10 | natchez
# Processing Record 14 of Set 10 | abdulino
# Processing Record 15 of Set 10 | san policarpo
# Processing Record 16 of Set 10 | miraflores
# Processing Record 17 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 10 | santa fe do sul
# Processing Record 19 of Set 10 | nioro
# Processing Record 20 of Set 10 | celestun
# Processing Record 21 of Set 10 | werda
# Processing Record 22 of Set 10 | bundaberg
# Processing Record 23 of Set 10 | atar
# Processing Record 24 of Set 10 | lavrentiya
# Processing Record 25 of Set 10 | sao jose do belmonte
# Processing Record 26 of Set 10 | yongan
# Processing Record 27 of Set 10 | uspenka
# Processing Record 28 of Set 10 | barra do bugres
# Processing Record 29 of Set 10 | mahon
# Processing Record 30 of Set 10 | omboue
# Processing Record 31 of Set 10 | saint-pierre
# Processing Record 32 of Set 10 | anadyr
# Processing Record 33 of Set 10 | mecca
# Processing Record 34 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 10 | nome
# Processing Record 36 of Set 10 | ylivieska
# Processing Record 37 of Set 10 | lithakia
# Processing Record 38 of Set 10 | ferrol
# Processing Record 39 of Set 10 | fjerritslev
# Processing Record 40 of Set 10 | gorom-gorom
# Processing Record 41 of Set 10 | lexington
# Processing Record 42 of Set 10 | payo
# Processing Record 43 of Set 10 | swakopmund
# Processing Record 44 of Set 10 | praia da vitoria
# Processing Record 45 of Set 10 | daru
# Processing Record 46 of Set 10 | olivet
# Processing Record 47 of Set 10 | mildura
# Processing Record 48 of Set 10 | alibag
# Processing Record 49 of Set 10 | margate
# Processing Record 50 of Set 10 | san jose
# Processing Record 1 of Set 11 | klaksvik
# Processing Record 2 of Set 11 | barra
# Processing Record 3 of Set 11 | hambantota
# Processing Record 4 of Set 11 | miles city
# Processing Record 5 of Set 11 | marsabit
# Processing Record 6 of Set 11 | hulyaypole
# Processing Record 7 of Set 11 | ryabovo
# Processing Record 8 of Set 11 | bugko
# Processing Record 9 of Set 11 | nantucket
# Processing Record 10 of Set 11 | springfield
# Processing Record 11 of Set 11 | fallon
# Processing Record 12 of Set 11 | zhezkazgan
# Processing Record 13 of Set 11 | ayan
# Processing Record 14 of Set 11 | inhambane
# Processing Record 15 of Set 11 | adre
# Processing Record 16 of Set 11 | bouca
# Processing Record 17 of Set 11 | pemangkat
# Processing Record 18 of Set 11 | tucuman
# Processing Record 19 of Set 11 | sompeta
# Processing Record 20 of Set 11 | oxford
# Processing Record 21 of Set 11 | gimli
# Processing Record 22 of Set 11 | nouadhibou
# Processing Record 23 of Set 11 | piacabucu
# Processing Record 24 of Set 11 | krathum baen
# Processing Record 25 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 11 | jaicos
# Processing Record 27 of Set 11 | lanxi
# Processing Record 28 of Set 11 | nagato
# Processing Record 29 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 30 of Set 11 | semporna
# Processing Record 31 of Set 11 | cururupu
# Processing Record 32 of Set 11 | peterongan
# Processing Record 33 of Set 11 | port blair
# Processing Record 34 of Set 11 | weston
# Processing Record 35 of Set 11 | hofn
# Processing Record 36 of Set 11 | maryborough
# Processing Record 37 of Set 11 | henties bay
# Processing Record 38 of Set 11 | vodnyy
# Processing Record 39 of Set 11 | oda
# Processing Record 40 of Set 11 | gondanglegi
# Processing Record 41 of Set 11 | lircay
# Processing Record 42 of Set 11 | loa janan
# Processing Record 43 of Set 11 | hillsboro
# Processing Record 44 of Set 11 | presidente medici
# Processing Record 45 of Set 11 | dali
# Processing Record 46 of Set 11 | ullapool
# Processing Record 47 of Set 11 | hervey bay
# Processing Record 48 of Set 11 | orumiyeh
# Processing Record 49 of Set 11 | auburn
# Processing Record 50 of Set 11 | darnah
# Processing Record 1 of Set 12 | trimbak
# Processing Record 2 of Set 12 | komsomolskiy
# Processing Record 3 of Set 12 | vestmannaeyjar
# Processing Record 4 of Set 12 | sainte-maxime
# Processing Record 5 of Set 12 | atasu
# Processing Record 6 of Set 12 | papara
# Processing Record 7 of Set 12 | masindi
# Processing Record 8 of Set 12 | senador jose porfirio
# Processing Record 9 of Set 12 | ciudad bolivar
# Processing Record 10 of Set 12 | desaguadero
# Processing Record 11 of Set 12 | dubbo
# Processing Record 12 of Set 12 | pudozh
# Processing Record 13 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 14 of Set 12 | fengrun
# Processing Record 15 of Set 12 | poum
# Processing Record 16 of Set 12 | makaryev
# Processing Record 17 of Set 12 | yulara
# Processing Record 18 of Set 12 | aksarka
# Processing Record 19 of Set 12 | vostok
# Processing Record 20 of Set 12 | san juan
# Processing Record 21 of Set 12 | eureka
# Processing Record 22 of Set 12 | katete
# Processing Record 23 of Set 12 | bose
# Processing Record 24 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 25 of Set 12 | plettenberg bay
# Processing Record 26 of Set 12 | sorong
# Processing Record 27 of Set 12 | lukulu
# Processing Record 28 of Set 12 | pringsewu
# Processing Record 29 of Set 12 | parambu
# Processing Record 30 of Set 12 | manzanillo
# Processing Record 31 of Set 12 | disna
# Processing Record 32 of Set 12 | sur
# Processing Record 33 of Set 12 | svetlaya
# Processing Record 34 of Set 12 | wiarton
# Processing Record 35 of Set 12 | galveston
# Processing Record 36 of Set 12 | makinsk
# Processing Record 37 of Set 12 | aswan
# Processing Record 38 of Set 12 | leshukonskoye
# Processing Record 39 of Set 12 | karad
# Processing Record 40 of Set 12 | santa catalina
# Processing Record 41 of Set 12 | mercedes
# Processing Record 42 of Set 12 | qasigiannguit
# Processing Record 43 of Set 12 | ulladulla
# Processing Record 44 of Set 12 | olinda
# Processing Record 45 of Set 12 | watertown
# Processing Record 46 of Set 12 | garowe
# Processing Record 47 of Set 12 | manakara
# Processing Record 48 of Set 12 | terrak
# Processing Record 49 of Set 12 | buin
# Processing Record 50 of Set 12 | verkhnyaya toyma
# Processing Record 1 of Set 13 | datong
# Processing Record 2 of Set 13 | kalmanhaza
# Processing Record 3 of Set 13 | naryan-mar
# Processing Record 4 of Set 13 | iqaluit
# Processing Record 5 of Set 13 | soyo
# Processing Record 6 of Set 13 | aitape
# Processing Record 7 of Set 13 | tabora
# Processing Record 8 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 13 | charters towers
# Processing Record 10 of Set 13 | ponta delgada
# Processing Record 11 of Set 13 | lensk
# Processing Record 12 of Set 13 | vapi
# Processing Record 13 of Set 13 | cayenne
# Processing Record 14 of Set 13 | manggar
# Processing Record 15 of Set 13 | krasnyy chikoy
# Processing Record 16 of Set 13 | boulder city
# Processing Record 17 of Set 13 | aktau
# Processing Record 18 of Set 13 | tocopilla
# Processing Record 19 of Set 13 | houma
# Processing Record 20 of Set 13 | batagay
# Processing Record 21 of Set 13 | rudsar
# Processing Record 22 of Set 13 | yar-sale
# Processing Record 23 of Set 13 | aksha
# Processing Record 24 of Set 13 | hlotse
# Processing Record 25 of Set 13 | thinadhoo
# Processing Record 26 of Set 13 | bull savanna
# Processing Record 27 of Set 13 | saint anthony
# Processing Record 28 of Set 13 | yamasaki
# Processing Record 29 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 13 | ajdabiya
# Processing Record 31 of Set 13 | kloulklubed
# Processing Record 32 of Set 13 | shache
# Processing Record 33 of Set 13 | bonavista
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Put the data into a dataframe
city_data_df = pd.DataFrame({
    "City": city_names,
    "Lat": lat,
    "Lng": long,
    "Max Temp": maxtemp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
})

# Display the DataFrame
print(city_data_df)
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0           Arraial do Cabo -22.9661  -42.0278     71.38        65
# 1                 Cape Town -33.9258   18.4232     57.00        93
# 2                  Hermanus -34.4187   19.2345     54.00        94
# 3               Clyde River  70.4692  -68.5914     19.40        93
# 4                  Khatanga  71.9667  102.5000     28.13        88
# ..                      ...      ...       ...       ...       ...
# 581  Yamazakichō-nakabirose  35.0000  134.5500     75.20        64
# 582                Ajdabiya  30.7554   20.2263     64.06        57
# 583             Kloulklubed   7.0419  134.2556     80.60        89
# 584                  Shache  38.4167   77.2406     64.94        43
# 585               Bonavista  48.6499  -53.1147     42.01        81
#
#      Cloudiness  Wind Speed Country        Date
# 0            32       11.03      BR  1620959320
# 1             0        4.61      ZA  1620959406
# 2            21        3.00      ZA  1620959518
# 3            90        9.22      CA  1620959361
# 4           100        4.94      RU  1620959444
# ..          ...         ...     ...         ...
# 581          75        6.91      JP  1620959645
# 582           3       10.78      LY  1620959645
# 583          90        6.91      PW  1620959597
# 584         100        2.28      CN  1620959646
# 585          99        5.75      CA  1620959646
#
# [586 rows x 9 columns]

# %%
# How many entries were returned?
city_data_df.count()
# Out:
# City          586
# Lat           586
# Lng           586
# Max Temp      586
# Humidity      586
# Cloudiness    586
# Wind Speed    586
# Country       586
# Date          586
# dtype: int64

# %%
# Inspect the data by using the describe function
city_data_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  586.000000  586.000000  586.000000  586.000000  586.000000  586.000000
# mean    19.566663   16.100690   64.276877   67.897611   50.090444    7.269966
# std     32.947301   93.111265   16.553301   21.259241   39.164964    4.807357
# min    -54.800000 -175.200000   17.600000    6.000000    0.000000    0.310000
# 25%     -6.215300  -68.929125   52.000000   54.000000    7.000000    3.582500
# 50%     22.110650   20.433000   64.400000   72.000000   56.500000    5.875000
# 75%     46.766750  105.106100   78.800000   84.000000   90.000000   10.360000
# max     77.484000  178.416700   95.000000  100.000000  100.000000   33.640000
#
#                Date
# count  5.860000e+02
# mean   1.620960e+09
# std    8.950225e+01
# min    1.620959e+09
# 25%    1.620960e+09
# 50%    1.620960e+09
# 75%    1.620960e+09
# max    1.620960e+09

# %%
# Export the city data into a csv file
city_data_df.to_csv("../output_data/city_data.csv", index=False)

# %%
# Show Record Count
countforme = len(city_data_df)
countforme
# Out:
# 586

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Calculate latest date (max) for plot titles
tstamp = city_data_df.Date.max()

# Convert Unix timestamp to formated date
fdate= time.strftime("%m/%d/%y",time.localtime(tstamp))
fdate
# Out:
# '05/13/21'

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude")

plt.savefig("../output_data/tempvlat.png")

# As latitude approaches 0, i.e. the equator, temperature increases

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Humidity (%) vs Latitude")

plt.savefig("../output_data/humvlat.png")

# There seems to be no relationship between humidity and latitude

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Cloudiness (%) vs Latitude")

plt.savefig("../output_data/cloudvlat.png")

# There seems to be no relationship between cloudiness and latitude

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Wind Speed (mph) vs Latitude")

plt.savefig("../output_data/windvlat.png")

# There seems to be no relationship between wind speed and latitude

# %% [markdown]
# ## Linear Regression

# %%
# Locate cities above or equal to 0 latitude and below 0 latitude
northern_cities = city_data_df[city_data_df.loc[:, "Lat"] >= 0]
southern_cities = city_data_df[city_data_df.loc[:, "Lat"] < 0]

# %%
# Create Northern and Southern Hemisphere DataFrames
northlat_df = city_data_df.loc[city_data_df["Lat"] >= 0,:]
southlat_df = city_data_df.loc[city_data_df["Lat"] < 0,:]

# %%
#Your next objective is to run linear regression on each relationship, only this time separating 
#them into Northern Hemisphere (greater than or equal to 0 degrees latitude) and 
#Southern Hemisphere (less than 0 degrees latitude):

#Northern Hemisphere - Humidity (%) vs. Latitude
#Southern Hemisphere - Humidity (%) vs. Latitude
#Northern Hemisphere - Cloudiness (%) vs. Latitude
#Southern Hemisphere - Cloudiness (%) vs. Latitude
#Northern Hemisphere - Wind Speed (mph) vs. Latitude
#Southern Hemisphere - Wind Speed (mph) vs. Latitude

#After each pair of plots explain what the linear regression is analyzing, any relationships you notice and any other analysis you may have.

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot Temperature (°F) vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Max Temp"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(10,10),fontsize=12,color="black")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../output_data/tempvlatnh.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot Temperature (F) vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Max Temp"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-53,81),fontsize=12,color="black")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig("../output_data/tempvlatsh.png")

# %%
print("The high r value indicates a strong positive correlation between latitude and max temperature.")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Lat"]
y_values = northlat_df["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('northernhumvlat')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Lat"]
y_values = southlat_df["Humidity"]
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('southernhumvlat')

print("The low r values indicate a weak to no relationship between humidity and latitude.")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Lat"]
y_values = northlat_df["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig('northerncloudvlat')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Lat"]
y_values = southlat_df["Cloudiness"]
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig('southerncloudvlat')

print("The low r values indicate a weak positive relationship between latitude and cloudiness.")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northlat_df["Lat"]
y_values = northlat_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('northernwindvlat')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southlat_df["Lat"]
y_values = southlat_df["Wind Speed"]
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig('southernwindvlat')

print("The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.")
      °

# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import json
import requests
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import datetime
from scipy.stats import linregress

# Import API key
from api_key import weather_api_key

# Incorporate citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/city_data.csv"

# Range of latitude and longitude
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %%
city_names = []
lat = []
long = []
maxtemp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
city_counter = 1
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
#         date.append(response["dt"])

print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_names.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date = datetime.datetime.fromtimestamp(int(response['dt'])).strftime('%m-%d-%Y')
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        maxtemp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        
        if city_counter > 49:
            city_counter = 0
            set_counter = set_counter + 1
    
        else:
            city_counter = city_counter + 1
            
        print(f"Processing Record {city_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 2 of Set 1 : upernavik
# Processing Record 3 of Set 1 : cape town
# Processing Record 4 of Set 1 : kenai
# Processing Record 5 of Set 1 : puerto baquerizo moreno
# Processing Record 6 of Set 1 : manjacaze
# Processing Record 7 of Set 1 : chuy
# Processing Record 8 of Set 1 : busselton
# Processing Record 9 of Set 1 : panguma
# City not found. Skipping...
# Processing Record 10 of Set 1 : bilma
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 1 : port alfred
# Processing Record 12 of Set 1 : punta arenas
# Processing Record 13 of Set 1 : hilo
# Processing Record 14 of Set 1 : mount gambier
# Processing Record 15 of Set 1 : rikitea
# Processing Record 16 of Set 1 : edgewater
# Processing Record 17 of Set 1 : forbes
# Processing Record 18 of Set 1 : christchurch
# Processing Record 19 of Set 1 : georgetown
# Processing Record 20 of Set 1 : mataura
# Processing Record 21 of Set 1 : kozelsk
# Processing Record 22 of Set 1 : valparaiso
# Processing Record 23 of Set 1 : boa vista
# Processing Record 24 of Set 1 : santarem
# Processing Record 25 of Set 1 : paamiut
# Processing Record 26 of Set 1 : rudraprayag
# Processing Record 27 of Set 1 : rossland
# Processing Record 28 of Set 1 : port elizabeth
# Processing Record 29 of Set 1 : padang
# Processing Record 30 of Set 1 : albany
# Processing Record 31 of Set 1 : rawson
# Processing Record 32 of Set 1 : garissa
# Processing Record 33 of Set 1 : avera
# Processing Record 34 of Set 1 : derzhavinsk
# Processing Record 35 of Set 1 : haines junction
# Processing Record 36 of Set 1 : alyangula
# Processing Record 37 of Set 1 : krasnyy chikoy
# Processing Record 38 of Set 1 : victoria
# Processing Record 39 of Set 1 : olafsvik
# Processing Record 40 of Set 1 : faanui
# Processing Record 41 of Set 1 : porbandar
# Processing Record 42 of Set 1 : sitka
# Processing Record 43 of Set 1 : ushuaia
# Processing Record 44 of Set 1 : bethel
# Processing Record 45 of Set 1 : novorzhev
# Processing Record 46 of Set 1 : ribeira grande
# Processing Record 47 of Set 1 : khatanga
# Processing Record 48 of Set 1 : vila franca do campo
# Processing Record 49 of Set 1 : vaini
# City not found. Skipping...
# Processing Record 50 of Set 1 : nikolskoye
# Processing Record 0 of Set 2 : yellowknife
# Processing Record 1 of Set 2 : cayenne
# Processing Record 2 of Set 2 : camacha
# Processing Record 3 of Set 2 : kaitangata
# Processing Record 4 of Set 2 : kapaa
# Processing Record 5 of Set 2 : atuona
# Processing Record 6 of Set 2 : dikson
# Processing Record 7 of Set 2 : hit
# Processing Record 8 of Set 2 : bengkulu
# Processing Record 9 of Set 2 : hermanus
# Processing Record 10 of Set 2 : plettenberg bay
# Processing Record 11 of Set 2 : foz
# Processing Record 12 of Set 2 : taltal
# Processing Record 13 of Set 2 : qaanaaq
# Processing Record 14 of Set 2 : inhambane
# Processing Record 15 of Set 2 : butaritari
# Processing Record 16 of Set 2 : arraial do cabo
# Processing Record 17 of Set 2 : cabo san lucas
# Processing Record 18 of Set 2 : pravdinskiy
# Processing Record 19 of Set 2 : saint-philippe
# Processing Record 20 of Set 2 : banikoara
# Processing Record 21 of Set 2 : hamilton
# Processing Record 22 of Set 2 : ahuimanu
# Processing Record 23 of Set 2 : alice springs
# Processing Record 24 of Set 2 : grand gaube
# Processing Record 25 of Set 2 : darnah
# Processing Record 26 of Set 2 : berlevag
# Processing Record 27 of Set 2 : mandalgovi
# Processing Record 28 of Set 2 : praya
# Processing Record 29 of Set 2 : aripuana
# Processing Record 30 of Set 2 : salinas
# Processing Record 31 of Set 2 : airai
# Processing Record 32 of Set 2 : tuktoyaktuk
# Processing Record 33 of Set 2 : hobart
# Processing Record 34 of Set 2 : bredasdorp
# Processing Record 35 of Set 2 : hukuntsi
# Processing Record 36 of Set 2 : donaueschingen
# Processing Record 37 of Set 2 : bowen
# Processing Record 38 of Set 2 : masumbwe
# Processing Record 39 of Set 2 : gusau
# Processing Record 40 of Set 2 : hofn
# Processing Record 41 of Set 2 : lake cowichan
# Processing Record 42 of Set 2 : vostok
# Processing Record 43 of Set 2 : casper
# Processing Record 44 of Set 2 : bathsheba
# Processing Record 45 of Set 2 : vestmanna
# Processing Record 46 of Set 2 : iqaluit
# Processing Record 47 of Set 2 : hualmay
# Processing Record 48 of Set 2 : tazovskiy
# Processing Record 49 of Set 2 : castro
# Processing Record 50 of Set 2 : barrow
# Processing Record 0 of Set 3 : jamestown
# Processing Record 1 of Set 3 : ler
# Processing Record 2 of Set 3 : beringovskiy
# City not found. Skipping...
# Processing Record 3 of Set 3 : pihuamo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 3 : hasaki
# Processing Record 5 of Set 3 : hithadhoo
# Processing Record 6 of Set 3 : shunyi
# Processing Record 7 of Set 3 : sola
# Processing Record 8 of Set 3 : hirara
# Processing Record 9 of Set 3 : bagdarin
# Processing Record 10 of Set 3 : saskylakh
# Processing Record 11 of Set 3 : mount isa
# Processing Record 12 of Set 3 : torrox
# Processing Record 13 of Set 3 : bambous virieux
# Processing Record 14 of Set 3 : geilo
# Processing Record 15 of Set 3 : chokurdakh
# Processing Record 16 of Set 3 : constitucion
# Processing Record 17 of Set 3 : norman wells
# City not found. Skipping...
# Processing Record 18 of Set 3 : lebu
# Processing Record 19 of Set 3 : san quintin
# Processing Record 20 of Set 3 : pacific grove
# Processing Record 21 of Set 3 : tongren
# Processing Record 22 of Set 3 : san pedro
# Processing Record 23 of Set 3 : viedma
# Processing Record 24 of Set 3 : slave lake
# Processing Record 25 of Set 3 : east london
# City not found. Skipping...
# Processing Record 26 of Set 3 : save
# Processing Record 27 of Set 3 : guerande
# Processing Record 28 of Set 3 : leningradskiy
# Processing Record 29 of Set 3 : lakes entrance
# Processing Record 30 of Set 3 : hambantota
# Processing Record 31 of Set 3 : sistranda
# Processing Record 32 of Set 3 : saldanha
# Processing Record 33 of Set 3 : saint george
# Processing Record 34 of Set 3 : asau
# Processing Record 35 of Set 3 : atar
# Processing Record 36 of Set 3 : mahebourg
# Processing Record 37 of Set 3 : pochutla
# Processing Record 38 of Set 3 : miyako
# Processing Record 39 of Set 3 : ponta do sol
# Processing Record 40 of Set 3 : ballina
# Processing Record 41 of Set 3 : esperance
# Processing Record 42 of Set 3 : mar del plata
# City not found. Skipping...
# Processing Record 43 of Set 3 : dubbo
# Processing Record 44 of Set 3 : waipawa
# Processing Record 45 of Set 3 : pringsewu
# Processing Record 46 of Set 3 : skibbereen
# Processing Record 47 of Set 3 : vila velha
# City not found. Skipping...
# Processing Record 48 of Set 3 : punta
# Processing Record 49 of Set 3 : las palmas
# Processing Record 50 of Set 3 : vina del mar
# Processing Record 0 of Set 4 : pantai remis
# Processing Record 1 of Set 4 : zhigansk
# Processing Record 2 of Set 4 : los llanos de aridane
# Processing Record 3 of Set 4 : tortoli
# Processing Record 4 of Set 4 : saint-augustin
# Processing Record 5 of Set 4 : sabancuy
# Processing Record 6 of Set 4 : nizwa
# Processing Record 7 of Set 4 : aklavik
# Processing Record 8 of Set 4 : penzance
# Processing Record 9 of Set 4 : kushmurun
# Processing Record 10 of Set 4 : tonj
# Processing Record 11 of Set 4 : payo
# City not found. Skipping...
# Processing Record 12 of Set 4 : arman
# Processing Record 13 of Set 4 : new norfolk
# Processing Record 14 of Set 4 : portland
# Processing Record 15 of Set 4 : clyde river
# Processing Record 16 of Set 4 : urumqi
# Processing Record 17 of Set 4 : malanje
# Processing Record 18 of Set 4 : kovur
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 4 : vanimo
# Processing Record 20 of Set 4 : shangzhi
# Processing Record 21 of Set 4 : moroto
# Processing Record 22 of Set 4 : sorong
# Processing Record 23 of Set 4 : xichang
# Processing Record 24 of Set 4 : roma
# Processing Record 25 of Set 4 : canutama
# Processing Record 26 of Set 4 : avarua
# Processing Record 27 of Set 4 : ola
# Processing Record 28 of Set 4 : lavrentiya
# Processing Record 29 of Set 4 : porto santo
# Processing Record 30 of Set 4 : shubarkuduk
# Processing Record 31 of Set 4 : tuatapere
# Processing Record 32 of Set 4 : doba
# Processing Record 33 of Set 4 : povenets
# Processing Record 34 of Set 4 : bonavista
# Processing Record 35 of Set 4 : berga
# Processing Record 36 of Set 4 : kirakira
# Processing Record 37 of Set 4 : guerrero negro
# Processing Record 38 of Set 4 : ambalavao
# Processing Record 39 of Set 4 : purranque
# Processing Record 40 of Set 4 : bluff
# Processing Record 41 of Set 4 : ponta delgada
# Processing Record 42 of Set 4 : beli manastir
# Processing Record 43 of Set 4 : freeport
# Processing Record 44 of Set 4 : okhotsk
# Processing Record 45 of Set 4 : cap malheureux
# Processing Record 46 of Set 4 : warsaw
# Processing Record 47 of Set 4 : soyo
# Processing Record 48 of Set 4 : severo-kurilsk
# Processing Record 49 of Set 4 : san patricio
# Processing Record 50 of Set 4 : fairbanks
# Processing Record 0 of Set 5 : sabang
# Processing Record 1 of Set 5 : thompson
# Processing Record 2 of Set 5 : san cristobal
# Processing Record 3 of Set 5 : belmonte
# City not found. Skipping...
# Processing Record 4 of Set 5 : wolnzach
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 5 : nouadhibou
# Processing Record 6 of Set 5 : kukes
# Processing Record 7 of Set 5 : kodiak
# Processing Record 8 of Set 5 : pangnirtung
# Processing Record 9 of Set 5 : talnakh
# Processing Record 10 of Set 5 : torbay
# Processing Record 11 of Set 5 : zeya
# Processing Record 12 of Set 5 : acapulco
# Processing Record 13 of Set 5 : nuuk
# City not found. Skipping...
# Processing Record 14 of Set 5 : fortuna
# City not found. Skipping...
# Processing Record 15 of Set 5 : auka
# Processing Record 16 of Set 5 : nyimba
# City not found. Skipping...
# Processing Record 17 of Set 5 : sao joao da barra
# Processing Record 18 of Set 5 : saint anthony
# Processing Record 19 of Set 5 : muriwai beach
# Processing Record 20 of Set 5 : khvoynaya
# Processing Record 21 of Set 5 : igarka
# Processing Record 22 of Set 5 : carnarvon
# Processing Record 23 of Set 5 : mayo
# Processing Record 24 of Set 5 : skjervoy
# Processing Record 25 of Set 5 : katsuura
# Processing Record 26 of Set 5 : cockburn town
# Processing Record 27 of Set 5 : meadow lake
# Processing Record 28 of Set 5 : la ronge
# Processing Record 29 of Set 5 : ulladulla
# Processing Record 30 of Set 5 : rafai
# Processing Record 31 of Set 5 : teluk nibung
# Processing Record 32 of Set 5 : arcata
# Processing Record 33 of Set 5 : sungai besar
# Processing Record 34 of Set 5 : high level
# Processing Record 35 of Set 5 : tambacounda
# Processing Record 36 of Set 5 : pevek
# Processing Record 37 of Set 5 : cidreira
# Processing Record 38 of Set 5 : manggar
# Processing Record 39 of Set 5 : brae
# Processing Record 40 of Set 5 : tasiilaq
# Processing Record 41 of Set 5 : vanavara
# Processing Record 42 of Set 5 : mana
# City not found. Skipping...
# Processing Record 43 of Set 5 : hastings
# Processing Record 44 of Set 5 : saint-raymond
# Processing Record 45 of Set 5 : omsukchan
# Processing Record 46 of Set 5 : awjilah
# Processing Record 47 of Set 5 : griffith
# Processing Record 48 of Set 5 : mackay
# Processing Record 49 of Set 5 : voh
# Processing Record 50 of Set 5 : muskegon
# Processing Record 0 of Set 6 : cuiluan
# City not found. Skipping...
# Processing Record 1 of Set 6 : lufilufi
# Processing Record 2 of Set 6 : palmer
# Processing Record 3 of Set 6 : port lincoln
# City not found. Skipping...
# Processing Record 4 of Set 6 : sobolevo
# Processing Record 5 of Set 6 : benghazi
# Processing Record 6 of Set 6 : tarko-sale
# Processing Record 7 of Set 6 : pangai
# Processing Record 8 of Set 6 : humberto de campos
# Processing Record 9 of Set 6 : hutchinson
# City not found. Skipping...
# Processing Record 10 of Set 6 : amboasary
# Processing Record 11 of Set 6 : shingu
# Processing Record 12 of Set 6 : klaksvik
# Processing Record 13 of Set 6 : harper
# Processing Record 14 of Set 6 : sibolga
# Processing Record 15 of Set 6 : rockhampton
# Processing Record 16 of Set 6 : batemans bay
# Processing Record 17 of Set 6 : mazamet
# City not found. Skipping...
# Processing Record 18 of Set 6 : tiarei
# Processing Record 19 of Set 6 : cabedelo
# Processing Record 20 of Set 6 : iracoubo
# Processing Record 21 of Set 6 : nantucket
# Processing Record 22 of Set 6 : neiafu
# Processing Record 23 of Set 6 : katangli
# Processing Record 24 of Set 6 : pisco
# Processing Record 25 of Set 6 : wanning
# Processing Record 26 of Set 6 : ixtapa
# Processing Record 27 of Set 6 : imeni poliny osipenko
# Processing Record 28 of Set 6 : korla
# Processing Record 29 of Set 6 : ende
# Processing Record 30 of Set 6 : saucillo
# Processing Record 31 of Set 6 : svetlogorsk
# Processing Record 32 of Set 6 : poum
# Processing Record 33 of Set 6 : kankon
# Processing Record 34 of Set 6 : cam ranh
# Processing Record 35 of Set 6 : orikhove
# Processing Record 36 of Set 6 : oranjemund
# Processing Record 37 of Set 6 : kantunilkin
# Processing Record 38 of Set 6 : baoshan
# Processing Record 39 of Set 6 : chaozhou
# Processing Record 40 of Set 6 : ostrovnoy
# Processing Record 41 of Set 6 : luanda
# Processing Record 42 of Set 6 : husavik
# Processing Record 43 of Set 6 : berezovyy
# Processing Record 44 of Set 6 : prince rupert
# Processing Record 45 of Set 6 : lompoc
# Processing Record 46 of Set 6 : kavieng
# Processing Record 47 of Set 6 : maragogi
# Processing Record 48 of Set 6 : minab
# Processing Record 49 of Set 6 : wakkanai
# City not found. Skipping...
# Processing Record 50 of Set 6 : yerbogachen
# Processing Record 0 of Set 7 : yarmouth
# Processing Record 1 of Set 7 : fredericksburg
# Processing Record 2 of Set 7 : monrovia
# Processing Record 3 of Set 7 : aksu
# City not found. Skipping...
# Processing Record 4 of Set 7 : caravelas
# Processing Record 5 of Set 7 : half moon bay
# Processing Record 6 of Set 7 : kruisfontein
# Processing Record 7 of Set 7 : naze
# Processing Record 8 of Set 7 : borba
# Processing Record 9 of Set 7 : constantine
# Processing Record 10 of Set 7 : broome
# Processing Record 11 of Set 7 : puerto ayora
# Processing Record 12 of Set 7 : rudnogorsk
# Processing Record 13 of Set 7 : alta floresta
# City not found. Skipping...
# Processing Record 14 of Set 7 : tecoanapa
# Processing Record 15 of Set 7 : sao filipe
# Processing Record 16 of Set 7 : salinopolis
# Processing Record 17 of Set 7 : gafargaon
# Processing Record 18 of Set 7 : danjiangkou
# City not found. Skipping...
# Processing Record 19 of Set 7 : monte alegre
# Processing Record 20 of Set 7 : sassandra
# Processing Record 21 of Set 7 : coquimbo
# Processing Record 22 of Set 7 : shahr-e babak
# Processing Record 23 of Set 7 : grindavik
# Processing Record 24 of Set 7 : solano
# Processing Record 25 of Set 7 : kozhevnikovo
# Processing Record 26 of Set 7 : aasiaat
# Processing Record 27 of Set 7 : manta
# Processing Record 28 of Set 7 : kudat
# Processing Record 29 of Set 7 : sarny
# Processing Record 30 of Set 7 : sarankhola
# Processing Record 31 of Set 7 : moyobamba
# Processing Record 32 of Set 7 : shimanovsk
# Processing Record 33 of Set 7 : mpika
# Processing Record 34 of Set 7 : westerland
# Processing Record 35 of Set 7 : deputatskiy
# Processing Record 36 of Set 7 : george
# Processing Record 37 of Set 7 : khor
# Processing Record 38 of Set 7 : mogadishu
# Processing Record 39 of Set 7 : kupino
# Processing Record 40 of Set 7 : merauke
# Processing Record 41 of Set 7 : mazagao
# Processing Record 42 of Set 7 : labuhan
# Processing Record 43 of Set 7 : tres picos
# Processing Record 44 of Set 7 : hobyo
# Processing Record 45 of Set 7 : port hardy
# Processing Record 46 of Set 7 : provideniya
# Processing Record 47 of Set 7 : lerwick
# City not found. Skipping...
# Processing Record 48 of Set 7 : tacuarembo
# Processing Record 49 of Set 7 : paka
# Processing Record 50 of Set 7 : vaitape
# Processing Record 0 of Set 8 : muros
# Processing Record 1 of Set 8 : pandan
# Processing Record 2 of Set 8 : jacareacanga
# Processing Record 3 of Set 8 : lesnoy
# Processing Record 4 of Set 8 : sinnar
# Processing Record 5 of Set 8 : conceicao do coite
# Processing Record 6 of Set 8 : benjamin constant
# Processing Record 7 of Set 8 : peleduy
# Processing Record 8 of Set 8 : kununurra
# Processing Record 9 of Set 8 : ilulissat
# Processing Record 10 of Set 8 : vestmannaeyjar
# Processing Record 11 of Set 8 : warrnambool
# Processing Record 12 of Set 8 : hoa binh
# Processing Record 13 of Set 8 : valleyview
# Processing Record 14 of Set 8 : sinazongwe
# Processing Record 15 of Set 8 : sakakah
# Processing Record 16 of Set 8 : bac lieu
# Processing Record 17 of Set 8 : meulaboh
# Processing Record 18 of Set 8 : cassilandia
# Processing Record 19 of Set 8 : stephenville
# Processing Record 20 of Set 8 : jardim
# Processing Record 21 of Set 8 : fallon
# Processing Record 22 of Set 8 : calvinia
# Processing Record 23 of Set 8 : honiara
# Processing Record 24 of Set 8 : grand forks
# Processing Record 25 of Set 8 : muravlenko
# Processing Record 26 of Set 8 : abu kamal
# Processing Record 27 of Set 8 : aykhal
# Processing Record 28 of Set 8 : lorengau
# Processing Record 29 of Set 8 : tsumeb
# Processing Record 30 of Set 8 : wadi musa
# Processing Record 31 of Set 8 : shelburne
# City not found. Skipping...
# Processing Record 32 of Set 8 : kloulklubed
# Processing Record 33 of Set 8 : veraval
# Processing Record 34 of Set 8 : sinnamary
# Processing Record 35 of Set 8 : langres
# Processing Record 36 of Set 8 : kasongo-lunda
# Processing Record 37 of Set 8 : khani
# Processing Record 38 of Set 8 : cherskiy
# Processing Record 39 of Set 8 : contamana
# Processing Record 40 of Set 8 : mpraeso
# City not found. Skipping...
# Processing Record 41 of Set 8 : tadine
# Processing Record 42 of Set 8 : trapani
# Processing Record 43 of Set 8 : dodoma
# Processing Record 44 of Set 8 : lasa
# Processing Record 45 of Set 8 : kijang
# Processing Record 46 of Set 8 : mogok
# Processing Record 47 of Set 8 : chapais
# Processing Record 48 of Set 8 : kisangani
# Processing Record 49 of Set 8 : maniitsoq
# Processing Record 50 of Set 8 : pozo colorado
# Processing Record 0 of Set 9 : malmyzh
# Processing Record 1 of Set 9 : syava
# Processing Record 2 of Set 9 : kupang
# Processing Record 3 of Set 9 : buin
# Processing Record 4 of Set 9 : port blair
# Processing Record 5 of Set 9 : marsa matruh
# Processing Record 6 of Set 9 : nemuro
# Processing Record 7 of Set 9 : rosaryville
# Processing Record 8 of Set 9 : moen
# Processing Record 9 of Set 9 : tiksi
# Processing Record 10 of Set 9 : luderitz
# Processing Record 11 of Set 9 : port augusta
# Processing Record 12 of Set 9 : kulhudhuffushi
# Processing Record 13 of Set 9 : north platte
# Processing Record 14 of Set 9 : launceston
# Processing Record 15 of Set 9 : bonthe
# Processing Record 16 of Set 9 : evensk
# Processing Record 17 of Set 9 : kidal
# Processing Record 18 of Set 9 : massakory
# Processing Record 19 of Set 9 : qinnan
# Processing Record 20 of Set 9 : orlik
# Processing Record 21 of Set 9 : sivas
# City not found. Skipping...
# Processing Record 22 of Set 9 : porto walter
# Processing Record 23 of Set 9 : ust-nera
# Processing Record 24 of Set 9 : tura
# Processing Record 25 of Set 9 : surok
# Processing Record 26 of Set 9 : longyearbyen
# Processing Record 27 of Set 9 : fare
# Processing Record 28 of Set 9 : quang ngai
# Processing Record 29 of Set 9 : jijiga
# Processing Record 30 of Set 9 : murray bridge
# Processing Record 31 of Set 9 : domoni
# Processing Record 32 of Set 9 : najran
# Processing Record 33 of Set 9 : wajid
# Processing Record 34 of Set 9 : tual
# Processing Record 35 of Set 9 : agadez
# Processing Record 36 of Set 9 : dana point
# Processing Record 37 of Set 9 : kahului
# Processing Record 38 of Set 9 : marawi
# City not found. Skipping...
# Processing Record 39 of Set 9 : umm kaddadah
# City not found. Skipping...
# Processing Record 40 of Set 9 : nioro
# Processing Record 41 of Set 9 : turbat
# Processing Record 42 of Set 9 : preobrazheniye
# Processing Record 43 of Set 9 : henties bay
# Processing Record 44 of Set 9 : coahuayana
# Processing Record 45 of Set 9 : mungaa
# Processing Record 46 of Set 9 : imbituba
# Processing Record 47 of Set 9 : cabo rojo
# Processing Record 48 of Set 9 : saint-pierre
# Processing Record 49 of Set 9 : barcelona
# Processing Record 50 of Set 9 : sioux lookout
# Processing Record 0 of Set 10 : mitchell
# Processing Record 1 of Set 10 : kaeo
# Processing Record 2 of Set 10 : correia pinto
# Processing Record 3 of Set 10 : ayr
# City not found. Skipping...
# Processing Record 4 of Set 10 : atasu
# Processing Record 5 of Set 10 : geraldton
# Processing Record 6 of Set 10 : southport
# Processing Record 7 of Set 10 : honningsvag
# Processing Record 8 of Set 10 : solwezi
# Processing Record 9 of Set 10 : kolaras
# Processing Record 10 of Set 10 : lac du bonnet
# Processing Record 11 of Set 10 : zhanakorgan
# Processing Record 12 of Set 10 : gulu
# Processing Record 13 of Set 10 : yuncheng
# Processing Record 14 of Set 10 : lamu
# Processing Record 15 of Set 10 : pandharpur
# Processing Record 16 of Set 10 : celestun
# Processing Record 17 of Set 10 : erenhot
# Processing Record 18 of Set 10 : shimoda
# Processing Record 19 of Set 10 : beyneu
# Processing Record 20 of Set 10 : yulara
# City not found. Skipping...
# Processing Record 21 of Set 10 : muriti
# Processing Record 22 of Set 10 : requena
# Processing Record 23 of Set 10 : abyek
# Processing Record 24 of Set 10 : kiunga
# Processing Record 25 of Set 10 : anito
# Processing Record 26 of Set 10 : bridlington
# Processing Record 27 of Set 10 : morros
# Processing Record 28 of Set 10 : narsaq
# Processing Record 29 of Set 10 : north bend
# Processing Record 30 of Set 10 : longido
# Processing Record 31 of Set 10 : luena
# City not found. Skipping...
# Processing Record 32 of Set 10 : birao
# Processing Record 33 of Set 10 : alto araguaia
# Processing Record 34 of Set 10 : farafangana
# Processing Record 35 of Set 10 : mae hong son
# City not found. Skipping...
# Processing Record 36 of Set 10 : troitsko-pechorsk
# Processing Record 37 of Set 10 : fort nelson
# Processing Record 38 of Set 10 : gaogou
# Processing Record 39 of Set 10 : dimbokro
# Processing Record 40 of Set 10 : sile
# Processing Record 41 of Set 10 : vilyuysk
# Processing Record 42 of Set 10 : muisne
# Processing Record 43 of Set 10 : sechura
# Processing Record 44 of Set 10 : maxixe
# Processing Record 45 of Set 10 : berger
# Processing Record 46 of Set 10 : tairua
# Processing Record 47 of Set 10 : buraydah
# Processing Record 48 of Set 10 : lahij
# Processing Record 49 of Set 10 : nome
# Processing Record 50 of Set 10 : uvalde
# Processing Record 0 of Set 11 : angoram
# Processing Record 1 of Set 11 : praia
# Processing Record 2 of Set 11 : lensk
# Processing Record 3 of Set 11 : vao
# Processing Record 4 of Set 11 : chicama
# Processing Record 5 of Set 11 : springfield
# City not found. Skipping...
# Processing Record 6 of Set 11 : paso de carrasco
# City not found. Skipping...
# Processing Record 7 of Set 11 : saint-joseph
# Processing Record 8 of Set 11 : moengo
# Processing Record 9 of Set 11 : naryan-mar
# Processing Record 10 of Set 11 : brigantine
# Processing Record 11 of Set 11 : touros
# Processing Record 12 of Set 11 : tambopata
# Processing Record 13 of Set 11 : menongue
# Processing Record 14 of Set 11 : puerto madryn
# Processing Record 15 of Set 11 : mujiayingzi
# City not found. Skipping...
# Processing Record 16 of Set 11 : souillac
# Processing Record 17 of Set 11 : lukulu
# Processing Record 18 of Set 11 : sungaipenuh
# Processing Record 19 of Set 11 : gigmoto
# Processing Record 20 of Set 11 : namibe
# City not found. Skipping...
# Processing Record 21 of Set 11 : sur
# Processing Record 22 of Set 11 : king city
# Processing Record 23 of Set 11 : gandajika
# Processing Record 24 of Set 11 : elbistan
# Processing Record 25 of Set 11 : raga
# City not found. Skipping...
# Processing Record 26 of Set 11 : itoman
# Processing Record 27 of Set 11 : dalvik
# Processing Record 28 of Set 11 : lancaster
# Processing Record 29 of Set 11 : alofi
# Processing Record 30 of Set 11 : banda aceh
# Processing Record 31 of Set 11 : muscat
# Processing Record 32 of Set 11 : bandundu
# Processing Record 33 of Set 11 : faya
# Processing Record 34 of Set 11 : sialkot
# Processing Record 35 of Set 11 : saquena
# City not found. Skipping...
# Processing Record 36 of Set 11 : madimba
# Processing Record 37 of Set 11 : bunia
# Processing Record 38 of Set 11 : nanortalik
# Processing Record 39 of Set 11 : cayambe
# Processing Record 40 of Set 11 : acajutla
# Processing Record 41 of Set 11 : baruun-urt
# Processing Record 42 of Set 11 : mooresville
# Processing Record 43 of Set 11 : te anau
# Processing Record 44 of Set 11 : jalu
# Processing Record 45 of Set 11 : salaga
# Processing Record 46 of Set 11 : teguise
# Processing Record 47 of Set 11 : adrar
# Processing Record 48 of Set 11 : saint-ambroise
# Processing Record 49 of Set 11 : mtwara
# Processing Record 50 of Set 11 : dabat
# Processing Record 0 of Set 12 : kendari
# Processing Record 1 of Set 12 : kandrian
# Processing Record 2 of Set 12 : nicolas de pierola
# Processing Record 3 of Set 12 : bambanglipuro
# Processing Record 4 of Set 12 : chimbote
# Processing Record 5 of Set 12 : srednekolymsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Put the data into a dataframe
city_data_df = pd.DataFrame({
    "City": city_names,
    "Lat": lat,
    "Lng": long,
    "Max Temp": maxtemp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
})

# Display the DataFrame
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Upernavik  72.7868  -56.1549     28.78        91         100
# 1                Cape Town -33.9258   18.4232     57.00        94          40
# 2                    Kenai  60.5544 -151.2583     42.80        87          90
# 3  Puerto Baquerizo Moreno  -0.9000  -89.6000     74.35        87          73
# 4                Manjacaze -24.7117   33.8828     76.26        37           0
#
#    Wind Speed Country        Date
# 0        7.43      GL  05-16-2021
# 1        1.14      ZA  05-16-2021
# 2       12.66      US  05-16-2021
# 3        9.66      EC  05-16-2021
# 4       11.43      MZ  05-16-2021

# %%
# How many entries were returned?
city_data_df.count()
# Out:
# City          565
# Lat           565
# Lng           565
# Max Temp      565
# Humidity      565
# Cloudiness    565
# Wind Speed    565
# Country       565
# Date          565
# dtype: int64

# %%
# Inspect the data by using the describe function
city_data_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean    18.550832   16.111829   65.432301   68.334513   57.198230    8.401292
# std     33.053496   91.532224   17.896378   23.154192   38.792451    5.584676
# min    -54.800000 -175.200000    5.000000    1.000000    0.000000    0.450000
# 25%     -8.466700  -64.383100   53.010000   55.000000   20.000000    4.290000
# 50%     20.516900   20.421900   67.950000   74.000000   75.000000    6.910000
# 75%     46.485600  100.628800   79.250000   87.000000   97.000000   11.500000
# max     78.218600  179.316700  106.610000  100.000000  100.000000   35.680000

# %%
# Export the city data into a csv file
city_data_df.to_csv("../output_data/city_data.csv", index=False)

# %%
# Show Record Count
countforme = len(city_data_df)
countforme
# Out:
# 565

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Calculate latest date (max) for plot titles
tstamp = city_data_df.Date.max()
tstamp
# Out:
# '05-16-2021'

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude")

plt.savefig("../images/tempvlat.png")

# As latitude approaches 0, i.e. the equator, temperature increases

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Humidity (%) vs Latitude")

plt.savefig("../images/humvlat.png")

# There seems to be no relationship between humidity and latitude

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Cloudiness (%) vs Latitude")

plt.savefig("../images/cloudvlat.png")

# There seems to be no relationship between cloudiness and latitude

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Wind Speed (mph) vs Latitude")

plt.savefig("../images/windvlat.png")

# There seems to be no relationship between wind speed and latitude

# %% [markdown]
# ## Linear Regression

# %%
# Locate cities above or equal to 0 latitude and below 0 latitude
northern_cities = city_data_df[city_data_df.loc[:, "Lat"] >= 0]
southern_cities = city_data_df[city_data_df.loc[:, "Lat"] < 0]

# %%
# Create Northern and Southern Hemisphere DataFrames
northlat_df = city_data_df.loc[city_data_df["Lat"] >= 0,:]
southlat_df = city_data_df.loc[city_data_df["Lat"] < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot Temperature (°F) vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Max Temp"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(10,10),fontsize=12,color="black")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/tempvlatnh.png")

# %%
print("The high r value indicates a strong positive correlation between latitude and max temperature.")
# Out:
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot Temperature (°F) vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Max Temp"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-53,81),fontsize=12,color="black")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/tempvlatsh.png")

# %%
print("The high r value indicates a strong positive correlation between latitude and max temperature.")
# Out:
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot Humidity vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Humidity"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(52,10),fontsize=12,color="black")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/northernhumvlat.png")

# %%
print("The low r values indicate a weak to no relationship between humidity and latitude.")
# Out:
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot Humidity vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Humidity"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-55,25),fontsize=12,color="black")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/sourthernhumvlat.png")

# %%
print("The low r values indicate a weak to no relationship between humidity and latitude.")
# Out:
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot Cloudiness vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Cloudiness"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(50,10),fontsize=12,color="black")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/northerncloudvlat.png")

# %%
print("The low r values indicate a weak positive relationship between latitude and cloudiness.")
# Out:
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot Cloudiness vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Cloudiness"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Cloudiness"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-57,62),fontsize=12,color="black")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig('../images/southerncloudvlat')

# %%
print("The low r values indicate a weak positive relationship between latitude and cloudiness.")
# Out:
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot Wind Speed (mph) vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Wind Speed"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed (mph) vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Wind Speed"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(50,30),fontsize=12,color="black")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig('../images/northernwindvlat')

# %%
print("The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.")
# Out:
# The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot Wind Speed (mph) vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Wind Speed"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed (mph) vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Wind Speed"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-55,20),fontsize=12,color="black")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig('../images/southernwindvlat')

# %%
print("The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.")
# Out:
# The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.

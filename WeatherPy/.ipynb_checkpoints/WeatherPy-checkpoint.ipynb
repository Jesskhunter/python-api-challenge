# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import json
import requests
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import datetime
from scipy.stats import linregress

# Import API key
from api_key import weather_api_key

# Incorporate citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/city_data.csv"

# Range of latitude and longitude
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %%
city_names = []
lat = []
long = []
maxtemp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
city_counter = 1
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
#         date.append(response["dt"])

print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_names.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date = datetime.datetime.fromtimestamp(int(response['dt'])).strftime('%m-%d-%Y')
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        maxtemp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        
        if city_counter > 49:
            city_counter = 0
            set_counter = set_counter + 1
    
        else:
            city_counter = city_counter + 1
            
        print(f"Processing Record {city_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 2 of Set 1 : saskylakh
# Processing Record 3 of Set 1 : thompson
# Processing Record 4 of Set 1 : sola
# Processing Record 5 of Set 1 : vorukh
# Processing Record 6 of Set 1 : busselton
# Processing Record 7 of Set 1 : vardo
# Processing Record 8 of Set 1 : ushuaia
# Processing Record 9 of Set 1 : arraial do cabo
# Processing Record 10 of Set 1 : atuona
# City not found. Skipping...
# Processing Record 11 of Set 1 : iqaluit
# Processing Record 12 of Set 1 : barrow
# Processing Record 13 of Set 1 : victoria
# Processing Record 14 of Set 1 : hermanus
# Processing Record 15 of Set 1 : los llanos de aridane
# Processing Record 16 of Set 1 : albany
# Processing Record 17 of Set 1 : jamestown
# Processing Record 18 of Set 1 : kysyl-syr
# Processing Record 19 of Set 1 : bluff
# Processing Record 20 of Set 1 : minas novas
# Processing Record 21 of Set 1 : ola
# City not found. Skipping...
# Processing Record 22 of Set 1 : half moon bay
# Processing Record 23 of Set 1 : port elizabeth
# Processing Record 24 of Set 1 : inirida
# Processing Record 25 of Set 1 : avarua
# Processing Record 26 of Set 1 : pangnirtung
# Processing Record 27 of Set 1 : tasiilaq
# Processing Record 28 of Set 1 : bud
# Processing Record 29 of Set 1 : torbay
# City not found. Skipping...
# Processing Record 30 of Set 1 : qaanaaq
# Processing Record 31 of Set 1 : cidreira
# Processing Record 32 of Set 1 : hobyo
# Processing Record 33 of Set 1 : hobart
# Processing Record 34 of Set 1 : kalavai
# Processing Record 35 of Set 1 : tortoli
# Processing Record 36 of Set 1 : rikitea
# Processing Record 37 of Set 1 : sao filipe
# Processing Record 38 of Set 1 : lavrentiya
# Processing Record 39 of Set 1 : sydney
# Processing Record 40 of Set 1 : adrar
# City not found. Skipping...
# Processing Record 41 of Set 1 : dikson
# Processing Record 42 of Set 1 : kozluk
# Processing Record 43 of Set 1 : berlevag
# Processing Record 44 of Set 1 : codrington
# Processing Record 45 of Set 1 : samarai
# Processing Record 46 of Set 1 : punta arenas
# Processing Record 47 of Set 1 : ust-tsilma
# Processing Record 48 of Set 1 : chokurdakh
# Processing Record 49 of Set 1 : castro
# Processing Record 50 of Set 1 : kalamare
# Processing Record 0 of Set 2 : lima
# Processing Record 1 of Set 2 : saint anthony
# Processing Record 2 of Set 2 : arona
# Processing Record 3 of Set 2 : rudnogorsk
# Processing Record 4 of Set 2 : nyurba
# Processing Record 5 of Set 2 : sainte-suzanne
# Processing Record 6 of Set 2 : hithadhoo
# Processing Record 7 of Set 2 : demirci
# Processing Record 8 of Set 2 : cape town
# Processing Record 9 of Set 2 : mataura
# Processing Record 10 of Set 2 : san patricio
# City not found. Skipping...
# Processing Record 11 of Set 2 : bredasdorp
# Processing Record 12 of Set 2 : upernavik
# Processing Record 13 of Set 2 : uddevalla
# Processing Record 14 of Set 2 : mogadishu
# Processing Record 15 of Set 2 : new norfolk
# Processing Record 16 of Set 2 : hobbs
# Processing Record 17 of Set 2 : lebu
# Processing Record 18 of Set 2 : neiafu
# Processing Record 19 of Set 2 : vaini
# Processing Record 20 of Set 2 : narsaq
# Processing Record 21 of Set 2 : hilo
# Processing Record 22 of Set 2 : airai
# City not found. Skipping...
# Processing Record 23 of Set 2 : kapaa
# Processing Record 24 of Set 2 : kattivakkam
# Processing Record 25 of Set 2 : cukai
# Processing Record 26 of Set 2 : biak
# Processing Record 27 of Set 2 : caravelas
# City not found. Skipping...
# Processing Record 28 of Set 2 : oeiras do para
# Processing Record 29 of Set 2 : pasighat
# City not found. Skipping...
# Processing Record 30 of Set 2 : ancud
# Processing Record 31 of Set 2 : bireun
# City not found. Skipping...
# Processing Record 32 of Set 2 : vikhorevka
# City not found. Skipping...
# Processing Record 33 of Set 2 : alofi
# Processing Record 34 of Set 2 : plettenberg bay
# Processing Record 35 of Set 2 : ozu
# Processing Record 36 of Set 2 : alenquer
# Processing Record 37 of Set 2 : mahebourg
# City not found. Skipping...
# Processing Record 38 of Set 2 : hasaki
# Processing Record 39 of Set 2 : souillac
# Processing Record 40 of Set 2 : provideniya
# Processing Record 41 of Set 2 : kang
# Processing Record 42 of Set 2 : aykhal
# Processing Record 43 of Set 2 : kambove
# Processing Record 44 of Set 2 : catabola
# Processing Record 45 of Set 2 : wadi musa
# Processing Record 46 of Set 2 : bengkulu
# Processing Record 47 of Set 2 : lichinga
# Processing Record 48 of Set 2 : pevek
# Processing Record 49 of Set 2 : fuerte
# Processing Record 50 of Set 2 : kaitangata
# Processing Record 0 of Set 3 : shache
# Processing Record 1 of Set 3 : burnie
# Processing Record 2 of Set 3 : hofn
# Processing Record 3 of Set 3 : yellowknife
# Processing Record 4 of Set 3 : central point
# City not found. Skipping...
# Processing Record 5 of Set 3 : dunedin
# Processing Record 6 of Set 3 : cherskiy
# Processing Record 7 of Set 3 : chaoyang
# Processing Record 8 of Set 3 : qasigiannguit
# Processing Record 9 of Set 3 : saravan
# Processing Record 10 of Set 3 : montrose
# Processing Record 11 of Set 3 : tautira
# City not found. Skipping...
# Processing Record 12 of Set 3 : ilulissat
# Processing Record 13 of Set 3 : roma
# Processing Record 14 of Set 3 : mount isa
# Processing Record 15 of Set 3 : kasongo
# Processing Record 16 of Set 3 : lorengau
# Processing Record 17 of Set 3 : elizabeth city
# Processing Record 18 of Set 3 : salamanca
# Processing Record 19 of Set 3 : harlingen
# Processing Record 20 of Set 3 : rancho palos verdes
# Processing Record 21 of Set 3 : khatanga
# Processing Record 22 of Set 3 : tuktoyaktuk
# Processing Record 23 of Set 3 : tarrafal
# Processing Record 24 of Set 3 : torrelavega
# Processing Record 25 of Set 3 : boueni
# Processing Record 26 of Set 3 : nikolskoye
# Processing Record 27 of Set 3 : port alfred
# Processing Record 28 of Set 3 : uyuni
# Processing Record 29 of Set 3 : mitchell
# City not found. Skipping...
# Processing Record 30 of Set 3 : namioka
# Processing Record 31 of Set 3 : cayenne
# Processing Record 32 of Set 3 : santa vitoria do palmar
# City not found. Skipping...
# Processing Record 33 of Set 3 : butaritari
# Processing Record 34 of Set 3 : bethel
# City not found. Skipping...
# Processing Record 35 of Set 3 : egvekinot
# Processing Record 36 of Set 3 : singkang
# Processing Record 37 of Set 3 : muros
# Processing Record 38 of Set 3 : goderich
# Processing Record 39 of Set 3 : margate
# Processing Record 40 of Set 3 : obo
# Processing Record 41 of Set 3 : sekoma
# Processing Record 42 of Set 3 : kukmor
# Processing Record 43 of Set 3 : flinders
# Processing Record 44 of Set 3 : isangel
# Processing Record 45 of Set 3 : magadan
# Processing Record 46 of Set 3 : vila velha
# Processing Record 47 of Set 3 : ikeda
# Processing Record 48 of Set 3 : lewistown
# Processing Record 49 of Set 3 : chateaubelair
# City not found. Skipping...
# Processing Record 50 of Set 3 : penzance
# Processing Record 0 of Set 4 : tura
# Processing Record 1 of Set 4 : bowen
# Processing Record 2 of Set 4 : pacific grove
# City not found. Skipping...
# Processing Record 3 of Set 4 : vila
# Processing Record 4 of Set 4 : viedma
# Processing Record 5 of Set 4 : magistralnyy
# Processing Record 6 of Set 4 : xinglongshan
# Processing Record 7 of Set 4 : mercedes
# City not found. Skipping...
# Processing Record 8 of Set 4 : hamilton
# Processing Record 9 of Set 4 : mar del plata
# Processing Record 10 of Set 4 : college
# City not found. Skipping...
# Processing Record 11 of Set 4 : carnarvon
# Processing Record 12 of Set 4 : pisco
# Processing Record 13 of Set 4 : san rafael
# Processing Record 14 of Set 4 : hualmay
# Processing Record 15 of Set 4 : ketchikan
# Processing Record 16 of Set 4 : vilyuysk
# Processing Record 17 of Set 4 : nizhniy kuranakh
# Processing Record 18 of Set 4 : borgo san lorenzo
# Processing Record 19 of Set 4 : palasbari
# Processing Record 20 of Set 4 : lipari
# Processing Record 21 of Set 4 : chalus
# Processing Record 22 of Set 4 : esteli
# Processing Record 23 of Set 4 : kodiak
# Processing Record 24 of Set 4 : esperance
# Processing Record 25 of Set 4 : ribeira grande
# Processing Record 26 of Set 4 : libreville
# Processing Record 27 of Set 4 : namibe
# Processing Record 28 of Set 4 : rawson
# Processing Record 29 of Set 4 : emirdag
# Processing Record 30 of Set 4 : coquimbo
# Processing Record 31 of Set 4 : bambous virieux
# Processing Record 32 of Set 4 : la ronge
# Processing Record 33 of Set 4 : havre
# Processing Record 34 of Set 4 : nuevo progreso
# City not found. Skipping...
# Processing Record 35 of Set 4 : kodinsk
# Processing Record 36 of Set 4 : banda aceh
# Processing Record 37 of Set 4 : ixtapa
# Processing Record 38 of Set 4 : mombetsu
# Processing Record 39 of Set 4 : jati
# Processing Record 40 of Set 4 : axim
# Processing Record 41 of Set 4 : sinjar
# Processing Record 42 of Set 4 : aklavik
# Processing Record 43 of Set 4 : vihti
# Processing Record 44 of Set 4 : polunochnoye
# Processing Record 45 of Set 4 : kandrian
# Processing Record 46 of Set 4 : evensk
# Processing Record 47 of Set 4 : iglesias
# Processing Record 48 of Set 4 : kruisfontein
# Processing Record 49 of Set 4 : geraldton
# Processing Record 50 of Set 4 : chuy
# Processing Record 0 of Set 5 : puerto ayora
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set 5 : brae
# City not found. Skipping...
# Processing Record 2 of Set 5 : lahat
# Processing Record 3 of Set 5 : beboto
# Processing Record 4 of Set 5 : ponta do sol
# Processing Record 5 of Set 5 : krasnoarmeysk
# Processing Record 6 of Set 5 : anchorage
# Processing Record 7 of Set 5 : luangwa
# Processing Record 8 of Set 5 : marsh harbour
# Processing Record 9 of Set 5 : mnogovershinnyy
# Processing Record 10 of Set 5 : beringovskiy
# Processing Record 11 of Set 5 : tynset
# Processing Record 12 of Set 5 : russell
# Processing Record 13 of Set 5 : lieksa
# Processing Record 14 of Set 5 : baker city
# Processing Record 15 of Set 5 : dalby
# Processing Record 16 of Set 5 : saint george
# Processing Record 17 of Set 5 : hervey bay
# Processing Record 18 of Set 5 : yumen
# City not found. Skipping...
# Processing Record 19 of Set 5 : shadrinsk
# Processing Record 20 of Set 5 : klaksvik
# City not found. Skipping...
# Processing Record 21 of Set 5 : abu samrah
# Processing Record 22 of Set 5 : marsa matruh
# Processing Record 23 of Set 5 : namatanai
# Processing Record 24 of Set 5 : nioro
# Processing Record 25 of Set 5 : east london
# Processing Record 26 of Set 5 : misratah
# Processing Record 27 of Set 5 : waipawa
# Processing Record 28 of Set 5 : tambacounda
# Processing Record 29 of Set 5 : san cristobal
# Processing Record 30 of Set 5 : necochea
# Processing Record 31 of Set 5 : leningradskiy
# Processing Record 32 of Set 5 : saint-joseph
# Processing Record 33 of Set 5 : saldanha
# Processing Record 34 of Set 5 : itarema
# Processing Record 35 of Set 5 : salinas
# Processing Record 36 of Set 5 : umbertide
# Processing Record 37 of Set 5 : goleta
# Processing Record 38 of Set 5 : palmer
# Processing Record 39 of Set 5 : kavieng
# Processing Record 40 of Set 5 : garmsar
# Processing Record 41 of Set 5 : san vicente
# Processing Record 42 of Set 5 : awbari
# Processing Record 43 of Set 5 : san jose
# Processing Record 44 of Set 5 : camacha
# Processing Record 45 of Set 5 : oistins
# Processing Record 46 of Set 5 : boyolangu
# Processing Record 47 of Set 5 : dingle
# Processing Record 48 of Set 5 : olhao
# Processing Record 49 of Set 5 : rio gallegos
# Processing Record 50 of Set 5 : sao joao da barra
# Processing Record 0 of Set 6 : marzuq
# Processing Record 1 of Set 6 : lagoa
# Processing Record 2 of Set 6 : malakal
# Processing Record 3 of Set 6 : vila franca do campo
# Processing Record 4 of Set 6 : komsomolskiy
# City not found. Skipping...
# Processing Record 5 of Set 6 : nicoya
# Processing Record 6 of Set 6 : sao jose da coroa grande
# Processing Record 7 of Set 6 : abonnema
# Processing Record 8 of Set 6 : ossora
# Processing Record 9 of Set 6 : alcacer do sal
# Processing Record 10 of Set 6 : elmadag
# City not found. Skipping...
# Processing Record 11 of Set 6 : karlskrona
# Processing Record 12 of Set 6 : novyy urengoy
# Processing Record 13 of Set 6 : deputatskiy
# Processing Record 14 of Set 6 : taos
# Processing Record 15 of Set 6 : kudahuvadhoo
# Processing Record 16 of Set 6 : tomino
# Processing Record 17 of Set 6 : poum
# Processing Record 18 of Set 6 : sitka
# Processing Record 19 of Set 6 : etne
# Processing Record 20 of Set 6 : cabo san lucas
# Processing Record 21 of Set 6 : saint-philippe
# Processing Record 22 of Set 6 : takoradi
# Processing Record 23 of Set 6 : san carlos de bariloche
# Processing Record 24 of Set 6 : mayo
# City not found. Skipping...
# Processing Record 25 of Set 6 : tilichiki
# City not found. Skipping...
# Processing Record 26 of Set 6 : weyburn
# Processing Record 27 of Set 6 : pangody
# Processing Record 28 of Set 6 : plouzane
# Processing Record 29 of Set 6 : faanui
# Processing Record 30 of Set 6 : oktyabrskiy
# Processing Record 31 of Set 6 : bathsheba
# Processing Record 32 of Set 6 : crestview
# Processing Record 33 of Set 6 : impfondo
# Processing Record 34 of Set 6 : krasnoselkup
# City not found. Skipping...
# Processing Record 35 of Set 6 : aleksandrov gay
# Processing Record 36 of Set 6 : clyde river
# Processing Record 37 of Set 6 : buraydah
# Processing Record 38 of Set 6 : matamoros
# Processing Record 39 of Set 6 : zhoucheng
# Processing Record 40 of Set 6 : nanortalik
# Processing Record 41 of Set 6 : hami
# Processing Record 42 of Set 6 : udachnyy
# City not found. Skipping...
# Processing Record 43 of Set 6 : ouadda
# Processing Record 44 of Set 6 : road town
# Processing Record 45 of Set 6 : sandwick
# Processing Record 46 of Set 6 : bogo
# Processing Record 47 of Set 6 : alta floresta
# Processing Record 48 of Set 6 : gushikawa
# Processing Record 49 of Set 6 : huayang
# City not found. Skipping...
# Processing Record 50 of Set 6 : gorontalo
# Processing Record 0 of Set 7 : yongan
# Processing Record 1 of Set 7 : tessalit
# Processing Record 2 of Set 7 : brookhaven
# City not found. Skipping...
# Processing Record 3 of Set 7 : dustlik
# Processing Record 4 of Set 7 : beni
# Processing Record 5 of Set 7 : nantucket
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 7 : katsuura
# Processing Record 7 of Set 7 : ambilobe
# Processing Record 8 of Set 7 : georgetown
# Processing Record 9 of Set 7 : xining
# Processing Record 10 of Set 7 : denpasar
# Processing Record 11 of Set 7 : merauke
# Processing Record 12 of Set 7 : enshi
# Processing Record 13 of Set 7 : thinadhoo
# Processing Record 14 of Set 7 : yambio
# Processing Record 15 of Set 7 : lovington
# Processing Record 16 of Set 7 : ordzhonikidze
# Processing Record 17 of Set 7 : cariamanga
# Processing Record 18 of Set 7 : lazarev
# City not found. Skipping...
# Processing Record 19 of Set 7 : havre-saint-pierre
# Processing Record 20 of Set 7 : sfantu gheorghe
# Processing Record 21 of Set 7 : lockhart
# Processing Record 22 of Set 7 : la union
# Processing Record 23 of Set 7 : lamu
# Processing Record 24 of Set 7 : rosarito
# Processing Record 25 of Set 7 : luanda
# Processing Record 26 of Set 7 : darhan
# Processing Record 27 of Set 7 : taltal
# Processing Record 28 of Set 7 : akdepe
# Processing Record 29 of Set 7 : gamba
# Processing Record 30 of Set 7 : tiarei
# City not found. Skipping...
# Processing Record 31 of Set 7 : beloha
# Processing Record 32 of Set 7 : sonoita
# Processing Record 33 of Set 7 : shubarshi
# Processing Record 34 of Set 7 : ahipara
# Processing Record 35 of Set 7 : ostrovnoy
# Processing Record 36 of Set 7 : raga
# Processing Record 37 of Set 7 : pascagoula
# Processing Record 38 of Set 7 : forestville
# Processing Record 39 of Set 7 : noumea
# Processing Record 40 of Set 7 : port arthur
# Processing Record 41 of Set 7 : mount gambier
# Processing Record 42 of Set 7 : katherine
# Processing Record 43 of Set 7 : spornoye
# Processing Record 44 of Set 7 : pavagada
# City not found. Skipping...
# Processing Record 45 of Set 7 : verkhoyansk
# Processing Record 46 of Set 7 : nouadhibou
# Processing Record 47 of Set 7 : luderitz
# City not found. Skipping...
# Processing Record 48 of Set 7 : rio grande
# Processing Record 49 of Set 7 : hoquiam
# Processing Record 50 of Set 7 : norman wells
# Processing Record 0 of Set 8 : rantauprapat
# Processing Record 1 of Set 8 : hambantota
# Processing Record 2 of Set 8 : marion
# Processing Record 3 of Set 8 : muli
# Processing Record 4 of Set 8 : te anau
# Processing Record 5 of Set 8 : sao domingos
# Processing Record 6 of Set 8 : castrillon
# Processing Record 7 of Set 8 : kisesa
# Processing Record 8 of Set 8 : tiksi
# Processing Record 9 of Set 8 : salalah
# City not found. Skipping...
# Processing Record 10 of Set 8 : tazovskiy
# Processing Record 11 of Set 8 : zaysan
# Processing Record 12 of Set 8 : birin
# Processing Record 13 of Set 8 : saint-louis
# Processing Record 14 of Set 8 : almaznyy
# Processing Record 15 of Set 8 : okhotsk
# Processing Record 16 of Set 8 : miri
# Processing Record 17 of Set 8 : emba
# Processing Record 18 of Set 8 : chimoio
# Processing Record 19 of Set 8 : tubmanburg
# Processing Record 20 of Set 8 : christchurch
# Processing Record 21 of Set 8 : aitape
# Processing Record 22 of Set 8 : lompoc
# Processing Record 23 of Set 8 : fortuna
# City not found. Skipping...
# Processing Record 24 of Set 8 : sawakin
# Processing Record 25 of Set 8 : sao felix do xingu
# Processing Record 26 of Set 8 : coffs harbour
# Processing Record 27 of Set 8 : ampanihy
# Processing Record 28 of Set 8 : tambura
# Processing Record 29 of Set 8 : ponazyrevo
# Processing Record 30 of Set 8 : araouane
# Processing Record 31 of Set 8 : kailua
# Processing Record 32 of Set 8 : tecolutla
# Processing Record 33 of Set 8 : beyneu
# Processing Record 34 of Set 8 : shakawe
# Processing Record 35 of Set 8 : sapele
# Processing Record 36 of Set 8 : kurilsk
# Processing Record 37 of Set 8 : vieste
# Processing Record 38 of Set 8 : andilamena
# Processing Record 39 of Set 8 : albertville
# Processing Record 40 of Set 8 : port-gentil
# Processing Record 41 of Set 8 : yuzhnyy
# Processing Record 42 of Set 8 : ardmore
# Processing Record 43 of Set 8 : gutierrez zamora
# Processing Record 44 of Set 8 : maragogi
# Processing Record 45 of Set 8 : houma
# Processing Record 46 of Set 8 : gat
# Processing Record 47 of Set 8 : pakokku
# Processing Record 48 of Set 8 : ryde
# Processing Record 49 of Set 8 : phan thiet
# Processing Record 50 of Set 8 : kalmunai
# Processing Record 0 of Set 9 : gela
# Processing Record 1 of Set 9 : batagay
# Processing Record 2 of Set 9 : galveston
# Processing Record 3 of Set 9 : kiunga
# Processing Record 4 of Set 9 : taksimo
# Processing Record 5 of Set 9 : samalkha
# Processing Record 6 of Set 9 : longyearbyen
# City not found. Skipping...
# Processing Record 7 of Set 9 : waingapu
# City not found. Skipping...
# Processing Record 8 of Set 9 : bogorodskoye
# City not found. Skipping...
# Processing Record 9 of Set 9 : juneau
# Processing Record 10 of Set 9 : ladario
# Processing Record 11 of Set 9 : kimberley
# Processing Record 12 of Set 9 : alice springs
# Processing Record 13 of Set 9 : lucapa
# Processing Record 14 of Set 9 : kiama
# Processing Record 15 of Set 9 : springbok
# Processing Record 16 of Set 9 : tezu
# Processing Record 17 of Set 9 : teacapan
# Processing Record 18 of Set 9 : san quintin
# Processing Record 19 of Set 9 : kahului
# Processing Record 20 of Set 9 : vanavara
# Processing Record 21 of Set 9 : halifax
# Processing Record 22 of Set 9 : baykit
# Processing Record 23 of Set 9 : premnitz
# Processing Record 24 of Set 9 : alta
# Processing Record 25 of Set 9 : saint-augustin
# Processing Record 26 of Set 9 : andenes
# Processing Record 27 of Set 9 : san policarpo
# Processing Record 28 of Set 9 : bull savanna
# Processing Record 29 of Set 9 : murray bridge
# Processing Record 30 of Set 9 : fayaoue
# Processing Record 31 of Set 9 : nushki
# City not found. Skipping...
# Processing Record 32 of Set 9 : makakilo city
# Processing Record 33 of Set 9 : dwarka
# Processing Record 34 of Set 9 : avera
# Processing Record 35 of Set 9 : trat
# Processing Record 36 of Set 9 : kununurra
# Processing Record 37 of Set 9 : bestobe
# City not found. Skipping...
# Processing Record 38 of Set 9 : henties bay
# Processing Record 39 of Set 9 : qazvin
# Processing Record 40 of Set 9 : severo-yeniseyskiy
# Processing Record 41 of Set 9 : vao
# Processing Record 42 of Set 9 : grand baie
# Processing Record 43 of Set 9 : mayskiy
# Processing Record 44 of Set 9 : gornopravdinsk
# Processing Record 45 of Set 9 : great malvern
# Processing Record 46 of Set 9 : humboldt
# Processing Record 47 of Set 9 : floriano
# City not found. Skipping...
# Processing Record 48 of Set 9 : bonthe
# Processing Record 49 of Set 9 : semey
# Processing Record 50 of Set 9 : coihueco
# Processing Record 0 of Set 10 : sungairaya
# Processing Record 1 of Set 10 : bandarbeyla
# Processing Record 2 of Set 10 : jabinyanah
# Processing Record 3 of Set 10 : shingu
# Processing Record 4 of Set 10 : awjilah
# Processing Record 5 of Set 10 : bilibino
# Processing Record 6 of Set 10 : qandala
# Processing Record 7 of Set 10 : amahai
# Processing Record 8 of Set 10 : tomari
# Processing Record 9 of Set 10 : port hedland
# Processing Record 10 of Set 10 : hackettstown
# Processing Record 11 of Set 10 : turayf
# Processing Record 12 of Set 10 : nikolayevsk-na-amure
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 10 : fort nelson
# Processing Record 14 of Set 10 : saint-georges
# Processing Record 15 of Set 10 : saurimo
# Processing Record 16 of Set 10 : liverpool
# Processing Record 17 of Set 10 : puerto escondido
# City not found. Skipping...
# Processing Record 18 of Set 10 : yerofey pavlovich
# Processing Record 19 of Set 10 : rodrigues alves
# Processing Record 20 of Set 10 : caxito
# Processing Record 21 of Set 10 : kemijarvi
# Processing Record 22 of Set 10 : fort smith
# Processing Record 23 of Set 10 : funadhoo
# Processing Record 24 of Set 10 : ulundi
# Processing Record 25 of Set 10 : meulaboh
# Processing Record 26 of Set 10 : quatre cocos
# Processing Record 27 of Set 10 : san andres
# Processing Record 28 of Set 10 : curuca
# Processing Record 29 of Set 10 : gilgit
# Processing Record 30 of Set 10 : sao luis do quitunde
# Processing Record 31 of Set 10 : muncie
# Processing Record 32 of Set 10 : king city
# Processing Record 33 of Set 10 : roxana
# Processing Record 34 of Set 10 : mehran
# Processing Record 35 of Set 10 : ambon
# Processing Record 36 of Set 10 : cache creek
# City not found. Skipping...
# Processing Record 37 of Set 10 : mana
# Processing Record 38 of Set 10 : nucet
# City not found. Skipping...
# Processing Record 39 of Set 10 : koungheul
# Processing Record 40 of Set 10 : soe
# Processing Record 41 of Set 10 : yaring
# City not found. Skipping...
# Processing Record 42 of Set 10 : ghugus
# Processing Record 43 of Set 10 : rincon
# Processing Record 44 of Set 10 : venado tuerto
# Processing Record 45 of Set 10 : maumere
# Processing Record 46 of Set 10 : kalabo
# City not found. Skipping...
# Processing Record 47 of Set 10 : camana
# Processing Record 48 of Set 10 : vigrestad
# Processing Record 49 of Set 10 : edmonton
# Processing Record 50 of Set 10 : kardla
# Processing Record 0 of Set 11 : langsa
# Processing Record 1 of Set 11 : tuatapere
# Processing Record 2 of Set 11 : manjeshwar
# Processing Record 3 of Set 11 : zomin
# Processing Record 4 of Set 11 : terrace
# City not found. Skipping...
# Processing Record 5 of Set 11 : cassilandia
# Processing Record 6 of Set 11 : rabaul
# City not found. Skipping...
# Processing Record 7 of Set 11 : klyuchi
# City not found. Skipping...
# Processing Record 8 of Set 11 : serik
# Processing Record 9 of Set 11 : marawi
# Processing Record 10 of Set 11 : panguna
# Processing Record 11 of Set 11 : balaipungut
# City not found. Skipping...
# Processing Record 12 of Set 11 : zdvinsk
# Processing Record 13 of Set 11 : sambava
# City not found. Skipping...
# Processing Record 14 of Set 11 : paita
# Processing Record 15 of Set 11 : isilkul
# Processing Record 16 of Set 11 : carballo
# Processing Record 17 of Set 11 : olafsvik
# Processing Record 18 of Set 11 : ust-kulom
# Processing Record 19 of Set 11 : garowe
# Processing Record 20 of Set 11 : henderson
# Processing Record 21 of Set 11 : alakurtti
# Processing Record 22 of Set 11 : gizo
# Processing Record 23 of Set 11 : talnakh
# Processing Record 24 of Set 11 : vostok
# Processing Record 25 of Set 11 : virarajendrapet
# Processing Record 26 of Set 11 : matara
# Processing Record 27 of Set 11 : pilar
# Processing Record 28 of Set 11 : kontagora
# Processing Record 29 of Set 11 : karpathos
# Processing Record 30 of Set 11 : jizan
# Processing Record 31 of Set 11 : padang
# Processing Record 32 of Set 11 : pangai
# Processing Record 33 of Set 11 : krasavino
# Processing Record 34 of Set 11 : salym
# Processing Record 35 of Set 11 : progreso
# City not found. Skipping...
# Processing Record 36 of Set 11 : sobolevo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Put the data into a dataframe
city_data_df = pd.DataFrame({
    "City": city_names,
    "Lat": lat,
    "Lng": long,
    "Max Temp": maxtemp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
})

# Display the DataFrame
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Saskylakh  71.9167  114.0833     29.68        91         100       10.07
# 1   Thompson  55.7435  -97.8558     36.70        97         100        9.01
# 2       Sola -13.8833  167.5500     80.44        80          78       19.17
# 3     Vorukh  39.8494   70.5838     58.19        71         100        8.46
# 4  Busselton -33.6500  115.3333     56.08        78           1        6.82
#
#   Country        Date
# 0      RU  05-19-2021
# 1      CA  05-19-2021
# 2      VU  05-19-2021
# 3      TJ  05-19-2021
# 4      AU  05-19-2021

# %%
# How many entries were returned?
city_data_df.count()
# Out:
# City          545
# Lat           545
# Lng           545
# Max Temp      545
# Humidity      545
# Cloudiness    545
# Wind Speed    545
# Country       545
# Date          545
# dtype: int64

# %%
# Inspect the data by using the describe function
city_data_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  545.000000  545.000000  545.000000  545.000000  545.000000  545.000000
# mean    19.813692   18.381491   67.323284   65.979817   56.469725    8.040092
# std     33.154904   91.016138   18.601521   23.817967   40.027788    5.428475
# min    -54.800000 -179.166700   18.160000    5.000000    0.000000    0.000000
# 25%     -8.419200  -61.748500   55.450000   49.000000   13.000000    3.830000
# 50%     25.533300   25.550000   71.960000   72.000000   71.000000    6.980000
# 75%     46.485600   96.166700   79.900000   85.000000   99.000000   10.940000
# max     78.218600  179.316700  112.100000  100.000000  100.000000   32.210000

# %%
# Export the city data into a csv file
city_data_df.to_csv("../output_data/city_data.csv", index=False)

# %%
# Show Record Count
countforme = len(city_data_df)
countforme
# Out:
# 545

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Calculate latest date (max) for plot titles
tstamp = city_data_df.Date.max()
tstamp
# Out:
# '05-19-2021'

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude")

plt.savefig("../images/tempvlat.png")

# As latitude approaches 0, i.e. the equator, temperature increases

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Humidity (%) vs Latitude")

plt.savefig("../images/humvlat.png")

# There seems to be no relationship between humidity and latitude

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Cloudiness (%) vs Latitude")

plt.savefig("../images/cloudvlat.png")

# There seems to be no relationship between cloudiness and latitude

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Wind Speed (mph) vs Latitude")

plt.savefig("../images/windvlat.png")

# There seems to be no relationship between wind speed and latitude

# %% [markdown]
# ## Linear Regression

# %%
# Locate cities above or equal to 0 latitude and below 0 latitude
northern_cities = city_data_df[city_data_df.loc[:, "Lat"] >= 0]
southern_cities = city_data_df[city_data_df.loc[:, "Lat"] < 0]

# %%
# Create Northern and Southern Hemisphere DataFrames
northlat_df = city_data_df.loc[city_data_df["Lat"] >= 0,:]
southlat_df = city_data_df.loc[city_data_df["Lat"] < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot Temperature (°F) vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Max Temp"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(5,30), fontsize=13,color="red")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/tempvlatnh.png")

# %%
print("The high r value indicates a strong positive correlation between latitude and max temperature.")
# Out:
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot Temperature (°F) vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Max Temp"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-55,81),fontsize=12,color="red")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/tempvlatsh.png")

# %%
print("The high r value indicates a strong positive correlation between latitude and max temperature.")
# Out:
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot Humidity vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Humidity"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(48,10),fontsize=13,color="red")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/northernhumvlat.png")

# %%
print("The low r values indicate a weak to no relationship between humidity and latitude.")
# Out:
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot Humidity vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Humidity"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-55,25), fontsize=13,color="red")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/sourthernhumvlat.png")

# %%
print("The low r values indicate a weak to no relationship between humidity and latitude.")
# Out:
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot Cloudiness vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Cloudiness"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(49,10), fontsize=13,color="red")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/northerncloudvlat.png")

# %%
print("The low r values indicate a weak positive relationship between latitude and cloudiness.")
# Out:
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot Cloudiness vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Cloudiness"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Cloudiness"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-55,22),fontsize=13,color="red")
plt.plot(southern_cities["Lat"], regress_values,"r-")

plt.savefig('../images/southerncloudvlat')

# %%
print("The low r values indicate a weak positive relationship between latitude and cloudiness.")
# Out:
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot Wind Speed (mph) vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Wind Speed"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed (mph) vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Wind Speed"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(49,22),fontsize=13,color="red")
plt.plot(northern_cities["Lat"], regress_values,"r-")

plt.savefig('../images/northernwindvlat')

# %%
print("The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.")
# Out:
# The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot Wind Speed (mph) vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Wind Speed"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed (mph) vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Wind Speed"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-55,17),fontsize=13,color="red")
plt.plot(southern_cities["Lat"], regress_values,"r-")

plt.savefig('../images/southernwindvlat')

# %%
print("The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.")
# Out:
# The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.

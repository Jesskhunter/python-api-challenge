# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import json
import requests
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import datetime
from scipy.stats import linregress

# Import API key
from api_key import weather_api_key

# Incorporate citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/city_data.csv"

# Range of latitude and longitude
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %%
city_names = []
lat = []
long = []
maxtemp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
city_counter = 1
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
#         date.append(response["dt"])

print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_names.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date = datetime.datetime.fromtimestamp(int(response['dt'])).strftime('%m-%d-%Y')
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        maxtemp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        
        if city_counter > 49:
            city_counter = 0
            set_counter = set_counter + 1
    
        else:
            city_counter = city_counter + 1
            
        print(f"Processing Record {city_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 2 of Set 1 : vaini
# Processing Record 3 of Set 1 : nyurba
# Processing Record 4 of Set 1 : avarua
# Processing Record 5 of Set 1 : ketchikan
# City not found. Skipping...
# Processing Record 6 of Set 1 : cidreira
# Processing Record 7 of Set 1 : kapaa
# Processing Record 8 of Set 1 : bull savanna
# Processing Record 9 of Set 1 : upernavik
# Processing Record 10 of Set 1 : hithadhoo
# Processing Record 11 of Set 1 : atuona
# Processing Record 12 of Set 1 : sobolevo
# Processing Record 13 of Set 1 : groa
# Processing Record 14 of Set 1 : muros
# Processing Record 15 of Set 1 : ushuaia
# Processing Record 16 of Set 1 : fortuna
# Processing Record 17 of Set 1 : new norfolk
# Processing Record 18 of Set 1 : sayyan
# Processing Record 19 of Set 1 : bonavista
# Processing Record 20 of Set 1 : lakeway
# Processing Record 21 of Set 1 : whitehall
# Processing Record 22 of Set 1 : albany
# Processing Record 23 of Set 1 : tiksi
# City not found. Skipping...
# Processing Record 24 of Set 1 : lebu
# Processing Record 25 of Set 1 : punta arenas
# Processing Record 26 of Set 1 : havoysund
# City not found. Skipping...
# Processing Record 27 of Set 1 : rikitea
# Processing Record 28 of Set 1 : teya
# Processing Record 29 of Set 1 : sao felix do xingu
# Processing Record 30 of Set 1 : tura
# Processing Record 31 of Set 1 : rawson
# Processing Record 32 of Set 1 : mount isa
# Processing Record 33 of Set 1 : barrow
# Processing Record 34 of Set 1 : cape town
# Processing Record 35 of Set 1 : tazovskiy
# Processing Record 36 of Set 1 : piacabucu
# Processing Record 37 of Set 1 : nikolskoye
# Processing Record 38 of Set 1 : puerto ayora
# Processing Record 39 of Set 1 : hami
# City not found. Skipping...
# Processing Record 40 of Set 1 : jamestown
# Processing Record 41 of Set 1 : adeje
# Processing Record 42 of Set 1 : kaitangata
# Processing Record 43 of Set 1 : mahibadhoo
# Processing Record 44 of Set 1 : witu
# Processing Record 45 of Set 1 : pimentel
# Processing Record 46 of Set 1 : thompson
# Processing Record 47 of Set 1 : batagay-alyta
# Processing Record 48 of Set 1 : nizhniy kuranakh
# Processing Record 49 of Set 1 : arraial do cabo
# Processing Record 50 of Set 1 : charlottetown
# City not found. Skipping...
# Processing Record 0 of Set 2 : butaritari
# Processing Record 1 of Set 2 : necochea
# Processing Record 2 of Set 2 : aklavik
# Processing Record 3 of Set 2 : chokurdakh
# Processing Record 4 of Set 2 : brandfort
# Processing Record 5 of Set 2 : mandera
# Processing Record 6 of Set 2 : bluff
# Processing Record 7 of Set 2 : honningsvag
# City not found. Skipping...
# Processing Record 8 of Set 2 : port elizabeth
# Processing Record 9 of Set 2 : moerai
# Processing Record 10 of Set 2 : buala
# Processing Record 11 of Set 2 : mahebourg
# City not found. Skipping...
# Processing Record 12 of Set 2 : hilo
# Processing Record 13 of Set 2 : huckelhoven
# Processing Record 14 of Set 2 : cabo san lucas
# Processing Record 15 of Set 2 : saint-philippe
# Processing Record 16 of Set 2 : san patricio
# Processing Record 17 of Set 2 : praia
# Processing Record 18 of Set 2 : alofi
# Processing Record 19 of Set 2 : kununurra
# Processing Record 20 of Set 2 : vilhena
# Processing Record 21 of Set 2 : cherskiy
# Processing Record 22 of Set 2 : longyearbyen
# Processing Record 23 of Set 2 : georgetown
# Processing Record 24 of Set 2 : nuuk
# Processing Record 25 of Set 2 : busselton
# Processing Record 26 of Set 2 : ilulissat
# Processing Record 27 of Set 2 : olinda
# Processing Record 28 of Set 2 : miraflores
# Processing Record 29 of Set 2 : fare
# Processing Record 30 of Set 2 : tuktoyaktuk
# Processing Record 31 of Set 2 : longonjo
# Processing Record 32 of Set 2 : kenora
# City not found. Skipping...
# Processing Record 33 of Set 2 : mayumba
# Processing Record 34 of Set 2 : katsuura
# Processing Record 35 of Set 2 : bredasdorp
# Processing Record 36 of Set 2 : ahipara
# Processing Record 37 of Set 2 : khatanga
# Processing Record 38 of Set 2 : pastavy
# Processing Record 39 of Set 2 : abay
# Processing Record 40 of Set 2 : adrar
# Processing Record 41 of Set 2 : westport
# Processing Record 42 of Set 2 : nikopol
# Processing Record 43 of Set 2 : chapais
# Processing Record 44 of Set 2 : mar del plata
# Processing Record 45 of Set 2 : hermanus
# Processing Record 46 of Set 2 : manokwari
# Processing Record 47 of Set 2 : chuy
# Processing Record 48 of Set 2 : kenai
# Processing Record 49 of Set 2 : sisimiut
# Processing Record 50 of Set 2 : chicama
# Processing Record 0 of Set 3 : aras
# Processing Record 1 of Set 3 : deputatskiy
# Processing Record 2 of Set 3 : victoria
# Processing Record 3 of Set 3 : hamilton
# Processing Record 4 of Set 3 : ulu-telyak
# Processing Record 5 of Set 3 : am timan
# Processing Record 6 of Set 3 : lagoa
# Processing Record 7 of Set 3 : dikson
# Processing Record 8 of Set 3 : te anau
# Processing Record 9 of Set 3 : castro
# Processing Record 10 of Set 3 : beringovskiy
# Processing Record 11 of Set 3 : pisco
# Processing Record 12 of Set 3 : sattenapalle
# Processing Record 13 of Set 3 : samarai
# City not found. Skipping...
# Processing Record 14 of Set 3 : hasaki
# Processing Record 15 of Set 3 : camabatela
# Processing Record 16 of Set 3 : mataura
# Processing Record 17 of Set 3 : saldanha
# Processing Record 18 of Set 3 : qaanaaq
# Processing Record 19 of Set 3 : vila velha
# Processing Record 20 of Set 3 : tiarei
# Processing Record 21 of Set 3 : clyde river
# Processing Record 22 of Set 3 : udomlya
# Processing Record 23 of Set 3 : ha tinh
# Processing Record 24 of Set 3 : severo-kurilsk
# Processing Record 25 of Set 3 : zhigansk
# Processing Record 26 of Set 3 : krasnyy chikoy
# Processing Record 27 of Set 3 : barcelos
# Processing Record 28 of Set 3 : palana
# Processing Record 29 of Set 3 : sur
# Processing Record 30 of Set 3 : kimry
# Processing Record 31 of Set 3 : tokur
# Processing Record 32 of Set 3 : airai
# Processing Record 33 of Set 3 : helong
# Processing Record 34 of Set 3 : bambous virieux
# Processing Record 35 of Set 3 : saskylakh
# Processing Record 36 of Set 3 : hobart
# Processing Record 37 of Set 3 : ust-tsilma
# Processing Record 38 of Set 3 : port alfred
# Processing Record 39 of Set 3 : tacna
# Processing Record 40 of Set 3 : mayo
# Processing Record 41 of Set 3 : bengkulu
# Processing Record 42 of Set 3 : gorontalo
# Processing Record 43 of Set 3 : niquelandia
# City not found. Skipping...
# Processing Record 44 of Set 3 : port-cartier
# Processing Record 45 of Set 3 : east london
# Processing Record 46 of Set 3 : nortelandia
# Processing Record 47 of Set 3 : lavrentiya
# Processing Record 48 of Set 3 : maku
# Processing Record 49 of Set 3 : quatre cocos
# Processing Record 50 of Set 3 : vestmannaeyjar
# Processing Record 0 of Set 4 : ekhabi
# Processing Record 1 of Set 4 : erzin
# Processing Record 2 of Set 4 : marataizes
# Processing Record 3 of Set 4 : touros
# Processing Record 4 of Set 4 : buta
# Processing Record 5 of Set 4 : saint-augustin
# Processing Record 6 of Set 4 : kavieng
# Processing Record 7 of Set 4 : provideniya
# Processing Record 8 of Set 4 : iqaluit
# Processing Record 9 of Set 4 : riyadh
# Processing Record 10 of Set 4 : nanakuli
# Processing Record 11 of Set 4 : bereda
# Processing Record 12 of Set 4 : buchanan
# Processing Record 13 of Set 4 : opuwo
# Processing Record 14 of Set 4 : kahului
# Processing Record 15 of Set 4 : bethel
# Processing Record 16 of Set 4 : lensk
# Processing Record 17 of Set 4 : tonj
# City not found. Skipping...
# Processing Record 18 of Set 4 : yulara
# Processing Record 19 of Set 4 : ribeira grande
# Processing Record 20 of Set 4 : kohima
# Processing Record 21 of Set 4 : kapuskasing
# Processing Record 22 of Set 4 : dong hoi
# Processing Record 23 of Set 4 : sarandi
# Processing Record 24 of Set 4 : hovd
# Processing Record 25 of Set 4 : naze
# Processing Record 26 of Set 4 : sovetskaya gavan
# City not found. Skipping...
# Processing Record 27 of Set 4 : ati
# Processing Record 28 of Set 4 : taoudenni
# Processing Record 29 of Set 4 : mandalgovi
# Processing Record 30 of Set 4 : puerto lopez
# City not found. Skipping...
# Processing Record 31 of Set 4 : port-gentil
# Processing Record 32 of Set 4 : mahanoro
# Processing Record 33 of Set 4 : palmer
# City not found. Skipping...
# Processing Record 34 of Set 4 : xuanhua
# Processing Record 35 of Set 4 : nargana
# Processing Record 36 of Set 4 : nosy varika
# Processing Record 37 of Set 4 : durban
# Processing Record 38 of Set 4 : sept-iles
# Processing Record 39 of Set 4 : nome
# Processing Record 40 of Set 4 : broken hill
# Processing Record 41 of Set 4 : kasongo-lunda
# Processing Record 42 of Set 4 : brae
# Processing Record 43 of Set 4 : nanortalik
# Processing Record 44 of Set 4 : reigate
# Processing Record 45 of Set 4 : prince rupert
# Processing Record 46 of Set 4 : berlevag
# Processing Record 47 of Set 4 : flin flon
# Processing Record 48 of Set 4 : dingle
# Processing Record 49 of Set 4 : carlton
# Processing Record 50 of Set 4 : carmen
# Processing Record 0 of Set 5 : la gomera
# City not found. Skipping...
# Processing Record 1 of Set 5 : makarov
# City not found. Skipping...
# Processing Record 2 of Set 5 : pimenta bueno
# Processing Record 3 of Set 5 : lotofaga
# Processing Record 4 of Set 5 : namibe
# Processing Record 5 of Set 5 : antalaha
# Processing Record 6 of Set 5 : sabha
# Processing Record 7 of Set 5 : andenes
# Processing Record 8 of Set 5 : bogorodskoye
# Processing Record 9 of Set 5 : tual
# City not found. Skipping...
# Processing Record 10 of Set 5 : torbay
# City not found. Skipping...
# Processing Record 11 of Set 5 : nago
# Processing Record 12 of Set 5 : high prairie
# Processing Record 13 of Set 5 : kendari
# Processing Record 14 of Set 5 : rognan
# Processing Record 15 of Set 5 : santo angelo
# Processing Record 16 of Set 5 : huicheng
# Processing Record 17 of Set 5 : kungurtug
# Processing Record 18 of Set 5 : huejuquilla el alto
# Processing Record 19 of Set 5 : nangwa
# Processing Record 20 of Set 5 : puerto baquerizo moreno
# City not found. Skipping...
# Processing Record 21 of Set 5 : hays
# Processing Record 22 of Set 5 : nam som
# Processing Record 23 of Set 5 : umm kaddadah
# Processing Record 24 of Set 5 : namtsy
# Processing Record 25 of Set 5 : palmares do sul
# Processing Record 26 of Set 5 : lata
# Processing Record 27 of Set 5 : shenjiamen
# Processing Record 28 of Set 5 : henties bay
# Processing Record 29 of Set 5 : araouane
# Processing Record 30 of Set 5 : xining
# Processing Record 31 of Set 5 : mogzon
# Processing Record 32 of Set 5 : sapa
# Processing Record 33 of Set 5 : estelle
# Processing Record 34 of Set 5 : arlit
# Processing Record 35 of Set 5 : ransang
# Processing Record 36 of Set 5 : vila franca do campo
# Processing Record 37 of Set 5 : abadzekhskaya
# City not found. Skipping...
# Processing Record 38 of Set 5 : huaraz
# Processing Record 39 of Set 5 : pahrump
# Processing Record 40 of Set 5 : hualmay
# Processing Record 41 of Set 5 : miramar
# Processing Record 42 of Set 5 : springfield
# Processing Record 43 of Set 5 : tasiilaq
# Processing Record 44 of Set 5 : surgut
# Processing Record 45 of Set 5 : pontianak
# Processing Record 46 of Set 5 : golspie
# Processing Record 47 of Set 5 : severodvinsk
# Processing Record 48 of Set 5 : puerto del rosario
# Processing Record 49 of Set 5 : ban nahin
# Processing Record 50 of Set 5 : yellowknife
# Processing Record 0 of Set 6 : constitucion
# Processing Record 1 of Set 6 : sinnamary
# City not found. Skipping...
# Processing Record 2 of Set 6 : puerto el triunfo
# Processing Record 3 of Set 6 : soe
# Processing Record 4 of Set 6 : marshall
# Processing Record 5 of Set 6 : sao filipe
# Processing Record 6 of Set 6 : kattivakkam
# Processing Record 7 of Set 6 : puri
# Processing Record 8 of Set 6 : dwarka
# Processing Record 9 of Set 6 : gamboma
# Processing Record 10 of Set 6 : berbera
# Processing Record 11 of Set 6 : pevek
# Processing Record 12 of Set 6 : danville
# Processing Record 13 of Set 6 : husavik
# Processing Record 14 of Set 6 : la ronge
# Processing Record 15 of Set 6 : esperance
# Processing Record 16 of Set 6 : talnakh
# City not found. Skipping...
# Processing Record 17 of Set 6 : dunedin
# Processing Record 18 of Set 6 : grand gaube
# Processing Record 19 of Set 6 : kodiak
# Processing Record 20 of Set 6 : lasa
# Processing Record 21 of Set 6 : kijang
# Processing Record 22 of Set 6 : bhabua
# Processing Record 23 of Set 6 : caucaia
# Processing Record 24 of Set 6 : kiama
# Processing Record 25 of Set 6 : nagato
# City not found. Skipping...
# Processing Record 26 of Set 6 : goderich
# Processing Record 27 of Set 6 : melur
# Processing Record 28 of Set 6 : tautira
# Processing Record 29 of Set 6 : sola
# Processing Record 30 of Set 6 : nichinan
# Processing Record 31 of Set 6 : tefe
# Processing Record 32 of Set 6 : mehamn
# Processing Record 33 of Set 6 : nanning
# Processing Record 34 of Set 6 : gizo
# Processing Record 35 of Set 6 : vardo
# Processing Record 36 of Set 6 : faanui
# Processing Record 37 of Set 6 : alenquer
# Processing Record 38 of Set 6 : goshen
# Processing Record 39 of Set 6 : bilibino
# Processing Record 40 of Set 6 : coquimbo
# Processing Record 41 of Set 6 : saint anthony
# Processing Record 42 of Set 6 : laguna
# Processing Record 43 of Set 6 : kruisfontein
# City not found. Skipping...
# Processing Record 44 of Set 6 : makakilo city
# Processing Record 45 of Set 6 : solikamsk
# Processing Record 46 of Set 6 : kulunda
# Processing Record 47 of Set 6 : kampot
# City not found. Skipping...
# Processing Record 48 of Set 6 : sioux lookout
# Processing Record 49 of Set 6 : guerrero negro
# Processing Record 50 of Set 6 : chirongui
# Processing Record 0 of Set 7 : andros town
# Processing Record 1 of Set 7 : nagornskiy
# Processing Record 2 of Set 7 : charters towers
# Processing Record 3 of Set 7 : tiznit
# Processing Record 4 of Set 7 : plover
# Processing Record 5 of Set 7 : vrangel
# Processing Record 6 of Set 7 : batemans bay
# Processing Record 7 of Set 7 : praya
# Processing Record 8 of Set 7 : roma
# Processing Record 9 of Set 7 : salalah
# Processing Record 10 of Set 7 : augusto correa
# Processing Record 11 of Set 7 : mahendranagar
# Processing Record 12 of Set 7 : shamary
# Processing Record 13 of Set 7 : carnarvon
# Processing Record 14 of Set 7 : norman wells
# City not found. Skipping...
# Processing Record 15 of Set 7 : dongsheng
# Processing Record 16 of Set 7 : ganzhou
# Processing Record 17 of Set 7 : mount gambier
# Processing Record 18 of Set 7 : alice springs
# Processing Record 19 of Set 7 : vostok
# City not found. Skipping...
# Processing Record 20 of Set 7 : bauchi
# Processing Record 21 of Set 7 : kostomuksha
# Processing Record 22 of Set 7 : hofn
# Processing Record 23 of Set 7 : polis
# Processing Record 24 of Set 7 : vokhma
# Processing Record 25 of Set 7 : bathsheba
# City not found. Skipping...
# Processing Record 26 of Set 7 : ponta do sol
# Processing Record 27 of Set 7 : portland
# Processing Record 28 of Set 7 : geraldton
# Processing Record 29 of Set 7 : elko
# Processing Record 30 of Set 7 : jalu
# Processing Record 31 of Set 7 : flinders
# City not found. Skipping...
# Processing Record 32 of Set 7 : strathroy
# Processing Record 33 of Set 7 : tornio
# Processing Record 34 of Set 7 : beira
# Processing Record 35 of Set 7 : kieta
# Processing Record 36 of Set 7 : partizanskoye
# Processing Record 37 of Set 7 : velikodvorskiy
# Processing Record 38 of Set 7 : nuevo progreso
# Processing Record 39 of Set 7 : valdivia
# Processing Record 40 of Set 7 : kautokeino
# Processing Record 41 of Set 7 : bilma
# Processing Record 42 of Set 7 : bosaso
# Processing Record 43 of Set 7 : pangnirtung
# Processing Record 44 of Set 7 : kloulklubed
# Processing Record 45 of Set 7 : preobrazheniye
# Processing Record 46 of Set 7 : pacific grove
# Processing Record 47 of Set 7 : beidao
# City not found. Skipping...
# Processing Record 48 of Set 7 : lardos
# Processing Record 49 of Set 7 : oum hadjer
# Processing Record 50 of Set 7 : gidam
# Processing Record 0 of Set 8 : jamame
# Processing Record 1 of Set 8 : paamiut
# Processing Record 2 of Set 8 : viedma
# Processing Record 3 of Set 8 : russell
# Processing Record 4 of Set 8 : san cristobal
# Processing Record 5 of Set 8 : trincomalee
# Processing Record 6 of Set 8 : klaksvik
# Processing Record 7 of Set 8 : itarema
# Processing Record 8 of Set 8 : santa barbara
# Processing Record 9 of Set 8 : poum
# Processing Record 10 of Set 8 : kaohsiung
# City not found. Skipping...
# Processing Record 11 of Set 8 : vaitape
# Processing Record 12 of Set 8 : hambantota
# Processing Record 13 of Set 8 : redmond
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 8 : itoman
# Processing Record 15 of Set 8 : tromso
# Processing Record 16 of Set 8 : oga
# Processing Record 17 of Set 8 : mackay
# City not found. Skipping...
# Processing Record 18 of Set 8 : gewane
# Processing Record 19 of Set 8 : qaqortoq
# Processing Record 20 of Set 8 : shubarkuduk
# Processing Record 21 of Set 8 : jos
# Processing Record 22 of Set 8 : praia da vitoria
# Processing Record 23 of Set 8 : conselheiro pena
# Processing Record 24 of Set 8 : imbituva
# Processing Record 25 of Set 8 : velyka oleksandrivka
# Processing Record 26 of Set 8 : komsomolskiy
# Processing Record 27 of Set 8 : carballo
# Processing Record 28 of Set 8 : san juan
# Processing Record 29 of Set 8 : baykit
# City not found. Skipping...
# Processing Record 30 of Set 8 : san ramon de la nueva oran
# Processing Record 31 of Set 8 : padang
# Processing Record 32 of Set 8 : port said
# Processing Record 33 of Set 8 : puerto escondido
# Processing Record 34 of Set 8 : mattru
# Processing Record 35 of Set 8 : kisarawe
# Processing Record 36 of Set 8 : pozo colorado
# Processing Record 37 of Set 8 : cabedelo
# Processing Record 38 of Set 8 : bulalacao
# Processing Record 39 of Set 8 : tonstad
# Processing Record 40 of Set 8 : kunya
# Processing Record 41 of Set 8 : gibara
# Processing Record 42 of Set 8 : rocha
# City not found. Skipping...
# Processing Record 43 of Set 8 : delta
# Processing Record 44 of Set 8 : bandarbeyla
# Processing Record 45 of Set 8 : ribas do rio pardo
# Processing Record 46 of Set 8 : souillac
# Processing Record 47 of Set 8 : san julian
# Processing Record 48 of Set 8 : vallenar
# Processing Record 49 of Set 8 : rio gallegos
# Processing Record 50 of Set 8 : khomutovo
# Processing Record 0 of Set 9 : muroto
# Processing Record 1 of Set 9 : okha
# Processing Record 2 of Set 9 : khasan
# Processing Record 3 of Set 9 : ulcinj
# Processing Record 4 of Set 9 : jawhar
# Processing Record 5 of Set 9 : juneau
# Processing Record 6 of Set 9 : taunggyi
# Processing Record 7 of Set 9 : maumere
# Processing Record 8 of Set 9 : tres arroyos
# Processing Record 9 of Set 9 : hamina
# Processing Record 10 of Set 9 : rockingham
# Processing Record 11 of Set 9 : pedasi
# Processing Record 12 of Set 9 : rochegda
# Processing Record 13 of Set 9 : sawang daen din
# Processing Record 14 of Set 9 : bergama
# Processing Record 15 of Set 9 : ordynskoye
# City not found. Skipping...
# Processing Record 16 of Set 9 : coihaique
# Processing Record 17 of Set 9 : omsukchan
# Processing Record 18 of Set 9 : broome
# Processing Record 19 of Set 9 : candabong
# Processing Record 20 of Set 9 : uige
# Processing Record 21 of Set 9 : sisophon
# Processing Record 22 of Set 9 : waldoboro
# Processing Record 23 of Set 9 : leningradskiy
# Processing Record 24 of Set 9 : northam
# Processing Record 25 of Set 9 : sao joao da barra
# Processing Record 26 of Set 9 : kushmurun
# Processing Record 27 of Set 9 : magadan
# Processing Record 28 of Set 9 : kutum
# Processing Record 29 of Set 9 : chara
# City not found. Skipping...
# Processing Record 30 of Set 9 : labuhan
# Processing Record 31 of Set 9 : port hardy
# Processing Record 32 of Set 9 : port lavaca
# Processing Record 33 of Set 9 : bucerias
# Processing Record 34 of Set 9 : la libertad
# City not found. Skipping...
# Processing Record 35 of Set 9 : zlobin
# Processing Record 36 of Set 9 : chavakkad
# Processing Record 37 of Set 9 : mountain home
# Processing Record 38 of Set 9 : san policarpo
# Processing Record 39 of Set 9 : kalianget
# Processing Record 40 of Set 9 : port lincoln
# Processing Record 41 of Set 9 : aguas formosas
# Processing Record 42 of Set 9 : champerico
# Processing Record 43 of Set 9 : mombasa
# Processing Record 44 of Set 9 : maryville
# Processing Record 45 of Set 9 : marshalltown
# Processing Record 46 of Set 9 : paso de carrasco
# City not found. Skipping...
# Processing Record 47 of Set 9 : jacmel
# Processing Record 48 of Set 9 : kagadi
# Processing Record 49 of Set 9 : progreso
# Processing Record 50 of Set 9 : ust-nera
# Processing Record 0 of Set 10 : batesville
# Processing Record 1 of Set 10 : ostrovnoy
# Processing Record 2 of Set 10 : olafsvik
# Processing Record 3 of Set 10 : codrington
# Processing Record 4 of Set 10 : chebenki
# Processing Record 5 of Set 10 : alwaye
# Processing Record 6 of Set 10 : karratha
# Processing Record 7 of Set 10 : aktash
# City not found. Skipping...
# Processing Record 8 of Set 10 : auki
# Processing Record 9 of Set 10 : macia
# Processing Record 10 of Set 10 : osterburg
# Processing Record 11 of Set 10 : asosa
# Processing Record 12 of Set 10 : usak
# Processing Record 13 of Set 10 : kibre mengist
# Processing Record 14 of Set 10 : aguimes
# Processing Record 15 of Set 10 : altay
# Processing Record 16 of Set 10 : yatou
# Processing Record 17 of Set 10 : muscat
# Processing Record 18 of Set 10 : dodge city
# Processing Record 19 of Set 10 : barabai
# Processing Record 20 of Set 10 : saint-louis
# Processing Record 21 of Set 10 : harper
# Processing Record 22 of Set 10 : pangody
# Processing Record 23 of Set 10 : vanimo
# Processing Record 24 of Set 10 : banepa
# Processing Record 25 of Set 10 : wanning
# Processing Record 26 of Set 10 : kamaishi
# Processing Record 27 of Set 10 : kuchl
# Processing Record 28 of Set 10 : nhulunbuy
# Processing Record 29 of Set 10 : senanga
# Processing Record 30 of Set 10 : nouadhibou
# Processing Record 31 of Set 10 : cockburn town
# Processing Record 32 of Set 10 : glenwood springs
# Processing Record 33 of Set 10 : magaria
# Processing Record 34 of Set 10 : alta floresta
# Processing Record 35 of Set 10 : petropavlovsk-kamchatskiy
# Processing Record 36 of Set 10 : victor harbor
# Processing Record 37 of Set 10 : anuradhapura
# Processing Record 38 of Set 10 : kavaratti
# Processing Record 39 of Set 10 : saint-francois
# Processing Record 40 of Set 10 : faya
# Processing Record 41 of Set 10 : palauig
# Processing Record 42 of Set 10 : caravelas
# City not found. Skipping...
# Processing Record 43 of Set 10 : ishigaki
# Processing Record 44 of Set 10 : diego de almagro
# Processing Record 45 of Set 10 : nang rong
# Processing Record 46 of Set 10 : kamina
# Processing Record 47 of Set 10 : labytnangi
# City not found. Skipping...
# Processing Record 48 of Set 10 : veraval
# Processing Record 49 of Set 10 : annaka
# Processing Record 50 of Set 10 : raiwala
# Processing Record 0 of Set 11 : inhambane
# Processing Record 1 of Set 11 : camopi
# Processing Record 2 of Set 11 : sao miguel do araguaia
# Processing Record 3 of Set 11 : kismayo
# Processing Record 4 of Set 11 : saint george
# Processing Record 5 of Set 11 : winsum
# Processing Record 6 of Set 11 : tessalit
# Processing Record 7 of Set 11 : kouvola
# Processing Record 8 of Set 11 : yulin
# Processing Record 9 of Set 11 : lompoc
# Processing Record 10 of Set 11 : srednekolymsk
# Processing Record 11 of Set 11 : sechura
# Processing Record 12 of Set 11 : haines junction
# Processing Record 13 of Set 11 : oussouye
# Processing Record 14 of Set 11 : mweka
# Processing Record 15 of Set 11 : paragominas
# Processing Record 16 of Set 11 : igualada
# Processing Record 17 of Set 11 : belmonte
# Processing Record 18 of Set 11 : ancud
# Processing Record 19 of Set 11 : natal
# Processing Record 20 of Set 11 : kichera
# Processing Record 21 of Set 11 : merauke
# Processing Record 22 of Set 11 : deep river
# Processing Record 23 of Set 11 : tarauaca
# Processing Record 24 of Set 11 : baiyin
# Processing Record 25 of Set 11 : irece
# Processing Record 26 of Set 11 : krasnyy yar
# Processing Record 27 of Set 11 : boddam
# Processing Record 28 of Set 11 : toronto
# Processing Record 29 of Set 11 : alugan
# Processing Record 30 of Set 11 : norrtalje
# Processing Record 31 of Set 11 : savannah bight
# Processing Record 32 of Set 11 : byron bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 11 : svetlogorsk
# Processing Record 34 of Set 11 : straumen
# Processing Record 35 of Set 11 : oistins
# Processing Record 36 of Set 11 : oxbow
# Processing Record 37 of Set 11 : yuxia
# Processing Record 38 of Set 11 : college
# Processing Record 39 of Set 11 : krasnoselkup
# Processing Record 40 of Set 11 : chulym
# Processing Record 41 of Set 11 : manali
# Processing Record 42 of Set 11 : todos santos
# Processing Record 43 of Set 11 : sitka
# Processing Record 44 of Set 11 : sierpc
# Processing Record 45 of Set 11 : kilimatinde
# Processing Record 46 of Set 11 : jaitaran
# Processing Record 47 of Set 11 : ozernovskiy
# Processing Record 48 of Set 11 : belyy yar
# Processing Record 49 of Set 11 : zharkent
# Processing Record 50 of Set 11 : mpongwe
# Processing Record 0 of Set 12 : morehead
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Put the data into a dataframe
city_data_df = pd.DataFrame({
    "City": city_names,
    "Lat": lat,
    "Lng": long,
    "Max Temp": maxtemp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
})

# Display the DataFrame
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Vaini -21.2000 -175.2000     75.36        94          75        4.61
# 1     Nyurba  63.2842  118.3319     26.29        70          86        3.29
# 2     Avarua -21.2078 -159.7750     77.05        88          75       12.66
# 3  Ketchikan  55.3422 -131.6461     47.41        70          97        4.29
# 4   Cidreira -30.1811  -50.2056     63.95        55          12       11.74
#
#   Country        Date
# 0      TO  05-18-2021
# 1      RU  05-18-2021
# 2      CK  05-18-2021
# 3      US  05-18-2021
# 4      BR  05-18-2021

# %%
# How many entries were returned?
city_data_df.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
# Inspect the data by using the describe function
city_data_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed
# count  560.000000  560.000000  560.000000  560.000000  560.000000  560.000000
# mean    20.843370   14.277728   67.172482   67.639286   60.808929    7.746286
# std     32.933715   90.887361   18.630310   21.337694   37.200721    5.270435
# min    -54.800000 -175.200000   12.740000    5.000000    0.000000    0.000000
# 25%     -6.692700  -67.224050   56.177500   55.000000   25.000000    3.850000
# 50%     22.608150   19.229450   71.520000   71.000000   75.000000    6.630000
# 75%     49.279200   96.535825   80.627500   83.250000   97.000000   10.487500
# max     78.218600  179.316700  115.410000  100.000000  100.000000   29.930000

# %%
# Export the city data into a csv file
city_data_df.to_csv("../output_data/city_data.csv", index=False)

# %%
# Show Record Count
countforme = len(city_data_df)
countforme
# Out:
# 560

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Calculate latest date (max) for plot titles
tstamp = city_data_df.Date.max()
tstamp
# Out:
# '05-18-2021'

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude")

plt.savefig("../images/tempvlat.png")

# As latitude approaches 0, i.e. the equator, temperature increases

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Humidity (%) vs Latitude")

plt.savefig("../images/humvlat.png")

# There seems to be no relationship between humidity and latitude

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Cloudiness (%) vs Latitude")

plt.savefig("../images/cloudvlat.png")

# There seems to be no relationship between cloudiness and latitude

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Wind Speed (mph) vs Latitude")

plt.savefig("../images/windvlat.png")

# There seems to be no relationship between wind speed and latitude

# %% [markdown]
# ## Linear Regression

# %%
# Locate cities above or equal to 0 latitude and below 0 latitude
northern_cities = city_data_df[city_data_df.loc[:, "Lat"] >= 0]
southern_cities = city_data_df[city_data_df.loc[:, "Lat"] < 0]

# %%
# Create Northern and Southern Hemisphere DataFrames
northlat_df = city_data_df.loc[city_data_df["Lat"] >= 0,:]
southlat_df = city_data_df.loc[city_data_df["Lat"] < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot Temperature (°F) vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Max Temp"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(5,30), fontsize=13,color="red")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/tempvlatnh.png")

# %%
print("The high r value indicates a strong positive correlation between latitude and max temperature.")
# Out:
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Plot Temperature (°F) vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Max Temp"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Temperature (°F)")
plt.title("Temperature (°F) vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Max Temp"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-53,81),fontsize=12,color="red")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/tempvlatsh.png")

# %%
print("The high r value indicates a strong positive correlation between latitude and max temperature.")
# Out:
# The high r value indicates a strong positive correlation between latitude and max temperature.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot Humidity vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Humidity"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(48,10),fontsize=13,color="red")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/northernhumvlat.png")

# %%
print("The low r values indicate a weak to no relationship between humidity and latitude.")
# Out:
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Plot Humidity vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Humidity"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-55,25), fontsize=13,color="red")
plt.plot(southern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/sourthernhumvlat.png")

# %%
print("The low r values indicate a weak to no relationship between humidity and latitude.")
# Out:
# The low r values indicate a weak to no relationship between humidity and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot Cloudiness vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Humidity"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Cloudiness"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(46,10), fontsize=13,color="red")
plt.plot(northern_cities["Lat"],regress_values,"r-")

plt.savefig("../images/northerncloudvlat.png")

# %%
print("The low r values indicate a weak positive relationship between latitude and cloudiness.")
# Out:
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Plot Cloudiness vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Cloudiness"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Cloudiness"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-55,10),fontsize=13,color="red")
plt.plot(southern_cities["Lat"], regress_values,"r-")

plt.savefig('../images/southerncloudvlat')

# %%
print("The low r values indicate a weak positive relationship between latitude and cloudiness.")
# Out:
# The low r values indicate a weak positive relationship between latitude and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot Wind Speed (mph) vs Latitude with linear regression for northern hemisphere
plt.scatter(northern_cities["Lat"], northern_cities["Wind Speed"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed (mph) vs Latitude (NH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_cities["Lat"], northern_cities["Wind Speed"])
regress_values = northern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(0,26),fontsize=13,color="red")
plt.plot(northern_cities["Lat"], regress_values,"r-")

plt.savefig('../images/northernwindvlat')

# %%
print("The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.")
# Out:
# The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Plot Wind Speed (mph) vs Latitude with linear regression for southern hemisphere
plt.scatter(southern_cities["Lat"], southern_cities["Wind Speed"], marker = "o", s = 25, facecolor = "teal", edgecolor="black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed (mph) vs Latitude (SH)")
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities["Lat"], southern_cities["Wind Speed"])
regress_values = southern_cities["Lat"] * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.annotate(line_equation,(-55,23),fontsize=13,color="red")
plt.plot(southern_cities["Lat"], regress_values,"r-")

plt.savefig('../images/southernwindvlat')

# %%
print("The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.")
# Out:
# The low r value indicates that there is no significant relationship between wind speed and latitude. The difference between the hemispheres doesn't seem to be significant enough to comment upon.
